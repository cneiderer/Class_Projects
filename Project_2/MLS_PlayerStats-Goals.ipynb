# %% [markdown]
# ## Scraping MLS Player Stats

# %% [markdown]
# Scraping www.mlssoccer.com/ for player statistics

# %% [markdown]
# ### Import Necessary Modules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime 
from dateutil import parser
import os
import time
import itertools
import re
import pickle

# %% [markdown]
# ### Scrape Statistics

# %% [markdown]
# #### Define Scraper and Helpers

# %%
def send_request(url, params={}, attempts=3):

    cnt = 0
    while cnt <= attempts:
        cnt += 1        
        # Send Request
        response = requests.get(url, params)
        # Check Status
        print(response.url, '\n', response.status_code, response.reason)
        if (response.status_code >= 200) and (response.status_code < 300):           
            return response
        # If bad status, pause before trying again
        print('Pause, then retry')
        time.sleep(15)
    return None

# %%
def map_id_to_club(franchise_id):
    
    franchise_map = {11091: 'ATL',
                     1207: 'CHI',
                     436: 'COL',
                     454: 'CLB',
                     1326: 'DC',
                     1903: 'DAL',
                     1897: 'HOU',
                     1230: 'LA',
                     11690: 'LAFC',
                     6977: 'MNUFC',
                     1616: 'MTL',
                     928: 'NE',
                     9668: 'NYCFC',
                     399: 'NYRB',
                     6900: 'ORL',
                     5513: 'PHI',
                     1581: 'POR',
                     1899: 'RSL',
                     1131: 'SJ',
                     3500: 'SEA',
                     421: 'KC',
                     2077: 'TOR',
                     1708: 'VAN'}
    return franchise_map[franchise_id]

# %%
def check_for_data(stats_table):
    # Check if the table has any 
    odd_rows = stats_table.findAll('tr', {'class': 'odd'})
    if odd_rows[0].text.strip() == 'Stats Unavailable':
        return False
    return True

# %%
def split_player_name(df):
    first = []
    last = []
    for t in df.Player.str.split():
        if len(t) == 1:
            first.append(t[0])
            last.append('')
        elif len(t) == 2:
            first.append(t[0])
            last.append(t[1])
        else:
            first.append(t[0])
            last.append(' '.join(t[1:]))
    
    df['Last'] = last
    df['First'] = first  
    
    df = df.drop('Player', axis=1)
    
    return df

# %%
# # Find and parse franchise popup menu to get list of teams
# soup = BeautifulSoup(response.text, 'lxml')
# franchise_select = soup.find('select', {'id': 'edit-franchise', 'name': 'franchise'})
# franchise = []
# # start with second index since first is generic "Select A Club"
# for team in franchise_select.findAll('option')[1:]:
#     franchise.append(int(team['value']))

# %%
def generate_param_combos(param_groups):
    params = []
    for combo in itertools.product(*param_groups):
        params.append({'franchise': combo[0],
                       'group': combo[1],
                       'season_type': combo[2],
                       'year': combo[3],
                       'page': combo[4]})
    return params

# %%
def scrape_player_stats(base_url, params, return_last_pg=False):

    response = send_request(base_url, params)
    if response is None:
        return None
    
    # Parse HTML
    soup = BeautifulSoup(response.text,'lxml')
    
    stats_table = soup.find('table')
    
    if not check_for_data(stats_table):
        return None
    
    stats_df = extract_stats(stats_table)
    # Add Year Column
    stats_df['Year'] = np.repeat(int(params['year']), len(stats_df))
    # Add Season Column
    stats_df['Season'] = np.repeat(params['season_type'], len(stats_df))
    
    if return_last_pg:
        return stats_df, get_last_page(soup)
    
    return stats_df

# %%
url = 'https://www.mlssoccer.com/stats/season?franchise=select&group=assists&season_type=REG&year=2009&page=14'

# %%
response = send_request(url)
# Out:
# https://www.mlssoccer.com/stats/season?franchise=select&group=assists&season_type=REG&year=2009&page=14
#  200 OK

# %%
soup = BeautifulSoup(response.text, 'lxml')

# %%
stat_table = soup.find('table')
# stat_table.findAll('tr')[-1]

# %%
    # Extract salary data
    stat_header = []
    stat_data = []
    t = []
    for row in stat_table.findAll('tr'):
        row_data = []

        # Get row type and check if header or data row
        row_type = row.findChild().name
        if row_type == 'th':
            # Extract header
            for h in stat_table.findAll('th'):
                stat_header.append(h.text) 
        else:
            # Extract data
            for data in row.findAll('td'):
                row_data.append(data.text)
            stat_data.append(row_data)

# %%
def extract_stats(stat_table):
    
    # Extract salary data
    stat_header = []
    stat_data = []
    for row in stat_table.findAll('tr'):
        row_data = []

        # Get row type and check if header or data row
        row_type = row.findChild().name
        if row_type == 'th':
            # Extract header
            for h in stat_table.findAll('th'):
                stat_header.append(h.text) 
        else:
            # Extract data
            for data in row.findAll('td'):
                row_data.append(data.text)
            stat_data.append(row_data)    
            
    # Compile stat dataframe
    stat_df = pd.DataFrame(stat_data, columns=stat_header)
    
    # Strip any whitespace from column names
    stat_df.columns = stat_df.columns.str.strip()
    
    # Replace blanks with nans
    stat_df = stat_df.replace('', np.nan)
        
    return stat_df

# %%
def get_last_page(soup):

    last_pg_url = soup.find('li', {'class': 'pager-last last'}).find('a')['href']
    last_pg = int(re.search('(?<=page=)\d+', last_pg_url).group())
    
    return last_pg

# %%
def scrape_group_stats(base_url, group, year=np.arange(2007, 2018), franchise='select', season_type='REG'):
    
    group_df = pd.DataFrame()
    combos = generate_param_combos([[franchise], [group], [season_type], year, [0]])
    for params in combos: 
        stats_df, last_pg = scrape_player_stats(base_url, params, True)
        
        if stats_df is None:
            continue
            
        # Scrape first page of results
        df = pd.concat([group_df, stats_df], axis=0)
        # Add pause to prevent 429 status
        print(datetime.now())
        time.sleep(np.random.uniform(2, 5)) 
        
        # Scrape next through last
        for idx in range(1, last_pg+1):
            params['page'] = idx
            stats_df = scrape_player_stats(base_url, params)
            if stats_df is None:
                continue
            group_df = pd.concat([group_df, stats_df], axis=0)            
            # Add pause to prevent 429 status
            print(datetime.now())
            time.sleep(np.random.uniform(2, 5)) 
            
    # Reset index to remove duplicates created during concatenation
    group_df.reset_index(inplace=True, drop=True)
    
    return group_df

# %% [markdown]
# #### Send Request to Base URL and Verify Site is Up

# %%
base_url = 'http://www.mlssoccer.com/stats/season'
response = requests.get(base_url)
response.status_code, response.url
# Out:
# (200, 'https://www.mlssoccer.com/stats/season')

# %% [markdown]
# #### Define parameter options

# %%
# group = ['goals', 'assists', 'shots', 'fouls', 'goalkeeping']
# for grp in group:
#     print('Scraping:', grp, datetime.now(), '\n')
#     df = scrape_group_stats(base_url, grp, np.arange(2007, 2018, 1))
#     df.to_pickle(grp + '_df.pkl')
#     print('Completed Scraping:', grp)

# %%
 goals_df = scrape_group_stats(base_url, 'goals')
# Out:
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2007&page=0
#  200 OK
# 2018-01-26 12:56:06.661022
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2007&page=1
#  200 OK
# 2018-01-26 12:56:13.431081
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2007&page
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=17
#  200 OK
# 2018-01-26 13:20:12.856810
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=18
#  200 OK
# 2018-01-26 13:20:18.857863
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=19
#  200 OK
# 2018-01-26 13:20:25.628494
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=20
#  200 OK
# 2018-01-26 13:20:33.135684
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=21
#  200 OK
# 2018-01-26 13:20:40.647295
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=22
#  200 OK
# 2018-01-26 13:20:48.343362
# https://www.mlssoccer.com/stats/season?franchise=select&group=goals&season_type=REG&year=2017&page=23
#  200 OK
# 2018-01-26 13:20:54.830522

# %%
goals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5041 entries, 0 to 5040
# Data columns (total 18 columns):
# Player     5041 non-null object
# Club       5037 non-null object
# POS        5041 non-null object
# GP         5037 non-null object
# GS         5037 non-null object
# MINS       5037 non-null object
# G          5037 non-null object
# A          5037 non-null object
# SHTS       5037 non-null object
# SOG        5037 non-null object
# GWG        5037 non-null object
# PKG/A      5041 non-null object
# HmG        5037 non-null object
# RdG        5037 non-null object
# G/90min    5041 non-null object
# SC%        5041 non-null object
# Year       5041 non-null int64
# Season     5041 non-null object
# dtypes: int64(1), object(17)
# memory usage: 709.0+ KB

# %%
goals_df
# Out:
#                           Player Club  POS  GP  GS  MINS  G   A SHTS SOG GWG  \
# 0                   Danny Dichio  TOR    F  17  14  1175  6   1   20  13   0
# 1                Jeff Cunningham  RSL    F  23  20  1636  6   1   32  21   0
# 2                      Juan Toja  DAL    M  27  27  2388  6   1   33  16   3
# 3                 Jovan Kirovski  COL  M-F  28  28  2161  6   1   36  14   2
# 4     Guillermo Barros Schelotto  CLB    F  22  19  1605  5  11   39  18   3
# 5                    Eddie Gaven  CLB    M  27  21  1923  5   7   59  33   0
# 6                  Stuart Holden  HOU    M  22  10  1030  5   5   24  13   3
# 7                   Abe Thompson  DAL    F  24  15  1227  5   4   19  11   2
# 8                   Edson Buddle  LA     F  26  15  1251  5   2   47  23   2
# 9                    Chris Brown  RSL  M-F  22  12  1083  5   0   23  13   0
# 10                Yura Movsisyan  RSL    F  23   9   993  5   0   42  13   1
# 11                 Steve Ralston  NE     M  26  26  2337  4  14   33  18   2
# 12                Sacha Kljestan  OCS    M  25  25  2186  4  13   40  21   0
# 13                   Davy Arnaud  KC     M  28  28  2489  4   9   74  29   0
# 14             Cuauhtemoc Blanco  CHI    M  14  14  1233  4   7   26  14   2
# 15                    Cobi Jones  LA     M  25  19  1679  4   5   19  12   1
# 16                Shalrie Joseph  NE     M  27  27  2366  4   5   42  14   1
# 17                 Adam Cristman  NE     F  28  14  1421  4   4   40  16   0
# 18                   Andy Herron  CLB    F  18  10   794  4   2   19  10   0
# 19                  Kenny Cooper  DAL    F  14  12  1068  4   2   33  16   1
# 20                Hérculez Gómez  COL    F  20  16  1537  4   2   51  22   1
# 21                   Maurice Edu  TOR    M  25  25  2180  4   1   24   8   1
# 22                 Gavin Glinton  LA     F  19   3   711  4   0   19  12   2
# 23                   Ramon Nunez  CHV    M  21  12  1248  3   5   43  15   2
# 24            Michael Harrington  KC     D  29  27  2422  3   4   15   9   0
# 25              Jeff Larentowicz  ATL    M  28  28  2455  3   4   28   9   1
# 8      0/0   4   1    0.36  10.6  2007    REG
# 9      0/0   2   3    0.42  21.7  2007    REG
# 10     0/0   2   3    0.45  11.9  2007    REG
# 11     0/0   4   0    0.15  12.1  2007    REG
# 12     1/1   1   3    0.16  10.0  2007    REG
# 13     0/0   1   3    0.14   5.4  2007    REG
# 14     1/2   2   2    0.29  15.4  2007    REG
# 15     0/0   4   0    0.21  21.1  2007    REG
# 16     3/4   3   1    0.15   9.5  2007    REG
# 17     0/0   3   1    0.25  10.0  2007    REG
# 18     1/1   2   2    0.45  21.1  2007    REG
# 19     1/1   0   4    0.34  12.1  2007    REG
# 20     0/0   3   1    0.23   7.8  2007    REG
# 21     0/0   3   1    0.17  16.7  2007    REG
# 22     0/0   1   3    0.51  21.1  2007    REG
# 23     0/0   3   0    0.22   7.0  2007    REG
# 24     0/0   2   1    0.11  20.0  2007    REG
# 25     0/0   1   2    0.11  10.7  2007    REG
# 26     1/1   3   0    0.21  11.1  2007    REG
# 27     0/1   2   1    0.13   8.1  2007    REG
# 28     0/0   0   3    0.11   5.8  2007    REG
# 29     0/0   2   1    0.14   4.9  2007    REG
# ...    ...  ..  ..     ...   ...   ...    ...
# 5011   0/0   0   0    0.00   0.0  2017    REG
# 5012   0/0   0   0    0.00   0.0  2017    REG
# 5013   0/0   0   0    0.00   0.0  2017    REG
# 5014   0/0   0   0    0.00   0.0  2017    REG
# 5015   0/0   0   0    0.00   0.0  2017    REG
# 5016   0/0   0   0    0.00   0.0  2017    REG
# 5017   0/0   0   0    0.00   0.0  2017    REG
# 5018   0/0   0   0    0.00   0.0  2017    REG
# 5019   0/0   0   0    0.00   0.0  2017    REG
# 5020   0/0   0   0    0.00   0.0  2017    REG
# 5021   0/0   0   0    0.00   0.0  2017    REG
# 5022   0/0   0   0    0.00   0.0  2017    REG
# 5023   0/0   0   0    0.00   0.0  2017    REG
# 5024   0/0   0   0    0.00   0.0  2017    REG
# 5025   0/0   0   0    0.00   0.0  2017    REG
# 5026   0/0   0   0    0.00   0.0  2017    REG
# 5027   0/0   0   0    0.00   0.0  2017    REG
# 5028   0/0   0   0    0.00   0.0  2017    REG
# 5029   0/0   0   0    0.00   0.0  2017    REG
# 5030   0/0   0   0    0.00   0.0  2017    REG
# 5031   0/0   0   0    0.00   0.0  2017    REG
# 5032   0/0   0   0    0.00   0.0  2017    REG
# 5033   0/0   0   0    0.00   0.0  2017    REG
# 5034   0/0   0   0    0.00   0.0  2017    REG
# 5035   0/0   0   0    0.00   0.0  2017    REG
# 5036   0/0   0   0    0.00   0.0  2017    REG
# 5037   0/0   0   0    0.00   0.0  2017    REG
# 5038   0/0   0   0    0.00   0.0  2017    REG
# 5039   0/0   0   0    0.00   0.0  2017    REG
# 5040   0/0   0   0    0.00   0.0  2017    REG
#
# [5041 rows x 18 columns]

# %%
goals_df.to_pickle('goals_df.pkl')

# %% [markdown]
# ### Sandbox

# %%
goals_df2 = goals_df.convert_objects(convert_numeric=True)
# Out:
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
goals_df2.describe()
# Out:
#                 GP           GS         MINS            G            A  \
# count  5037.000000  5037.000000  5037.000000  5037.000000  5037.000000
# mean     14.693071    11.351598  1020.098471     1.052214     1.295414
# std      10.766452    10.296154   897.450863     1.745143     2.110454
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     1.000000   147.000000     0.000000     0.000000
# 50%      15.000000     9.000000   831.000000     0.000000     0.000000
# 75%      25.000000    20.000000  1769.000000     1.000000     2.000000
# max      35.000000    34.000000  3060.000000    11.000000    20.000000
#
#               SHTS          SOG          GWG          HmG          RdG  \
# count  5037.000000  5037.000000  5037.000000  5037.000000  5037.000000
# mean     11.998412     4.167957     0.283899     0.632916     0.419297
# std      15.144354     5.875291     0.654614     1.179507     0.858824
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       6.000000     2.000000     0.000000     0.000000     0.000000
# 75%      17.000000     6.000000     0.000000     1.000000     1.000000
# max     121.000000    46.000000     6.000000     9.000000     8.000000
#
#            G/90min          SC%         Year
# count  5041.000000  5041.000000  5041.000000
# mean      0.094569     5.915929  2012.480063
# std       0.666906    10.540524     3.082215
# min       0.000000     0.000000  2007.000000
# 25%       0.000000     0.000000  2010.000000
# 50%       0.000000     0.000000  2013.000000
# 75%       0.110000     9.700000  2015.000000
# max      45.000000   100.000000  2017.000000

# %%
goals_df[['PKG', 'PKA']] = goals_df['PKG/A'].str.split('/', expand=True)
goals_df.drop('PKG/A', axis=1, inplace=True)

# %%
cols = ['GP', 'GS', 'MINS', 'G', 'A', 'SHTS', 'SOG', 'GWG', 'HmG', 'RdG', 'G/90min', 'SC%', 'Year', 'PKG', 'PKA']

# %%
goals_df[cols] = goals_df[cols].apply(pd.to_numeric)

# %%
goals_df.describe()
# Out:
#                 GP           GS         MINS            G            A  \
# count  5037.000000  5037.000000  5037.000000  5037.000000  5037.000000
# mean     14.693071    11.351598  1020.098471     1.052214     1.295414
# std      10.766452    10.296154   897.450863     1.745143     2.110454
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     1.000000   147.000000     0.000000     0.000000
# 50%      15.000000     9.000000   831.000000     0.000000     0.000000
# 75%      25.000000    20.000000  1769.000000     1.000000     2.000000
# max      35.000000    34.000000  3060.000000    11.000000    20.000000
#
#               SHTS          SOG          GWG          HmG          RdG  \
# count  5037.000000  5037.000000  5037.000000  5037.000000  5037.000000
# mean     11.998412     4.167957     0.283899     0.632916     0.419297
# std      15.144354     5.875291     0.654614     1.179507     0.858824
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       6.000000     2.000000     0.000000     0.000000     0.000000
# 75%      17.000000     6.000000     0.000000     1.000000     1.000000
# max     121.000000    46.000000     6.000000     9.000000     8.000000
#
#            G/90min          SC%         Year          PKG          PKA
# count  5041.000000  5041.000000  5041.000000  5037.000000  5037.000000
# mean      0.094569     5.915929  2012.480063     0.061346     0.082787
# std       0.666906    10.540524     3.082215     0.364761     0.434895
# min       0.000000     0.000000  2007.000000     0.000000     0.000000
# 25%       0.000000     0.000000  2010.000000     0.000000     0.000000
# 50%       0.000000     0.000000  2013.000000     0.000000     0.000000
# 75%       0.110000     9.700000  2015.000000     0.000000     0.000000
# max      45.000000   100.000000  2017.000000     5.000000     6.000000
