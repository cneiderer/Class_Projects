# %% [markdown]
# ## Scraping MLS Player Stats

# %% [markdown]
# Scraping www.mlssoccer.com/ for player statistics

# %% [markdown]
# ### Import Necessary Modules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime 
from dateutil import parser
import os
import time
import itertools
import re
import pickle

# %% [markdown]
# ### Scrape Statistics

# %% [markdown]
# #### Define Scraper and Helpers

# %%
def send_request(url, params={}, attempts=3):

    cnt = 0
    while cnt <= attempts:
        cnt += 1        
        # Send Request
        response = requests.get(url, params)
        # Check Status
        print(response.url, '\n', response.status_code, response.reason)
        if (response.status_code >= 200) and (response.status_code < 300):           
            return response
        # If bad status, pause before trying again
        print('Pause, then retry')
        time.sleep(15)
    return None

# %%
def map_id_to_club(franchise_id):
    
    franchise_map = {11091: 'ATL',
                     1207: 'CHI',
                     436: 'COL',
                     454: 'CLB',
                     1326: 'DC',
                     1903: 'DAL',
                     1897: 'HOU',
                     1230: 'LA',
                     11690: 'LAFC',
                     6977: 'MNUFC',
                     1616: 'MTL',
                     928: 'NE',
                     9668: 'NYCFC',
                     399: 'NYRB',
                     6900: 'ORL',
                     5513: 'PHI',
                     1581: 'POR',
                     1899: 'RSL',
                     1131: 'SJ',
                     3500: 'SEA',
                     421: 'KC',
                     2077: 'TOR',
                     1708: 'VAN'}
    return franchise_map[franchise_id]

# %%
def check_for_data(stats_table):
    # Check if the table has any 
    odd_rows = stats_table.findAll('tr', {'class': 'odd'})
    if odd_rows[0].text.strip() == 'Stats Unavailable':
        return False
    return True

# %%
def split_player_name(df):
    first = []
    last = []
    for t in df.Player.str.split():
        if len(t) == 1:
            first.append(t[0])
            last.append('')
        elif len(t) == 2:
            first.append(t[0])
            last.append(t[1])
        else:
            first.append(t[0])
            last.append(' '.join(t[1:]))
    
    df['Last'] = last
    df['First'] = first  
    
    df = df.drop('Player', axis=1)
    
    return df

# %%
# # Find and parse franchise popup menu to get list of teams
# soup = BeautifulSoup(response.text, 'lxml')
# franchise_select = soup.find('select', {'id': 'edit-franchise', 'name': 'franchise'})
# franchise = []
# # start with second index since first is generic "Select A Club"
# for team in franchise_select.findAll('option')[1:]:
#     franchise.append(int(team['value']))

# %%
def generate_param_combos(param_groups):
    params = []
    for combo in itertools.product(*param_groups):
        params.append({'franchise': combo[0],
                       'group': combo[1],
                       'season_type': combo[2],
                       'year': combo[3],
                       'page': combo[4]})
    return params

# %%
def scrape_player_stats(base_url, params, return_last_pg=False):

    response = send_request(base_url, params)
    if response is None:
        return None
    
    # Parse HTML
    soup = BeautifulSoup(response.text,'lxml')
    
    stats_table = soup.find('table')
    
    if not check_for_data(stats_table):
        return None
    
    stats_df = extract_stats(stats_table)
    # Add Year Column
    stats_df['Year'] = np.repeat(int(params['year']), len(stats_df))
    # Add Season Column
    stats_df['Season'] = np.repeat(params['season_type'], len(stats_df))
    
    if return_last_pg:
        return stats_df, get_last_page(soup)
    
    return stats_df

# %%
url = 'https://www.mlssoccer.com/stats/season?franchise=select&group=assists&season_type=REG&year=2009&page=14'

# %%
response = send_request(url)
# Out:
# https://www.mlssoccer.com/stats/season?franchise=select&group=assists&season_type=REG&year=2009&page=14
#  200 OK

# %%
soup = BeautifulSoup(response.text, 'lxml')

# %%
stat_table = soup.find('table')
# stat_table.findAll('tr')[-1]

# %%
    # Extract salary data
    stat_header = []
    stat_data = []
    t = []
    for row in stat_table.findAll('tr'):
        row_data = []

        # Get row type and check if header or data row
        row_type = row.findChild().name
        if row_type == 'th':
            # Extract header
            for h in stat_table.findAll('th'):
                stat_header.append(h.text) 
        else:
            # Extract data
            for data in row.findAll('td'):
                row_data.append(data.text)
            stat_data.append(row_data)

# %%
def extract_stats(stat_table):
    
    # Extract salary data
    stat_header = []
    stat_data = []
    for row in stat_table.findAll('tr'):
        row_data = []

        # Get row type and check if header or data row
        row_type = row.findChild().name
        if row_type == 'th':
            # Extract header
            for h in stat_table.findAll('th'):
                stat_header.append(h.text) 
        else:
            # Extract data
            for data in row.findAll('td'):
                row_data.append(data.text)
            stat_data.append(row_data)    
            
    # Compile stat dataframe
    stat_df = pd.DataFrame(stat_data, columns=stat_header)
    
    # Strip any whitespace from column names
    stat_df.columns = stat_df.columns.str.strip()
    
    # Replace blanks with nans
    stat_df = stat_df.replace('', np.nan)
        
    return stat_df

# %%
def get_last_page(soup):

    last_pg_url = soup.find('li', {'class': 'pager-last last'}).find('a')['href']
    last_pg = int(re.search('(?<=page=)\d+', last_pg_url).group())
    
    return last_pg

# %%
def scrape_group_stats(base_url, group, year=np.arange(2007, 2018), franchise='select', season_type='REG'):
    
    group_df = pd.DataFrame()
    combos = generate_param_combos([[franchise], [group], [season_type], year, [0]])
    for params in combos: 
        stats_df, last_pg = scrape_player_stats(base_url, params, True)
        
        if stats_df is None:
            continue
            
        # Scrape first page of results
        df = pd.concat([group_df, stats_df], axis=0)
        # Add pause to prevent 429 status
        print(datetime.now())
        time.sleep(np.random.uniform(2, 5)) 
        
        # Scrape next through last
        for idx in range(1, last_pg+1):
            params['page'] = idx
            stats_df = scrape_player_stats(base_url, params)
            if stats_df is None:
                continue
            group_df = pd.concat([group_df, stats_df], axis=0)            
            # Add pause to prevent 429 status
            print(datetime.now())
            time.sleep(np.random.uniform(2, 5)) 
            
    # Reset index to remove duplicates created during concatenation
    group_df.reset_index(inplace=True, drop=True)
    
    return group_df

# %% [markdown]
# #### Send Request to Base URL and Verify Site is Up

# %%
base_url = 'http://www.mlssoccer.com/stats/season'
response = requests.get(base_url)
response.status_code, response.url
# Out:
# (200, 'https://www.mlssoccer.com/stats/season')

# %% [markdown]
# #### Define parameter options

# %%
# group = ['goals', 'assists', 'shots', 'fouls', 'goalkeeping']
# for grp in group:
#     print('Scraping:', grp, datetime.now(), '\n')
#     df = scrape_group_stats(base_url, grp, np.arange(2007, 2018, 1))
#     df.to_pickle(grp + '_df.pkl')
#     print('Completed Scraping:', grp)

# %%
 shots_df = scrape_group_stats(base_url, 'shots')
# Out:
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=0
#  200 OK
# 2018-01-26 11:37:25.482855
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=1
#  200 OK
# 2018-01-26 11:37:35.339322
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=2
#  200 OK
# 2018-01-26 11:37:41.171442
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=3
#  200 OK
# 2018-01-26 11:37:49.494501
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=4
#  200 OK
# 2018-01-26 11:37:54.847556
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=5
#  200 OK
# 2018-01-26 11:38:00.448073
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=6
#  200 OK
# 2018-01-26 11:38:10.472340
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=7
#  200 OK
# 2018-01-26 11:38:19.662553
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=8
#  200 OK
# 2018-01-26 11:38:28.429671
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=9
#  200 OK
# 2018-01-26 11:38:33.497487
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=10
#  200 OK
# 2018-01-26 11:38:38.838898
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=11
#  200 OK
# 2018-01-26 11:38:46.451256
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=12
#  200 OK
# 2018-01-26 11:38:53.641302
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=13
#  200 OK
# 2018-01-26 11:39:02.698515
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2007&page=14
#  200 OK
# 2018-01-26 11:39:08.221534
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=0
#  200 OK
# 2018-01-26 11:39:13.419905
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=1
#  200 OK
# 2018-01-26 11:39:20.626262
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=2
#  200 OK
# 2018-01-26 11:39:26.286587
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=3
#  200 OK
# 2018-01-26 11:39:33.638226
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=4
#  200 OK
# 2018-01-26 11:39:39.248782
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=5
#  200 OK
# 2018-01-26 11:39:45.814564
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=6
#  200 OK
# 2018-01-26 11:39:52.262250
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=7
#  200 OK
# 2018-01-26 11:39:57.842422
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=8
#  200 OK
# 2018-01-26 11:40:02.411320
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=9
#  200 OK
# 2018-01-26 11:40:08.720557
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=10
#  200 OK
# 2018-01-26 11:40:13.753407
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=11
#  200 OK
# 2018-01-26 11:40:21.391492
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=12
#  200 OK
# 2018-01-26 11:40:27.673135
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=13
#  200 OK
# 2018-01-26 11:40:34.629004
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=14
#  200 OK
# 2018-01-26 11:40:40.472560
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=15
#  200 OK
# 2018-01-26 11:40:48.386502
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2008&page=16
#  200 OK
# 2018-01-26 11:40:58.744025
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=0
#  200 OK
# 2018-01-26 11:41:03.310756
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=1
#  200 OK
# 2018-01-26 11:41:08.976825
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=2
#  200 OK
# 2018-01-26 11:41:16.460954
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=3
#  200 OK
# 2018-01-26 11:41:22.461243
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=4
#  200 OK
# 2018-01-26 11:41:27.068530
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=5
#  200 OK
# 2018-01-26 11:41:32.281979
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=6
#  200 OK
# 2018-01-26 11:41:39.553012
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=7
#  200 OK
# 2018-01-26 11:41:45.004909
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=8
#  200 OK
# 2018-01-26 11:41:50.659005
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=9
#  200 OK
# 2018-01-26 11:41:56.326800
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=10
#  200 OK
# 2018-01-26 11:42:01.071326
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=11
#  200 OK
# 2018-01-26 11:42:08.056628
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=12
#  200 OK
# 2018-01-26 11:42:14.959788
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=13
#  200 OK
# 2018-01-26 11:42:20.845228
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2009&page=14
#  200 OK
# 2018-01-26 11:42:27.707122
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=0
#  200 OK
# 2018-01-26 11:42:34.021348
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=1
#  200 OK
# 2018-01-26 11:42:39.031791
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=2
#  200 OK
# 2018-01-26 11:42:45.210771
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=3
#  200 OK
# 2018-01-26 11:42:52.890903
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=4
#  200 OK
# 2018-01-26 11:42:59.901263
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=5
#  200 OK
# 2018-01-26 11:43:05.122114
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=6
#  200 OK
# 2018-01-26 11:43:10.686424
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=7
#  200 OK
# 2018-01-26 11:43:16.820451
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=8
#  200 OK
# 2018-01-26 11:43:21.341681
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=9
#  200 OK
# 2018-01-26 11:43:29.394950
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=10
#  200 OK
# 2018-01-26 11:43:35.546593
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=11
#  200 OK
# 2018-01-26 11:43:42.465201
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=12
#  200 OK
# 2018-01-26 11:43:47.754830
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=13
#  200 OK
# 2018-01-26 11:43:54.052947
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=14
#  200 OK
# 2018-01-26 11:44:00.938440
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=15
#  200 OK
# 2018-01-26 11:44:07.367009
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2010&page=16
#  200 OK
# 2018-01-26 11:44:12.208808
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=0
#  200 OK
# 2018-01-26 11:44:19.402089
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=1
#  200 OK
# 2018-01-26 11:44:26.743412
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=2
#  200 OK
# 2018-01-26 11:44:32.753719
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=3
#  200 OK
# 2018-01-26 11:44:38.456868
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=4
#  200 OK
# 2018-01-26 11:44:45.466708
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=5
#  200 OK
# 2018-01-26 11:44:51.671609
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=6
#  200 OK
# 2018-01-26 11:44:58.193623
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=7
#  200 OK
# 2018-01-26 11:45:07.472347
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=8
#  200 OK
# 2018-01-26 11:45:13.649284
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=9
#  200 OK
# 2018-01-26 11:45:18.991126
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=10
#  200 OK
# 2018-01-26 11:45:27.160564
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=11
#  200 OK
# 2018-01-26 11:45:35.432081
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=12
#  200 OK
# 2018-01-26 11:45:43.118676
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=13
#  200 OK
# 2018-01-26 11:45:48.961188
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=14
#  200 OK
# 2018-01-26 11:45:56.754320
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=15
#  200 OK
# 2018-01-26 11:46:03.960080
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=16
#  200 OK
# 2018-01-26 11:46:11.307810
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=17
#  200 OK
# 2018-01-26 11:46:17.816650
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=18
#  200 OK
# 2018-01-26 11:46:24.023305
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2011&page=19
#  200 OK
# 2018-01-26 11:46:32.144507
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=0
#  200 OK
# 2018-01-26 11:46:37.738599
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=1
#  200 OK
# 2018-01-26 11:46:45.725513
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=2
#  200 OK
# 2018-01-26 11:46:52.831440
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=3
#  200 OK
# 2018-01-26 11:46:59.530606
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=4
#  200 OK
# 2018-01-26 11:47:07.299739
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=5
#  200 OK
# 2018-01-26 11:47:15.309808
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=6
#  200 OK
# 2018-01-26 11:47:22.052302
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=7
#  200 OK
# 2018-01-26 11:47:28.579449
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=8
#  200 OK
# 2018-01-26 11:47:35.165838
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=9
#  200 OK
# 2018-01-26 11:47:40.932721
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=10
#  200 OK
# 2018-01-26 11:47:47.678375
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=11
#  200 OK
# 2018-01-26 11:47:54.608215
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=12
#  200 OK
# 2018-01-26 11:47:59.693817
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=13
#  200 OK
# 2018-01-26 11:48:04.673634
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=14
#  200 OK
# 2018-01-26 11:48:13.377935
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=15
#  200 OK
# 2018-01-26 11:48:20.132712
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=16
#  200 OK
# 2018-01-26 11:48:27.403595
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=17
#  200 OK
# 2018-01-26 11:48:34.595387
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=18
#  200 OK
# 2018-01-26 11:48:42.233403
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=19
#  200 OK
# 2018-01-26 11:48:48.397599
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=20
#  200 OK
# 2018-01-26 11:48:55.073154
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2012&page=21
#  200 OK
# 2018-01-26 11:49:02.199120
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=0
#  200 OK
# 2018-01-26 11:49:07.024255
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=1
#  200 OK
# 2018-01-26 11:49:14.168836
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=2
#  200 OK
# 2018-01-26 11:49:18.926459
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=3
#  200 OK
# 2018-01-26 11:49:24.592514
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=4
#  200 OK
# 2018-01-26 11:49:31.821722
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=5
#  200 OK
# 2018-01-26 11:49:37.325321
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=6
#  200 OK
# 2018-01-26 11:49:44.345922
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=7
#  200 OK
# 2018-01-26 11:49:52.000868
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=8
#  200 OK
# 2018-01-26 11:49:57.237407
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=9
#  200 OK
# 2018-01-26 11:50:03.768955
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=10
#  200 OK
# 2018-01-26 11:50:08.688372
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=11
#  200 OK
# 2018-01-26 11:50:16.584491
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=12
#  200 OK
# 2018-01-26 11:50:23.273816
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=13
#  200 OK
# 2018-01-26 11:50:29.776641
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=14
#  200 OK
# 2018-01-26 11:50:37.219695
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=15
#  200 OK
# 2018-01-26 11:50:44.151007
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=16
#  200 OK
# 2018-01-26 11:50:51.842793
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=17
#  200 OK
# 2018-01-26 11:50:59.322806
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=18
#  200 OK
# 2018-01-26 11:51:05.656245
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=19
#  200 OK
# 2018-01-26 11:51:11.641156
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=20
#  200 OK
# 2018-01-26 11:51:19.718923
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2013&page=21
#  200 OK
# 2018-01-26 11:51:25.555824
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=0
#  200 OK
# 2018-01-26 11:51:33.284079
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=1
#  200 OK
# 2018-01-26 11:51:40.430236
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=2
#  200 OK
# 2018-01-26 11:51:46.425142
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=3
#  200 OK
# 2018-01-26 11:51:54.671870
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=4
#  200 OK
# 2018-01-26 11:52:00.486699
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=5
#  200 OK
# 2018-01-26 11:55:47.668203
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=6
#  200 OK
# 2018-01-26 11:55:55.018780
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=7
#  200 OK
# 2018-01-26 11:56:02.042881
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=8
#  200 OK
# 2018-01-26 11:56:11.093283
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=9
#  200 OK
# 2018-01-26 11:56:16.907743
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=10
#  200 OK
# 2018-01-26 11:56:24.713306
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=11
#  200 OK
# 2018-01-26 11:56:30.852410
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=12
#  200 OK
# 2018-01-26 11:56:37.817303
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=13
#  200 OK
# 2018-01-26 11:56:44.683545
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=14
#  200 OK
# 2018-01-26 11:56:52.273107
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=15
#  200 OK
# 2018-01-26 11:57:00.483087
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=16
#  200 OK
# 2018-01-26 11:57:06.646290
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=17
#  200 OK
# 2018-01-26 11:57:13.087538
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=18
#  200 OK
# 2018-01-26 11:57:18.057989
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=19
#  200 OK
# 2018-01-26 11:57:25.136554
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=20
#  200 OK
# 2018-01-26 11:57:31.906905
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2014&page=21
#  200 OK
# 2018-01-26 11:57:38.714409
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=0
#  200 OK
# 2018-01-26 11:57:45.992813
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=1
#  200 OK
# 2018-01-26 11:57:51.644146
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=2
#  200 OK
# 2018-01-26 11:57:57.873421
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=3
#  200 OK
# 2018-01-26 11:58:04.632879
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=4
#  200 OK
# 2018-01-26 11:58:10.509477
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=5
#  200 OK
# 2018-01-26 11:58:15.567689
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=6
#  200 OK
# 2018-01-26 11:58:22.668297
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=7
#  200 OK
# 2018-01-26 11:58:27.954119
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=8
#  200 OK
# 2018-01-26 11:58:33.028920
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=9
#  200 OK
# 2018-01-26 11:58:38.414110
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=10
#  200 OK
# 2018-01-26 11:58:47.598424
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=11
#  200 OK
# 2018-01-26 11:58:54.830615
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=12
#  200 OK
# 2018-01-26 11:59:02.280716
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=13
#  200 OK
# 2018-01-26 11:59:08.041326
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=14
#  200 OK
# 2018-01-26 11:59:12.800270
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=15
#  200 OK
# 2018-01-26 11:59:19.606578
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=16
#  200 OK
# 2018-01-26 11:59:24.325757
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=17
#  200 OK
# 2018-01-26 11:59:30.925133
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=18
#  200 OK
# 2018-01-26 11:59:37.800565
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=19
#  200 OK
# 2018-01-26 11:59:45.337775
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=20
#  200 OK
# 2018-01-26 11:59:51.645623
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2015&page=21
#  200 OK
# 2018-01-26 11:59:58.808417
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=0
#  200 OK
# 2018-01-26 12:00:05.764140
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=1
#  200 OK
# 2018-01-26 12:00:11.468439
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=2
#  200 OK
# 2018-01-26 12:00:17.152076
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=3
#  200 OK
# 2018-01-26 12:00:25.410292
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=4
#  200 OK
# 2018-01-26 12:00:33.849077
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=5
#  200 OK
# 2018-01-26 12:00:41.251516
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=6
#  200 OK
# 2018-01-26 12:00:48.693830
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=7
#  200 OK
# 2018-01-26 12:00:59.673871
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=8
#  200 OK
# 2018-01-26 12:01:08.793575
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=9
#  200 OK
# 2018-01-26 12:01:16.730003
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=10
#  200 OK
# 2018-01-26 12:01:23.991835
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=11
#  200 OK
# 2018-01-26 12:01:30.935718
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=12
#  200 OK
# 2018-01-26 12:01:37.504936
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=13
#  200 OK
# 2018-01-26 12:01:45.189847
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=14
#  200 OK
# 2018-01-26 12:01:50.411194
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=15
#  200 OK
# 2018-01-26 12:01:58.619042
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=16
#  200 OK
# 2018-01-26 12:02:05.651107
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=17
#  200 OK
# 2018-01-26 12:02:11.929880
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=18
#  200 OK
# 2018-01-26 12:02:19.810566
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=19
#  200 OK
# 2018-01-26 12:02:24.920296
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=20
#  200 OK
# 2018-01-26 12:02:32.341371
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2016&page=21
#  200 OK
# 2018-01-26 12:02:38.994035
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=0
#  200 OK
# 2018-01-26 12:02:45.066077
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=1
#  200 OK
# 2018-01-26 12:02:51.640006
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=2
#  200 OK
# 2018-01-26 12:02:57.294120
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=3
#  200 OK
# 2018-01-26 12:03:06.010883
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=4
#  200 OK
# 2018-01-26 12:03:14.525156
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=5
#  200 OK
# 2018-01-26 12:03:23.259942
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=6
#  200 OK
# 2018-01-26 12:03:29.259669
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=7
#  200 OK
# 2018-01-26 12:03:33.313300
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=8
#  200 OK
# 2018-01-26 12:03:39.591772
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=9
#  200 OK
# 2018-01-26 12:03:51.136616
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=10
#  200 OK
# 2018-01-26 12:03:56.233455
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=11
#  200 OK
# 2018-01-26 12:04:02.360580
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=12
#  200 OK
# 2018-01-26 12:04:09.987184
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=13
#  200 OK
# 2018-01-26 12:04:15.340131
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=14
#  200 OK
# 2018-01-26 12:04:21.877565
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=15
#  200 OK
# 2018-01-26 12:04:27.996610
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=16
#  200 OK
# 2018-01-26 12:04:35.284266
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=17
#  200 OK
# 2018-01-26 12:04:41.847863
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=18
#  200 OK
# 2018-01-26 12:04:48.211219
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=19
#  200 OK
# 2018-01-26 12:04:55.011370
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=20
#  200 OK
# 2018-01-26 12:05:02.654171
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=21
#  200 OK
# 2018-01-26 12:05:08.889176
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=22
#  200 OK
# 2018-01-26 12:05:14.150530
# https://www.mlssoccer.com/stats/season?franchise=select&group=shots&season_type=REG&year=2017&page=23
#  200 OK
# 2018-01-26 12:05:21.209311

# %%
shots_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5041 entries, 0 to 5040
# Data columns (total 15 columns):
# Player    5041 non-null object
# Club      5037 non-null object
# POS       5041 non-null object
# GP        5037 non-null object
# GS        5037 non-null object
# MINS      5037 non-null object
# G         5037 non-null object
# A         5037 non-null object
# SHTS      5037 non-null object
# SOG       5037 non-null object
# PKG/A     5041 non-null object
# SC%       5041 non-null object
# SOG%      5041 non-null object
# Year      5041 non-null int64
# Season    5041 non-null object
# dtypes: int64(1), object(14)
# memory usage: 590.8+ KB

# %%
shots_df
# Out:
#                           Player Club  POS  GP  GS  MINS  G   A SHTS SOG  \
# 0                 Yura Movsisyan  RSL    F  23   9   993  5   0   42  13
# 1               Carlos Marinelli  KC     M  26  19  1674  1   5   42  21
# 2                     Pat Noonan  NE     F  27  21  1736  7   4   42  24
# 3                 Shalrie Joseph  NE     M  27  27  2366  4   5   42  14
# 4                  Collin Samuel  TOR    F  18  18  1510  3   0   41  24
# 5                  Adam Cristman  NE     F  28  14  1421  4   4   40  16
# 6                 Sacha Kljestan  OCS    M  25  25  2186  4  13   40  21
# 7                 Joseph Ngwenya  CLB    F  30  30  2362  7   4   40  23
# 8                    Chris Klein  LA     M  32  32  2880  2   4   40  16
# 9     Guillermo Barros Schelotto  CLB    F  22  19  1605  5  11   39  18
# 10                   Chris Rolfe  CHI    F  19  18  1451  6   3   38  19
# 11                  Ned Grabavoy  CLB    M  26  24  2093  3   3   37  17
# 12               Sasha Victorine  KC     M  29  24  2135  2   7   37  13
# 13                Jovan Kirovski  COL  M-F  28  28  2161  6   1   36  14
# 14                   Khano Smith  NE     M  29  26  2210  2   6   36  12
# 15            Dave van den Bergh  NY     M  29  26  2228  2   8   36  19
# 16             Francisco Mendoza  CHV    M  28  27  2459  2   4   36  16
# 17               Mehdi Ballouchy  COL    M  23  22  1853  1   2   35  10
# 18                  Jaime Moreno  DC     F  21  15  1439  7   6   34  18
# 19                  Kenny Cooper  DAL    F  14  12  1068  4   2   33  16
# 20                    Calen Carr  CHI    F  27  10  1134  3   2   33  13
# 21                   Scott Sealy  KC     F  18  15  1193  7   2   33  20
# 22                 Steve Ralston  NE     M  26  26  2337  4  14   33  18
# 23                     Juan Toja  DAL    M  27  27  2388  6   1   33  16
# 24               Jeff Cunningham  RSL    F  23  20  1636  6   1   32  21
# 25                Robbie Findley  LA     F  25  14  1353  8   0   31  16
# 26                  Carlos Pavon  LA     F  18  10   978  3   0   29  10
# 27             Nicolas Hernandez  COL    F  21  17  1474  1   1   29   7
# 28                     Ben Olsen  DC     M  24  21  1881  7   7   29  17
# 29                  Kyle Martino  LA     M  26  25  1928  3   1   29  10
# ...                          ...  ...  ...  ..  ..   ... ..  ..  ...  ..
# 5011               Mauro Rosales  VAN    M   5   0    52  0   0    0   0
# 5012              Brandt Bronico  CHI  M-F   4   0    53  0   0    0   0
# 5013               John Stertzer  NYC    M   5   0    53  0   0    0   0
# 5014                Donnie Smith   NE    M   1   1    53  0   0    0   0
# 5015                Nosa Igiebor  VAN    M   1   1    73  0   0    0   0
# 5016                Maxim Tissot   DC    D   1   1    90  0   0    0   0
# 5017                Jacori Hayes  DAL    M   3   2    90  0   0    0   0
# 5018                Ben McKendry  VAN    M   1   1    90  0   0    0   0
# 5019                Sam Hamilton  COL    M   3   1   124  0   0    0   0
# 5020           Philippe Senderos  HOU    D   2   2   162  0   0    0   0
# 5021                  Mark Bloom  ATL    D   2   2   163  0   0    0   0
# 5022            London Woodberry   NE    D   3   2   165  0   0    0   0
# 5023                 Reagan Dunk  RSL    D   3   2   174  0   0    0   0
# 5024                 Walker Hume  DAL    F   2   2   180  0   0    0   0
# 5025                Kevin Garcia  HOU    D   3   2   211  0   0    0   0
# 5026              Adrian Arregui  MTL    M   6   3   238  0   1    0   0
# 5027             Dennis Castillo  COL    D   3   3   244  0   0    0   0
# 5028               Soni Mustivar  KC     M  14   2   260  0   1    0   0
# 5029        Louis Béland-Goyette  MTL    M   6   4   293  0   1    0   0
# 5030               Hugo Arellano   LA    D   4   4   334  0   0    0   0
# 5031                 Joshua Yaro  PHI    D   6   4   369  0   0    0   0
# 5032                 Amobi Okugo  POR  D-M   8   3   396  0   0    0   0
# 5033                Marco Farfan  POR    D   6   5   403  0   0    0   0
# 5034            Chris Odoi-Atsem   DC    D   9   5   482  0   0    0   0
# 5035                Justin Davis  MIN    D   8   5   492  0   0    0   0
# 5036             Jason Hernandez  TOR    D   8   5   526  0   0    0   0
# 5037               Kevin Venegas  MIN    D   6   6   540  0   0    0   0
# 5038           Erik Palmer-Brown  KC     D  10   7   641  0   0    0   0
# 5039          Michael Harrington  CHI    D   9   9   798  0   0    0   0
# 5040                  Marc Burch  MIN    D  18  17  1502  0   1    0   0
#
#      PKG/A   SC%  SOG%  Year Season
# 0      0/0  11.9  31.0  2007    REG
# 1      1/2   2.4  50.0  2007    REG
# 2      0/0  16.7  57.1  2007    REG
# 3      3/4   9.5  33.3  2007    REG
# 4      1/1   7.3  58.5  2007    REG
# 5      0/0  10.0  40.0  2007    REG
# 6      1/1  10.0  52.5  2007    REG
# 7      0/0  17.5  57.5  2007    REG
# 8      0/0   5.0  40.0  2007    REG
# 9      1/1  12.8  46.2  2007    REG
# 10     1/1  15.8  50.0  2007    REG
# 11     0/1   8.1  45.9  2007    REG
# 12     0/0   5.4  35.1  2007    REG
# 13     4/4  16.7  38.9  2007    REG
# 14     0/0   5.6  33.3  2007    REG
# 15     0/0   5.6  52.8  2007    REG
# 16     0/0   5.6  44.4  2007    REG
# 17     0/0   2.9  28.6  2007    REG
# 18     4/4  20.6  52.9  2007    REG
# 19     1/1  12.1  48.5  2007    REG
# 20     0/0   9.1  39.4  2007    REG
# 21     0/0  21.2  60.6  2007    REG
# 22     0/0  12.1  54.5  2007    REG
# 23     0/0  18.2  48.5  2007    REG
# 24     1/1  18.8  65.6  2007    REG
# 25     0/0  25.8  51.6  2007    REG
# 26     0/0  10.3  34.5  2007    REG
# 27     0/0   3.4  24.1  2007    REG
# 28     0/0  24.1  58.6  2007    REG
# 29     0/1  10.3  34.5  2007    REG
# ...    ...   ...   ...   ...    ...
# 5011   0/0   0.0   0.0  2017    REG
# 5012   0/0   0.0   0.0  2017    REG
# 5013   0/0   0.0   0.0  2017    REG
# 5014   0/0   0.0   0.0  2017    REG
# 5015   0/0   0.0   0.0  2017    REG
# 5016   0/0   0.0   0.0  2017    REG
# 5017   0/0   0.0   0.0  2017    REG
# 5018   0/0   0.0   0.0  2017    REG
# 5019   0/0   0.0   0.0  2017    REG
# 5020   0/0   0.0   0.0  2017    REG
# 5021   0/0   0.0   0.0  2017    REG
# 5022   0/0   0.0   0.0  2017    REG
# 5023   0/0   0.0   0.0  2017    REG
# 5024   0/0   0.0   0.0  2017    REG
# 5025   0/0   0.0   0.0  2017    REG
# 5026   0/0   0.0   0.0  2017    REG
# 5027   0/0   0.0   0.0  2017    REG
# 5028   0/0   0.0   0.0  2017    REG
# 5029   0/0   0.0   0.0  2017    REG
# 5030   0/0   0.0   0.0  2017    REG
# 5031   0/0   0.0   0.0  2017    REG
# 5032   0/0   0.0   0.0  2017    REG
# 5033   0/0   0.0   0.0  2017    REG
# 5034   0/0   0.0   0.0  2017    REG
# 5035   0/0   0.0   0.0  2017    REG
# 5036   0/0   0.0   0.0  2017    REG
# 5037   0/0   0.0   0.0  2017    REG
# 5038   0/0   0.0   0.0  2017    REG
# 5039   0/0   0.0   0.0  2017    REG
# 5040   0/0   0.0   0.0  2017    REG
#
# [5041 rows x 15 columns]

# %%
shots_df.to_pickle('shots_df.pickle')

# %% [markdown]
# ### Sandbox
