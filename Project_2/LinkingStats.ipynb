# %% [markdown]
# ## Linking Stat Data

# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime 
from dateutil import parser
import os
import time
import itertools
import re
import pickle
import locale

# %% [markdown]
# ### Stats Data

# %%
goals_df = pickle.load(open('./data/goals_df.pkl', 'rb'))
assists_df = pickle.load(open('./data/assists_df.pkl', 'rb'))
shots_df = pickle.load(open('./data/shots_df.pkl', 'rb'))
fouls_df = pickle.load(open('./data/fouls_df.pkl', 'rb'))
goalkeeping_df = pickle.load(open('./data/goalkeeping_df.pkl', 'rb'))

# %% [markdown]
# #### Merge Field Player Stats

# %%
def merge_stats(df1, df2):
    cols = list(set(df1.columns).intersection(df2.columns))
    merged_df = pd.merge(df1, df2, how='outer', left_on=cols, right_on=cols, suffixes=['', '_Dup'])
    return merged_df

# %%
fp_df = merge_stats(goals_df, assists_df)
fp_df = merge_stats(fp_df, shots_df)
fp_df = merge_stats(fp_df, fouls_df)

# %% [markdown]
# #### Clean Field Player Stats

# %%
# Replace null values with 0
fp_df = fp_df.replace(np.nan, '0')

# %%
# Split PKG/A column into to and drop
fp_df[['PKG', 'PKA']] = fp_df['PKG/A'].str.split('/', expand=True)
fp_df.drop('PKG/A', axis=1, inplace=True)
fp_df = fp_df.replace('', '0')

# %% [markdown]
# ##### Set Column Dtypes

# %%
int_cols = ['GP', 'GS', 'MINS', 'G', 'A', 'SHTS', 'SOG', 'GWG', 
            'HmG', 'RdG', 'Year', 'GWA', 'HmA', 'RdA', 'FC', 'FS', 
            'OFF', 'YC', 'RC', 'PKG', 'PKA']
for col in int_cols:
    fp_df[col] = fp_df[col].astype(int)

# %%
float_cols = ['G/90min', 'SC%', 'A/90min', 'SOG%']
for col in float_cols:
    fp_df[col] = fp_df[col].astype(float)

# %%
fp_df.rename(columns={'G/90min': 'Gp90', 
                      'SC%': 'SCpct', 
                      'A/90min': 'Ap90', 
                      'SOG%': 'SOGpct'}, inplace=True)

# %%
fieldplayer_df.to_csv('fieldplayer.csv')

# %% [markdown]
# #### Merge Field Player Stats with Goalkeeping Stats

# %%
stats_df = merge_stats(fieldplayer_df, goalkeeping_df)

# %%
stats_df.to_csv('stats.csv')

# %% [markdown]
# ### Salary Data

# %%
salary_df = pickle.load(open('./data/salary_df.pkl', 'rb'))

# %% [markdown]
# #### Clean Salary Dataframe

# %%
# Create Player column for linking
salary_df['Last Name'] = salary_df['Last Name'].str.strip()
salary_df['First Name'] = salary_df['First Name'].str.strip()
salary_df['Player'] = salary_df['First Name'] + ' ' + salary_df['Last Name']

# Rename Pos to POS for linking
salary_df.rename(columns={'Pos': 'POS'}, inplace=True)

# Create Year Column
salary_df['Year'] = salary_df.Date.map(lambda x: x.year)

# %%
# Convert numeric str to float
def convert_money(money_str):
    money_str = money_str.strip()
    # replace empty str with 0
    if len(money_str) == 0:
        money_str = re.sub('', '0', money_str)
    return float(re.sub('[\$,]', '', re.sub('-', '0', money_str)))

# %%
# Convert Salary Columns
salary_df['Base Salary'] = salary_df['Base Salary'].map(lambda x: convert_money(x))
salary_df['Guaranteed Compensation'] = salary_df['Guaranteed Compensation'].map(lambda x: convert_money(x))

# %%
# salary_df = salary_df.replace('', 0)
# salary_df = salary_df.replace('-', 0)
# salary_df['Base Salary'] = salary_df['Base Salary'].replace('[\$,]', '', regex=True).astype(float)
# salary_df['Guaranteed Compensation'] = salary_df['Guaranteed Compensation'].replace('[\$,]', '', regex=True).astype(float)

# %%
def subset_latest(salary_df):
    new_df = pd.DataFrame()
    for year in np.unique(salary_df['Year']):
        max_date = max(salary_df[salary_df['Year'] == year]['Date'])
        subset_df = salary_df[salary_df['Date'] == max_date]
        new_df = pd.concat([new_df, subset_df], axis=0, ignore_index=True)
    return new_df

# %%
salary_df = subset_latest(salary_df)

# %% [markdown]
# ### Merge Stats with Salary Data

# %%
cols = ['Year', 'Player']
df = pd.merge(merged_df, salary_df, how='outer', left_on=cols, right_on=cols, suffixes=['', '_Dup'])

# %%
df
# Out:
#                           Player Club  POS   GP   GS  MINS    G    A SHTS  \
# 0                 Luciano Emilio  DC     F   29   28  2410   20    1   79
# 1               Juan Pablo Angel  NY     F   24   24  2125   19    5   97
# 2                Taylor Twellman  NE     F   26   25  2283   16    3   90
# 3                  Eddie Johnson  KC     F   24   24  2149   15    6   75
# 4                 Maykel Galindo  CHV    F   28   24  2021   12    5   55
# 5                     Ante Razov  CHV    F   26   24  2041   11    8   85
# 6                Christian Gomez  DC     M   27   27  2272   10    9   82
# 7                  Jozy Altidore  TOR    F   22   15  1399    9    4   43
# 8                 Landon Donovan  LA   M-F   25   24  2191    8   13   44
# 9                 Robbie Findley  LA     F   25   14  1353    8    0   31
# 10                          Fred  DC     M   26   23  2096    7    8   28
# 11                     Ben Olsen  DC     M   24   21  1881    7    7   29
# 12              Alejandro Moreno  CLB    F   29   27  2357    7    7   54
# 13                  Jaime Moreno  DC     F   21   15  1439    7    6   34
# 14                Joseph Ngwenya  CLB    F   30   30  2362    7    4   40
# 15                    Pat Noonan  NE     F   27   21  1736    7    4   42
# 16                   Scott Sealy  KC     F   18   15  1193    7    2   33
# 17                   Brian Ching  HOU    F   20   17  1590    7    2   48
# 18                   Andy Dorman  NE     M   30   27  2269    7    2   48
# 19                    Nate Jaqua  HOU    F   25   19  1772    7    2   49
# 20                  Chad Barrett  CHI    F   30   25  1983    7    2   59
# 21                   Carlos Ruiz  DAL    F   22   19  1721    7    2   59
# 22             Dwayne De Rosario  HOU    M   24   22  1973    6    4   62
# 23                   Chris Rolfe  CHI    F   19   18  1451    6    3   38
# 24                  Clint Mathis  NY     M   26   19  1722    6    2   47
# 25                  Danny Dichio  TOR    F   17   14  1175    6    1   20
# 26               Jeff Cunningham  RSL    F   23   20  1636    6    1   32
# 27                     Juan Toja  DAL    M   27   27  2388    6    1   33
# 28                Jovan Kirovski  COL  M-F   28   28  2161    6    1   36
# 29    Guillermo Barros Schelotto  CLB    F   22   19  1605    5   11   39
# ...                          ...  ...  ...  ...  ...   ...  ...  ...  ...
# 6608                Matt Bersano  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6609                   Mark Pais  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6610              Spencer Richey  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6611            Romario Williams  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6612                 Calle Brown  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6613                Joshua Smith  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6614                Earl Edwards  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6615             Richard Sanchez  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6616             Anthony Fontana  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6617             Derrick Etienne  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6618              Eric Klenofsky  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6619        Louis Beland Goyette  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6620                 Matt Turner  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6621            Stefan Cleveland  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6622              Logan Ketterer  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6623              Joseph Holland  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6624          Monday Bassey Etim  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6625          Thomas De Villardi  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6626                   Alex Kapp  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6627                  Evan Louro  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6628                Hassan N'dam  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6629               Devron Garcia  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6630                Jake McGuire  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6631               Billy Heavner  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6632              Connor Sparrow  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6633                Deybi Flores  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6634        Jeffrey Oblitey Otoo  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6635             Adrian Zendejas  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6636             Mason Stajduhar  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 6637            Kendall McIntosh  NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
#
#       SOG     ...      OFF   YC   RC Club_Dup       Last Name  \
# 0      47     ...       21    2    0       DC          Emilio
# 1      53     ...       42    2    1       NY           Angel
# 2      55     ...       21    2    0       NE        Twellman
# 3      43     ...       50    6    0       KC         Johnson
# 4      28     ...       30    6    0      CHV         Galindo
# 5      42     ...       30    2    0      CHV           Razov
# 6      44     ...       10    6    0      NaN             NaN
# 7      20     ...       12    4    0      NaN             NaN
# 8      20     ...       11    3    0       LA         Donovan
# 9      16     ...       14    0    0      NaN             NaN
# 10     14     ...       21    5    1      NaN             NaN
# 11     17     ...       11    8    0       DC           Olsen
# 12     32     ...       32    3    0      CLB          Moreno
# 13     18     ...       15    3    0       DC          Moreno
# 14     23     ...       55    4    0      HOU         Ngwenya
# 15     24     ...       32    2    0       NE          Noonan
# 16     20     ...       23    1    0       KC           Sealy
# 17     18     ...       15    1    0      HOU           Ching
# 18     27     ...        4    5    0       NE          Dorman
# 19     19     ...        8    6    0      HOU           Jaqua
# 20     37     ...       37    3    0      CHI         Barrett
# 21     25     ...       23    9    1      DAL            Ruiz
# 22     24     ...       19    5    0      NaN             NaN
# 23     19     ...        4    1    0      CHI           Rolfe
# 24     22     ...        5    2    2       NY          Mathis
# 25     13     ...        6    3    1      NaN             NaN
# 26     21     ...       33    3    0      NaN             NaN
# 27     16     ...        6    4    0      NaN             NaN
# 28     14     ...       16    3    0      COL        Kirovski
# 29     18     ...       20    5    0      CLB       Schelotto
# ...   ...     ...      ...  ...  ...      ...             ...
# 6608  NaN     ...      NaN  NaN  NaN       SJ         Bersano
# 6609  NaN     ...      NaN  NaN  NaN      TOR            Pais
# 6610  NaN     ...      NaN  NaN  NaN      VAN          Richey
# 6611  NaN     ...      NaN  NaN  NaN      ATL        Williams
# 6612  NaN     ...      NaN  NaN  NaN      HOU           Brown
# 6613  NaN     ...      NaN  NaN  NaN       NE           Smith
# 6614  NaN     ...      NaN  NaN  NaN      ORL         Edwards
# 6615  NaN     ...      NaN  NaN  NaN      CHI         Sanchez
# 6616  NaN     ...      NaN  NaN  NaN      PHI         Fontana
# 6617  NaN     ...      NaN  NaN  NaN     NYRB         Etienne
# 6618  NaN     ...      NaN  NaN  NaN       DC       Klenofsky
# 6619  NaN     ...      NaN  NaN  NaN      MTL  Beland Goyette
# 6620  NaN     ...      NaN  NaN  NaN       NE          Turner
# 6621  NaN     ...      NaN  NaN  NaN      CHI       Cleveland
# 6622  NaN     ...      NaN  NaN  NaN      CLB        Ketterer
# 6623  NaN     ...      NaN  NaN  NaN      HOU         Holland
# 6624  NaN     ...      NaN  NaN  NaN     LAFC            Etim
# 6625  NaN     ...      NaN  NaN  NaN    MNUFC     De Villardi
# 6626  NaN     ...      NaN  NaN  NaN    MNUFC            Kapp
# 6627  NaN     ...      NaN  NaN  NaN     NYRB           Louro
# 6628  NaN     ...      NaN  NaN  NaN     NYRB           N'dam
# 6629  NaN     ...      NaN  NaN  NaN      ORL          Garcia
# 6630  NaN     ...      NaN  NaN  NaN      PHI         McGuire
# 6631  NaN     ...      NaN  NaN  NaN     POOL         Heavner
# 6632  NaN     ...      NaN  NaN  NaN      RSL         Sparrow
# 6633  NaN     ...      NaN  NaN  NaN      VAN          Flores
# 6634  NaN     ...      NaN  NaN  NaN      ATL    Oblitey Otoo
# 6635  NaN     ...      NaN  NaN  NaN       KC        Zendejas
# 6636  NaN     ...      NaN  NaN  NaN      ORL       Stajduhar
# 6637  NaN     ...      NaN  NaN  NaN      POR        McIntosh
#
#             First Name  POS_Dup Base Salary Guaranteed Compensation  \
# 0              Luciano        F   265000.00               293125.00
# 1           Juan Pablo        F  1500000.00              1593750.00
# 2               Taylor        F   325008.00               350008.00
# 3                Eddie        F   750000.00               875000.00
# 4               Maykel        F    72500.00                72500.00
# 5                 Ante        F   245000.00               248750.00
# 6                  NaN      NaN         NaN                     NaN
# 7                  NaN      NaN         NaN                     NaN
# 8               Landon        F   900000.00               900000.00
# 9                  NaN      NaN         NaN                     NaN
# 10                 NaN      NaN         NaN                     NaN
# 11                 Ben        M   155000.00               177500.00
# 12           Alejandro        F   120000.00               125000.00
# 13               Jaime        F   250000.00               275000.00
# 14              Joseph        F    51148.13                62023.13
# 15                 Pat        F   225000.00               227500.00
# 16               Scott        F    33075.00                33075.00
# 17               Brian        F   220000.00               220000.00
# 18                Andy        M    30870.00                30870.00
# 19                Nate        F   112500.00               119525.00
# 20                Chad        F    41212.50                48712.50
# 21              Carlos        F   325000.00               435000.00
# 22                 NaN      NaN         NaN                     NaN
# 23               Chris        F    70000.00                74700.00
# 24               Clint      M-F   270000.00               410000.00
# 25                 NaN      NaN         NaN                     NaN
# 26                 NaN      NaN         NaN                     NaN
# 27                 NaN      NaN         NaN                     NaN
# 28               Jovan        F   200000.00               200000.00
# 29    Guillermo Barros        F   150000.00               150000.00
# ...                ...      ...         ...                     ...
# 6608              Matt       GK    65004.00                65004.00
# 6609              Mark       GK    65004.00                65004.00
# 6610           Spencer       GK    65004.00                65004.00
# 6611           Romario        F    65000.00                65000.00
# 6612             Calle       GK    65000.00                65000.00
# 6613            Joshua        D    65000.00                65000.00
# 6614              Earl       GK    65000.00                65000.00
# 6615           Richard        M    64999.92                64999.92
# 6616           Anthony        M    53004.00                61421.60
# 6617           Derrick        M    53000.00                58000.00
# 6618              Eric       GK    53004.00                56754.00
# 6619             Louis        M    53000.00                54250.00
# 6620              Matt       GK    54075.00                54075.00
# 6621            Stefan       GK    53004.00                53004.00
# 6622             Logan       GK    53004.00                53004.00
# 6623            Joseph        M    53004.00                53004.00
# 6624     Monday Bassey        M    53004.00                53004.00
# 6625            Thomas        D    53004.00                53004.00
# 6626              Alex       GK    53004.00                53004.00
# 6627              Evan       GK    53004.00                53004.00
# 6628            Hassan        D    53004.00                53004.00
# 6629            Devron      M-F    53004.00                53004.00
# 6630              Jake       GK    53004.00                53004.00
# 6631             Billy       GK    53004.00                53004.00
# 6632            Connor       GK    53004.00                53004.00
# 6633             Deybi        M    53000.04                53000.04
# 6634           Jeffrey      M-F    53000.00                53000.00
# 6635            Adrian       GK    53000.00                53000.00
# 6636             Mason       GK    53000.00                53000.00
# 6637           Kendall       GK    53000.00                53000.00
#
#             Date
# 0     2007-08-31
# 1     2007-08-31
# 2     2007-08-31
# 3     2007-08-31
# 4     2007-08-31
# 5     2007-08-31
# 6            NaN
# 7            NaN
# 8     2007-08-31
# 9            NaN
# 10           NaN
# 11    2007-08-31
# 12    2007-08-31
# 13    2007-08-31
# 14    2007-08-31
# 15    2007-08-31
# 16    2007-08-31
# 17    2007-08-31
# 18    2007-08-31
# 19    2007-08-31
# 20    2007-08-31
# 21    2007-08-31
# 22           NaN
# 23    2007-08-31
# 24    2007-08-31
# 25           NaN
# 26           NaN
# 27           NaN
# 28    2007-08-31
# 29    2007-08-31
# ...          ...
# 6608  2017-09-15
# 6609  2017-09-15
# 6610  2017-09-15
# 6611  2017-09-15
# 6612  2017-09-15
# 6613  2017-09-15
# 6614  2017-09-15
# 6615  2017-09-15
# 6616  2017-09-15
# 6617  2017-09-15
# 6618  2017-09-15
# 6619  2017-09-15
# 6620  2017-09-15
# 6621  2017-09-15
# 6622  2017-09-15
# 6623  2017-09-15
# 6624  2017-09-15
# 6625  2017-09-15
# 6626  2017-09-15
# 6627  2017-09-15
# 6628  2017-09-15
# 6629  2017-09-15
# 6630  2017-09-15
# 6631  2017-09-15
# 6632  2017-09-15
# 6633  2017-09-15
# 6634  2017-09-15
# 6635  2017-09-15
# 6636  2017-09-15
# 6637  2017-09-15
#
# [6638 rows x 35 columns]

# %%
df.to_csv('field_player.csv')

# %% [markdown]
# #### Fix Player Name Association

# %%
import fuzzywuzzy as fwuzz

# %%
fwuzz.fuzz.ratio('Testing FuzzyWuzzy', 'Testing FuzzyWuzzy')
# Out:
# 100

# %%
str1 = 'Fred da Silva Carreiro'
str2 = 'Fred Carreiro da Silva'
str3 = 'Fred Carreiro'
str4 = 'Fred'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6638 entries, 0 to 6637
# Data columns (total 35 columns):
# Player                     6638 non-null object
# Club                       5312 non-null object
# POS                        5316 non-null object
# GP                         5312 non-null object
# GS                         5312 non-null object
# MINS                       5312 non-null object
# G                          5312 non-null object
# A                          5312 non-null object
# SHTS                       5312 non-null object
# SOG                        5312 non-null object
# GWG                        5312 non-null object
# PKG/A                      5316 non-null object
# HmG                        5312 non-null object
# RdG                        5312 non-null object
# G/90min                    5316 non-null object
# SC%                        5316 non-null object
# Year                       6638 non-null int64
# Season                     5316 non-null object
# GWA                        5312 non-null object
# HmA                        5312 non-null object
# RdA                        5312 non-null object
# A/90min                    5316 non-null object
# SOG%                       5316 non-null object
# FC                         5312 non-null object
# FS                         5312 non-null object
# OFF                        5312 non-null object
# YC                         5312 non-null object
# RC                         5312 non-null object
# Club_Dup                   5623 non-null object
# Last Name                  5623 non-null object
# First Name                 5623 non-null object
# POS_Dup                    5623 non-null object
# Base Salary                5623 non-null object
# Guaranteed Compensation    5623 non-null object
# Date                       5623 non-null object
# dtypes: int64(1), object(34)
# memory usage: 1.8+ MB

# %%
print(fwuzz.fuzz.ratio(str1, str2))
print(fwuzz.fuzz.ratio(str1, str3))
print(fwuzz.fuzz.ratio(str2, str3))
# Out:
# 59
# 74
# 74

# %%
print(fwuzz.fuzz.partial_ratio(str1, str2))
print(fwuzz.fuzz.partial_ratio(str1, str3))
print(fwuzz.fuzz.partial_ratio(str2, str3))
# Out:
# 59
# 69
# 100

# %%
print(fwuzz.fuzz.token_set_ratio(str1, str2))
print(fwuzz.fuzz.token_set_ratio(str1, str3))
print(fwuzz.fuzz.token_set_ratio(str2, str3))
# Out:
# 100
# 100
# 100
