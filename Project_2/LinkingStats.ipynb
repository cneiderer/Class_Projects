# %% [markdown]
# # Linking and Cleaning Data

# %% [markdown]
# ## Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime 
from dateutil import parser
import os
import time
import itertools
import re
import pickle
import locale
from fuzzywuzzy import fuzz

# %% [markdown]
# ## Process Stats Data

# %% [markdown]
# ### Load Data

# %%
goals_df = pickle.load(open('./data/goals_df.pkl', 'rb'))
assists_df = pickle.load(open('./data/assists_df.pkl', 'rb'))
shots_df = pickle.load(open('./data/shots_df.pkl', 'rb'))
fouls_df = pickle.load(open('./data/fouls_df.pkl', 'rb'))
gk_df = pickle.load(open('./data/goalkeeping_df.pkl', 'rb'))

# %% [markdown]
# ### Merge Field Player Stats

# %%
def merge_stats(df1, df2):
    cols = list(set(df1.columns).intersection(df2.columns))
    merged_df = pd.merge(df1, df2, how='outer', left_on=cols, right_on=cols, suffixes=['', '_Dup'])
    return merged_df

# %%
fp_df = merge_stats(goals_df, assists_df)
fp_df = merge_stats(fp_df, shots_df)
fp_df = merge_stats(fp_df, fouls_df)

# %% [markdown]
# ### Clean Field Player Stats

# %%
# Replace null values with 0
fp_df = fp_df.replace(np.nan, '0')

# %%
# Split PKG/A column into to and drop
fp_df[['PKG', 'PKA']] = fp_df['PKG/A'].str.split('/', expand=True)
fp_df.drop('PKG/A', axis=1, inplace=True)
fp_df = fp_df.replace('', '0')

# %%
# Split Player into Last Name and First Name columns
first_name = []
last_name = []
for item in fp_df['Player'].str.split(' '):
    first_name.append(item[0])
    last_name.append(' '.join(item[1:]))
fp_df['Last Name'] = last_name    
fp_df['First Name'] = first_name

# %% [markdown]
# #### Set Column Dtypes

# %%
int_cols = ['GP', 'GS', 'MINS', 'G', 'A', 'SHTS', 'SOG', 'GWG', 
            'HmG', 'RdG', 'Year', 'GWA', 'HmA', 'RdA', 'FC', 'FS', 
            'OFF', 'YC', 'RC', 'PKG', 'PKA']
for col in int_cols:
    fp_df[col] = fp_df[col].astype(int)

# %%
float_cols = ['G/90min', 'SC%', 'A/90min', 'SOG%']
for col in float_cols:
    fp_df[col] = fp_df[col].astype(float)

# %%
fp_df.rename(columns={'G/90min': 'Gp90', 
                      'SC%': 'SCpct', 
                      'A/90min': 'Ap90', 
                      'SOG%': 'SOGpct'}, inplace=True)

# %% [markdown]
# #### Strip Whitespace

# %%
str_cols = ['Player', 'Club', 'POS', 'Season', 'Last Name', 'First Name']
for col in str_cols:
    fp_df[col] = fp_df[col].str.strip()

# %% [markdown]
# #### Save Clean Data

# %%
fp_df.to_csv('fieldplayer.csv')
fp_df.to_pickle('fieldplayer.pkl')

# %% [markdown]
# ### Clean Goalkeeper Stats

# %%
# Replace null values with 0
gk_df = gk_df.replace(np.nan, '0')

# %%
# Split PKG/A column into to and drop
gk_df[['PKG', 'PKA']] = gk_df['PKG/A'].str.split('/', expand=True)
gk_df.drop('PKG/A', axis=1, inplace=True)
gk_df = gk_df.replace('', '0')

# %%
# Split Player into Last Name and First Name columns
first_name = []
last_name = []
for item in gk_df['Player'].str.split(' '):
    first_name.append(item[0])
    last_name.append(' '.join(item[1:]))
gk_df['Last Name'] = last_name    
gk_df['First Name'] = first_name

# %% [markdown]
# #### Set Column DTypes

# %%
int_cols = ['GP', 'GS', 'MINS', 'SHTS', 'SV', 'GA', 'W', 'L', 
            'T', 'ShO', 'Year', 'PKG', 'PKA']
for col in int_cols:
    gk_df[col] = gk_df[col].astype(int)

# %%
float_cols = ['GAA', 'W%', 'Sv%']
for col in float_cols:
    gk_df[col] = gk_df[col].astype(float)

# %% [markdown]
# #### Strip Whitespace

# %%
str_cols = ['Player', 'Club', 'POS', 'Season', 'Last Name', 'First Name']
for col in str_cols:
    gk_df[col] = gk_df[col].str.strip()

# %% [markdown]
# #### Save Clean Data

# %%
gk_df.to_csv('goalkeeper.csv')
gk_df.to_pickle('goalkeeper.pkl')

# %% [markdown]
# ### Merge FP with GK Stats

# %%
stats_df = merge_stats(fp_df, gk_df)

# %%
stats_df.to_csv('stats.csv')

# %% [markdown]
# ## Salary Data

# %% [markdown]
# ### Load Data

# %%
salary_df = pickle.load(open('./data/salary_df.pkl', 'rb'))

# %% [markdown]
# ### Clean Data

# %%
# Create Player column for linking
salary_df['Last Name'] = salary_df['Last Name'].str.strip()
salary_df['First Name'] = salary_df['First Name'].str.strip()
salary_df['Player'] = salary_df['First Name'] + ' ' + salary_df['Last Name']

# Replace NAN names with empty string
salary_df['First Name'] = salary_df['First Name'].replace(np.nan, '')
salary_df['Last Name'] = salary_df['Last Name'].replace(np.nan, '')

# Rename Pos to POS for linking
salary_df.rename(columns={'Pos': 'POS'}, inplace=True)

# Create Year Column
salary_df['Year'] = salary_df.Date.map(lambda x: x.year)

# Convert money str to float
def convert_money(salary_df, columns):
    if isinstance(columns, str):
        columns = [columns]
    for col in columns:
        salary_df[col] = salary_df[col].replace('', 0)
        salary_df[col] = salary_df[col].replace('-', 0)
        salary_df[col] = salary_df[col].replace('[\$,]', '', regex=True).astype(float)
    return salary_df
salary_df = convert_money(salary_df, ['Base Salary', 'Guaranteed Compensation'])

# %% [markdown]
# #### Strip Whitespace

# %%
str_cols = ['Player', 'Club', 'POS', 'Last Name', 'First Name']
for col in str_cols:
    salary_df[col] = salary_df[col].str.strip()

# %%
salary_df[salary_df['Last Name'] == 'Kaka']
# Out:
#      Club Last Name First Name POS  Base Salary  Guaranteed Compensation  \
# 0     ORL      Kaka              M    6660000.0                7167500.0
# 960   ORL      Kaka              M    6660000.0                7167500.0
# 1855  ORL      Kaka              M    6660000.0                7167500.0
# 2410  ORL      Kaka              M    6660000.0                7167500.0
# 2984  ORL      Kaka              M    6660000.0                7167500.0
# 3550  ORL      Kaka              M    6660000.0                7167500.0
# 4122  ORL      Kaka              M    6660000.0                7167500.0
#
#             Date Player  Year
# 0     2017-09-15   Kaka  2017
# 960   2017-04-15   Kaka  2017
# 1855  2016-09-15   Kaka  2016
# 2410  2016-05-15   Kaka  2016
# 2984  2015-09-15   Kaka  2015
# 3550  2015-07-15   Kaka  2015
# 4122  2014-09-15   Kaka  2014

# %%
salary_df[salary_df['Last Name'] == 'Findley']
# Out:
#      Club Last Name First Name POS  Base Salary  Guaranteed Compensation  \
# 2874  TOR   Findley     Robbie   F     225000.0                 255500.0
# 3447  TOR   Findley     Robbie   F     225000.0                 255500.0
# 4035  RSL   Findley     Robbie   F     215000.0                 245500.0
# 4595  RSL   Findley     Robbie   F     215000.0                 245500.0
# 5157  RSL   Findley     Robbie   F     175000.0                 205500.0
# 5724  RSL   Findley     Robbie   F     175000.0                 205500.0
# 6284  RSL   Findley     Robbie   F     175000.0                 205500.0
# 8744  RSL   Findley     Robert   F      73566.0                  87316.0
# 9146  RSL   Findley     Robert   F      60060.0                  72560.0
# 9559  RSL   Findley     Robert   F      47100.0                  59600.0
# 9933  RSL   Findley     Robert   F      36000.0                  48500.0
#
#             Date          Player  Year
# 2874  2015-09-15  Robbie Findley  2015
# 3447  2015-07-15  Robbie Findley  2015
# 4035  2014-09-15  Robbie Findley  2014
# 4595  2014-04-01  Robbie Findley  2014
# 5157  2013-09-15  Robbie Findley  2013
# 5724  2013-08-01  Robbie Findley  2013
# 6284  2013-05-01  Robbie Findley  2013
# 8744  2010-08-12  Robert Findley  2010
# 9146  2009-09-15  Robert Findley  2009
# 9559  2008-10-07  Robert Findley  2008
# 9933  2007-08-31  Robert Findley  2007

# %% [markdown]
# #### Keep Last Reported Salary
# Salary data may have been released multiple times during the year, generally once in the spring and once in the fall but sometimes more often. We want the last salary reported for the year. Salary is usually consistent across datasets for the same year; however, these sometimes differ and we want to guarantee we're using the lastest.

# %%
# Sort dataframe by Date, then keep last reported salary from the groupby
salary_df = salary_df.sort_values(['Date', 'Year', 'Club'])
salary_df = salary_df.groupby(['Year', 'Club', 'Last Name', 'First Name', 'Player', 'POS'], as_index=False).first()

# %%
salary_df[salary_df['Last Name'] == 'Findley']
# Out:
#       Year Club Last Name First Name          Player POS  Base Salary  \
# 323   2007  RSL   Findley     Robert  Robert Findley   F      36000.0
# 706   2008  RSL   Findley     Robert  Robert Findley   F      47100.0
# 1082  2009  RSL   Findley     Robert  Robert Findley   F      60060.0
# 1486  2010  RSL   Findley     Robert  Robert Findley   F      73566.0
# 3232  2013  RSL   Findley     Robbie  Robbie Findley   F     175000.0
# 3877  2014  RSL   Findley     Robbie  Robbie Findley   F     215000.0
# 4590  2015  TOR   Findley     Robbie  Robbie Findley   F     225000.0
#
#       Guaranteed Compensation        Date
# 323                   48500.0  2007-08-31
# 706                   59600.0  2008-10-07
# 1082                  72560.0  2009-09-15
# 1486                  87316.0  2010-08-12
# 3232                 205500.0  2013-05-01
# 3877                 245500.0  2014-04-01
# 4590                 255500.0  2015-07-15

# %% [markdown]
# ### Split Salary Data into Field Players and Goalkeepers

# %%
gk_idx = (salary_df['POS'] == 'GK')
fp_salary_df = salary_df[~gk_idx]
gk_salary_df = salary_df[gk_idx]

# %% [markdown]
# ### Merge Field Player Stats with Field Player Salary Data

# %%
# Not merging on Club because this causes issues 
cols = ['Year', 'Last Name']
df = pd.merge(fp_df, fp_salary_df, how='outer', left_on=cols, right_on=cols, suffixes=['', '_Dup'])

# %%
good_merge = df[~df.isnull().any(axis=1)]

# %%
len(good_merge)
# Out:
# 5921

# %%
good_merge[good_merge['Last Name'] == 'Findley']
# Out:
#               Player Club POS    GP    GS    MINS     G    A  SHTS   SOG  \
# 10    Robbie Findley   LA   F  25.0  14.0  1353.0   8.0  0.0  31.0  16.0
# 445   Robbie Findley  RSL   F  29.0  15.0  1493.0   6.0  5.0  44.0  18.0
# 876   Robbie Findley  RSL   F  27.0  18.0  1751.0  12.0  4.0  60.0  26.0
# 1316  Robbie Findley  RSL   F  24.0  15.0  1355.0   5.0  4.0  33.0  14.0
# 3083  Robbie Findley  RSL   F  25.0  17.0  1260.0   6.0  2.0  36.0  15.0
# 3976  Robbie Findley  RSL   F  16.0   8.0   764.0   1.0  0.0  24.0   9.0
# 4495  Robbie Findley  TOR   F  25.0  18.0  1476.0   2.0  3.0  28.0   8.0
#
#          ...      PKA  Last Name  First Name  Club_Dup  First Name_Dup  \
# 10       ...      0.0    Findley      Robbie       RSL          Robert
# 445      ...      0.0    Findley      Robbie       RSL          Robert
# 876      ...      1.0    Findley      Robbie       RSL          Robert
# 1316     ...      2.0    Findley      Robbie       RSL          Robert
# 3083     ...      0.0    Findley      Robbie       RSL          Robbie
# 3976     ...      0.0    Findley      Robbie       RSL          Robbie
# 4495     ...      0.0    Findley      Robbie       TOR          Robbie
#
#           Player_Dup POS_Dup  Base Salary  Guaranteed Compensation        Date
# 10    Robert Findley       F      36000.0                  48500.0  2007-08-31
# 445   Robert Findley       F      47100.0                  59600.0  2008-10-07
# 876   Robert Findley       F      60060.0                  72560.0  2009-09-15
# 1316  Robert Findley       F      73566.0                  87316.0  2010-08-12
# 3083  Robbie Findley       F     175000.0                 205500.0  2013-05-01
# 3976  Robbie Findley       F     215000.0                 245500.0  2014-04-01
# 4495  Robbie Findley       F     225000.0                 255500.0  2015-07-15
#
# [7 rows x 38 columns]

# %%
good_merge.to_csv('goodmerge_fp.csv')
good_merge.to_pickle('goodmerge_fp.pkl')

# %%
bad_merge = df[df.isnull().any(axis=1)]

# %%
len(bad_merge)
# Out:
# 915

# %%
bad_merge[bad_merge['Base Salary'] > 100000]
# Out:
#      Player Club  POS  GP  GS  MINS   G   A  SHTS  SOG     ...      PKA  \
# 6445    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6446    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6448    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6450    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6453    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6454    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6458    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6460    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6461    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6464    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6466    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6472    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6476    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6477    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6481    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6487    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6490    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6491    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6500    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6502    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6503    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6504    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6505    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6506    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6512    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6514    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6519    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6521    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6522    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6525    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# ...     ...  ...  ...  ..  ..   ...  ..  ..   ...  ...     ...      ...
# 6782    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6783    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6787    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6788    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6789    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6790    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6791    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6792    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6793    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6794    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6796    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6799    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6801    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6809    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6810    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6811    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6812    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6815    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6818    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6820    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6822    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6823    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6825    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6826    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6827    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6828    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6830    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6831    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6832    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
# 6833    NaN  NaN  NaN NaN NaN   NaN NaN NaN   NaN  NaN     ...      NaN
#
#               Last Name  First Name  Club_Dup    First Name_Dup  \
# 6445          Schelotto         NaN       CLB  Guillermo Barros
# 6446        De Oliveira         NaN       DAL          Denilson
# 6448           Carreiro         NaN        DC     Fred da Silva
# 6450          DeRosario         NaN       HOU            Dwayne
# 6453              Angel         NaN        NY        Juan Pablo
# 6454      Van Den Bergh         NaN        NY              Dave
# 6458          Schelotto         NaN       CLB  Guillermo Barros
# 6460  Carreiro da Silva         NaN        DC              Fred
# 6461          DeRosario         NaN       HOU            Dwayne
# 6464              Angel         NaN        NY        Juan Pablo
# 6466      Van Den Bergh         NaN        NY              Dave
# 6472          Schelotto         NaN       CLB  Guillermo Barros
# 6476      Van Den Bergh         NaN       DAL              Dave
# 6477           Carreiro         NaN        DC              Fred
# 6481              Angel         NaN        NY        Juan Pablo
# 6487          DeRosario         NaN       TFC            Dwayne
# 6490              Umana         NaN       CHV           Michael
# 6491           Renteria         NaN       CLB            Emilio
# 6500              Angel         NaN        NY        Juan Pablo
# 6502            Marquez         NaN        NY            Rafael
# 6503              Salou         NaN        NY           Ibrahim
# 6504             Orozco         NaN       PHI           Michael
# 6505          Fernandez         NaN       SEA            Alvaro
# 6506            Hurtado         NaN       SEA      John Kennedy
# 6512          DeRosario         NaN       TFC            Dwayne
# 6514              Angel         NaN       CHV        Juan Pablo
# 6519              Umana         NaN       CHV           Michael
# 6521           Renteria         NaN       CLB            Emilio
# 6522            Benitez         NaN       DAL              Jair
# 6525          DeRosario         NaN        DC            Dwayne
# ...                 ...         ...       ...               ...
# 6782           De Leeuw         NaN       CHI           Michael
# 6783            Juninho         NaN       CHI
# 6787            Sjoberg         NaN       COL              Axel
# 6788              Ortiz         NaN        DC    Jose Guillermo
# 6789            Cabezas         NaN       HOU        Juan David
# 6790            Iniguez         NaN       HOU           Agustin
# 6791   Monteiro de Lima         NaN       HOU              Alex
# 6792      Rubio Kostner         NaN        KC             Diego
# 6793         Dos Santos         NaN        LA           Giovani
# 6794         Dos Santos         NaN        LA          Jonathan
# 6796         Van Anholt         NaN        LA              Pele
# 6799               Anor         NaN     MNUFC          Bernardo
# 6801              Ibson         NaN     MNUFC
# 6809             Mlinar         NaN        NE   Antonio Delamea
# 6810          Brilliant         NaN     NYCFC          Frederic
# 6811           Diskerud         NaN     NYCFC               Mix
# 6812               Mena         NaN     NYCFC         Jefferson
# 6815            Martins         NaN      NYRB            Felipe
# 6818              Veron         NaN      NYRB           Gonzalo
# 6820               Kaka         NaN       ORL
# 6822            Fabinho         NaN       PHI
# 6823            Fabinho         NaN       PHI           Fabinho
# 6825            Ilsinho         NaN       PHI
# 6826    Andriuskevicius         NaN       POR          Vytautas
# 6827             Melano         NaN       POR             Lucas
# 6828             Sunday         NaN       RSL           Stephen
# 6830          Bernardez         NaN        SJ            Victor
# 6831              Ceren         NaN        SJ            Darwin
# 6832              Urena         NaN        SJ             Marco
# 6833            Bolanos         NaN       VAN         Christian
#
#                       Player_Dup POS_Dup  Base Salary  \
# 6445  Guillermo Barros Schelotto       F    150000.00
# 6446        Denilson De Oliveira       M    872736.00
# 6448      Fred da Silva Carreiro     M-F    190008.00
# 6450            Dwayne DeRosario       M    324999.96
# 6453            Juan Pablo Angel       F   1500000.00
# 6454          Dave Van Den Bergh       M    180000.00
# 6458  Guillermo Barros Schelotto       F    250000.00
# 6460      Fred Carreiro da Silva       M    210000.00
# 6461            Dwayne DeRosario       M    325000.00
# 6464            Juan Pablo Angel       F   1500000.00
# 6466          Dave Van Den Bergh       M    240000.00
# 6472  Guillermo Barros Schelotto     F-M    650000.00
# 6476          Dave Van Den Bergh       M    210000.00
# 6477               Fred Carreiro     M-F    225000.00
# 6481            Juan Pablo Angel       F   1500000.00
# 6487            Dwayne DeRosario       M    357000.00
# 6490               Michael Umana       D    132000.00
# 6491             Emilio Renteria       F    108000.00
# 6500            Juan Pablo Angel       F   1620000.00
# 6502              Rafael Marquez       D   5544000.00
# 6503               Ibrahim Salou       F    264000.00
# 6504              Michael Orozco       D    150000.00
# 6505            Alvaro Fernandez       M    300000.00
# 6506        John Kennedy Hurtado       D    120000.00
# 6512            Dwayne DeRosario       M    375000.00
# 6514            Juan Pablo Angel       F   1000000.00
# 6519               Michael Umana       D    138000.00
# 6521             Emilio Renteria       F    120000.00
# 6522                Jair Benitez       D    150000.00
# 6525            Dwayne DeRosario       M    425000.00
# ...                          ...     ...          ...
# 6782            Michael De Leeuw       F    500000.00
# 6783                     Juninho       M    700008.00
# 6787                Axel Sjoberg       D    108350.00
# 6788        Jose Guillermo Ortiz       F    129996.00
# 6789          Juan David Cabezas       M    243000.00
# 6790             Agustin Iniguez       D    143000.00
# 6791       Alex Monteiro de Lima       M    170000.00
# 6792         Diego Rubio Kostner       F    202000.00
# 6793          Giovani Dos Santos       F   3750000.00
# 6794         Jonathan Dos Santos       M   2000000.04
# 6796             Pele Van Anholt       D    216000.00
# 6799               Bernardo Anor       M    105000.00
# 6801                       Ibson       M    200004.00
# 6809      Antonio Delamea Mlinar       D    400008.00
# 6810          Frederic Brilliant       D    280000.00
# 6811                Mix Diskerud       M    772669.00
# 6812              Jefferson Mena       D    250000.00
# 6815              Felipe Martins       M    275000.00
# 6818               Gonzalo Veron     M-F    500000.00
# 6820                        Kaka       M   6660000.00
# 6822                     Fabinho       D    159759.00
# 6823             Fabinho Fabinho       D    159759.00
# 6825                     Ilsinho       M    470000.00
# 6826    Vytautas Andriuskevicius       D    222500.00
# 6827                Lucas Melano       F    790000.00
# 6828              Stephen Sunday       M    240000.00
# 6830            Victor Bernardez       D    225000.00
# 6831                Darwin Ceren       M    200000.00
# 6832                 Marco Urena       F    275004.00
# 6833           Christian Bolanos       M    250000.00
#
#       Guaranteed Compensation        Date
# 6445                150000.00  2007-08-31
# 6446                879936.00  2007-08-31
# 6448                222008.00  2007-08-31
# 6450                324999.96  2007-08-31
# 6453               1593750.00  2007-08-31
# 6454                214583.33  2007-08-31
# 6458                375000.00  2008-10-07
# 6460                242000.00  2008-10-07
# 6461                324999.96  2008-10-07
# 6464               1593750.00  2008-10-07
# 6466                274583.33  2008-10-07
# 6472                775000.00  2009-09-15
# 6476                227000.00  2009-09-15
# 6477                257000.00  2009-09-15
# 6481               1798000.00  2009-09-15
# 6487                425750.00  2009-09-15
# 6490                144312.50  2010-08-12
# 6491                109875.00  2010-08-12
# 6500               1918000.00  2010-08-12
# 6502               5544000.00  2010-08-12
# 6503                264000.00  2010-08-12
# 6504                200000.00  2010-08-12
# 6505                300000.00  2010-08-12
# 6506                121000.00  2010-08-12
# 6512                443750.00  2010-08-12
# 6514               1250000.00  2011-09-01
# 6519                145500.00  2011-09-01
# 6521                121875.00  2011-09-01
# 6522                171250.00  2011-09-01
# 6525                493750.00  2011-09-01
# ...                       ...         ...
# 6782                564212.50  2017-04-15
# 6783                716674.67  2017-04-15
# 6787                123350.00  2017-04-15
# 6788                137621.00  2017-04-15
# 6789                267000.00  2017-04-15
# 6790                143000.00  2017-04-15
# 6791                170000.00  2017-04-15
# 6792                218875.00  2017-04-15
# 6793               5500000.00  2017-04-15
# 6794               2000000.04  2017-09-15
# 6796                216000.00  2017-09-15
# 6799                105000.00  2017-04-15
# 6801                210337.40  2017-04-15
# 6809                400008.00  2017-04-15
# 6810                319666.67  2017-04-15
# 6811                772669.00  2017-04-15
# 6812                261400.00  2017-04-15
# 6815                305000.00  2017-04-15
# 6818                500000.00  2017-04-15
# 6820               7167500.00  2017-04-15
# 6822                167759.00  2017-09-15
# 6823                167759.00  2017-04-15
# 6825                518333.33  2017-04-15
# 6826                244375.00  2017-04-15
# 6827               1010000.00  2017-04-15
# 6828                253000.00  2017-04-15
# 6830                266600.00  2017-04-15
# 6831                249375.00  2017-04-15
# 6832                289420.67  2017-04-15
# 6833                253500.00  2017-04-15
#
# [194 rows x 38 columns]

# %%
bad_merge.to_csv('badmerge_fp.csv')
bad_merge.to_pickle('badmerge_fp.pkl')

# %% [markdown]
# ### Fix Player Name Association
# Some names are different between the datasets; therefore, they fail to link during the merge operation.  Given time, it would be nice to explore fixing this association for as many as possible.

# %%
players1 = pd.concat([fp_df.Player, gk_df.Player], ignore_index=True).unique()

# %%
players2 = salary_df.Player.unique()

# %%
true_player = {}
for p2 in players2:
    scores = np.zeros((len(players1), 3))
    for ii, p1 in enumerate(players1):
        scores[ii, :] = np.array([fuzz.ratio(p1, p2), 
                                  fuzz.partial_ratio(p1, p2),
                                  fuzz.token_set_ratio(p1, p2)])
    true_player[p2] = scores

# %%
player_map = {}
for player in true_player.keys():
    match_idx = true_player[player][:, 2].argmax()
    match = players1[match_idx]
    match_score = true_player[player][match_idx, :] / 100
    player_map[player] = (match, match_score)
    if (match_score[2] < 0.9) & (match_score[2] >= 0.8):
        print(player, '=>', match, ':', match_score)

# %%
test = fp_df.groupby(['Year', 'Club']).last()
test

# %%
for

# %% [markdown]
# ## Playing with Multi-Index

# %%
tmp = salary_df.groupby(['Year', 'Club'], as_index=True).mean()
tmp

# %%
tmp.index

# %%
tmp.iloc[0]

# %%
tmp.loc[2007, 'CHI']

# %%
tmp2 = salary_df.groupby(['Year', 'Club', 'Player'], as_index=True).mean()

# %%
tmp2.loc[2017, 'DC']
