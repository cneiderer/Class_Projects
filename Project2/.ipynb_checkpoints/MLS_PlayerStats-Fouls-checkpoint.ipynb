# %% [markdown]
# ## Scraping MLS Player Stats

# %% [markdown]
# Scraping www.mlssoccer.com/ for player statistics

# %% [markdown]
# ### Import Necessary Modules

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime 
from dateutil import parser
import os
import time
import itertools
import re
import pickle

# %% [markdown]
# ### Scrape Statistics

# %% [markdown]
# #### Define Scraper and Helpers

# %%
def send_request(url, params={}, attempts=3):

    cnt = 0
    while cnt <= attempts:
        cnt += 1        
        # Send Request
        response = requests.get(url, params)
        # Check Status
        print(response.url, '\n', response.status_code, response.reason)
        if (response.status_code >= 200) and (response.status_code < 300):           
            return response
        # If bad status, pause before trying again
        print('Pause, then retry')
        time.sleep(15)
    return None

# %%
def map_id_to_club(franchise_id):
    
    franchise_map = {11091: 'ATL',
                     1207: 'CHI',
                     436: 'COL',
                     454: 'CLB',
                     1326: 'DC',
                     1903: 'DAL',
                     1897: 'HOU',
                     1230: 'LA',
                     11690: 'LAFC',
                     6977: 'MNUFC',
                     1616: 'MTL',
                     928: 'NE',
                     9668: 'NYCFC',
                     399: 'NYRB',
                     6900: 'ORL',
                     5513: 'PHI',
                     1581: 'POR',
                     1899: 'RSL',
                     1131: 'SJ',
                     3500: 'SEA',
                     421: 'KC',
                     2077: 'TOR',
                     1708: 'VAN'}
    return franchise_map[franchise_id]

# %%
def check_for_data(stats_table):
    # Check if the table has any 
    odd_rows = stats_table.findAll('tr', {'class': 'odd'})
    if odd_rows[0].text.strip() == 'Stats Unavailable':
        return False
    return True

# %%
def split_player_name(df):
    first = []
    last = []
    for t in df.Player.str.split():
        if len(t) == 1:
            first.append(t[0])
            last.append('')
        elif len(t) == 2:
            first.append(t[0])
            last.append(t[1])
        else:
            first.append(t[0])
            last.append(' '.join(t[1:]))
    
    df['Last'] = last
    df['First'] = first  
    
    df = df.drop('Player', axis=1)
    
    return df

# %%
# # Find and parse franchise popup menu to get list of teams
# soup = BeautifulSoup(response.text, 'lxml')
# franchise_select = soup.find('select', {'id': 'edit-franchise', 'name': 'franchise'})
# franchise = []
# # start with second index since first is generic "Select A Club"
# for team in franchise_select.findAll('option')[1:]:
#     franchise.append(int(team['value']))

# %%
def generate_param_combos(param_groups):
    params = []
    for combo in itertools.product(*param_groups):
        params.append({'franchise': combo[0],
                       'group': combo[1],
                       'season_type': combo[2],
                       'year': combo[3],
                       'page': combo[4]})
    return params

# %%
def scrape_player_stats(base_url, params, return_last_pg=False):

    response = send_request(base_url, params)
    if response is None:
        return None
    
    # Parse HTML
    soup = BeautifulSoup(response.text,'lxml')
    
    stats_table = soup.find('table')
    
    if not check_for_data(stats_table):
        return None
    
    stats_df = extract_stats(stats_table)
    # Add Year Column
    stats_df['Year'] = np.repeat(int(params['year']), len(stats_df))
    # Add Season Column
    stats_df['Season'] = np.repeat(params['season_type'], len(stats_df))
    
    if return_last_pg:
        return stats_df, get_last_page(soup)
    
    return stats_df

# %% [raw]
# base_url = 'http://www.mlssoccer.com/stats/season'
# params = {'franchise': select,
#           'group': 'goalkeeping',
#           'season_type': 'REG',
#           'year': 2017,
#           'page': 0,
#           'op': 'Search'})
# response = requests.get(url, params)

# %%
def extract_stats(stat_table):
    
    # Extract salary data
    stat_header = []
    stat_data = []
    for row in stat_table.findAll('tr'):
        row_data = []

        # Get row type and check if header or data row
        row_type = row.findChild().name
        if row_type == 'th':
            # Extract header
            for h in stat_table.findAll('th'):
                stat_header.append(h.text) 
        else:
            # Extract data
            for data in row.findAll('td'):
                row_data.append(data.text)
            stat_data.append(row_data)    
            
    # Compile stat dataframe
    stat_df = pd.DataFrame(stat_data, columns=stat_header)
    
    # Strip any whitespace from column names
    stat_df.columns = stat_df.columns.str.strip()
    
    # Replace blanks with nans
    stat_df = stat_df.replace('', np.nan)
        
    return stat_df

# %%
def get_last_page(soup):

    last_pg_url = soup.find('li', {'class': 'pager-last last'}).find('a')['href']
    last_pg = int(re.search('(?<=page=)\d+', last_pg_url).group())
    
    return last_pg

# %%
def scrape_group_stats(base_url, group, year=np.arange(2007, 2018), franchise='select', season_type='REG'):
    
    group_df = pd.DataFrame()
    combos = generate_param_combos([[franchise], [group], [season_type], year, [0]])
    for params in combos: 
        stats_df, last_pg = scrape_player_stats(base_url, params, True)
        
        if stats_df is None:
            continue
            
        # Scrape first page of results
        group_df = pd.concat([group_df, stats_df], axis=0)
        # Add pause to prevent 429 status
        print(datetime.now())
        time.sleep(np.random.uniform(2, 5)) 
        
        # Scrape next through last
        for idx in range(1, last_pg+1):
            params['page'] = idx
            stats_df = scrape_player_stats(base_url, params)
            if stats_df is None:
                continue
            group_df = pd.concat([group_df, stats_df], axis=0)            
            # Add pause to prevent 429 status
            print(datetime.now())
            time.sleep(np.random.uniform(2, 5)) 
            
    # Reset index to remove duplicates created during concatenation
    group_df.reset_index(inplace=True, drop=True)
    
    return group_df

# %% [markdown]
# #### Send Request to Base URL and Verify Site is Up

# %%
base_url = 'http://www.mlssoccer.com/stats/season'
response = requests.get(base_url)
response.status_code, response.url
# Out:
# (200, 'https://www.mlssoccer.com/stats/season')

# %% [markdown]
# #### Define parameter options

# %%
# group = ['goals', 'assists', 'shots', 'fouls', 'goalkeeping']
# for grp in group:
#     print('Scraping:', grp, datetime.now(), '\n')
#     df = scrape_group_stats(base_url, grp, np.arange(2007, 2018, 1))
#     df.to_pickle(grp + '_df.pkl')
#     print('Completed Scraping:', grp)

# %%
fouls_df = scrape_group_stats(base_url, 'fouls')
# Out:
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=0
#  200 OK
# 2018-01-26 17:36:43.348369
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=1
#  200 OK
# 2018-01-26 17:36:53.232375
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=2
#  200 OK
# 2018-01-26 17:37:04.300632
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=3
#  200 OK
# 2018-01-26 17:37:18.309698
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=4
#  200 OK
# 2018-01-26 17:37:30.313162
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=5
#  200 OK
# 2018-01-26 17:37:38.724534
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=6
#  200 OK
# 2018-01-26 17:37:45.731797
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=7
#  200 OK
# 2018-01-26 17:37:54.299337
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=8
#  200 OK
# 2018-01-26 17:38:04.568320
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=9
#  200 OK
# 2018-01-26 17:38:12.300413
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=10
#  200 OK
# 2018-01-26 17:38:21.326423
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=11
#  200 OK
# 2018-01-26 17:38:28.318185
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=12
#  200 OK
# 2018-01-26 17:38:37.290072
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=13
#  200 OK
# 2018-01-26 17:38:45.025348
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2007&page=14
#  200 OK
# 2018-01-26 17:38:55.289306
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2008&page=0
#  200 OK
# 2018-01-26 17:39:02.317792
# https://www.mlssoccer.com/stats/season?franchise=select&group=fouls&season_type=REG&year=2008&page
# 5300       Luis Gonzalez  DAL    M   2   0     8   0   0    0   0   0   1   0
# 5301        Shamit Shome  MTL    M   1   0     8   0   0    1   0   0   0   0
# 5302       Brandon Allen  MIN    F   1   0     9   0   0    0   0   0   0   0
# 5303         Hadji Barry  ORL    F   3   0    11   0   0    1   0   0   0   1
# 5304           Coy Craft  DAL  F-M   1   0    11   0   0    1   0   0   1   0
# 5305       Alhaji Kamara   DC    F   1   0    14   0   0    1   0   0   0   0
# 5306         Jose Leiton  MIN    M   1   0    15   0   0    0   0   0   0   0
# 5307      Jesus Ferreira  DAL    F   1   0    19   1   0    1   1   0   0   0
# 5308      Cameron Porter  KC     F   1   0    21   0   0    1   0   0   0   1
# 5309      Jose Escalante  HOU    M   3   0    24   0   0    2   0   0   2   0
# 5310      Charlie Davies  PHI    F   3   0    25   0   0    0   0   0   1   0
# 5311        Chance Myers  POR    D   1   1    44   0   0    0   0   0   0   0
# 5312       Mauro Rosales  VAN    M   5   0    52   0   0    0   0   0   1   0
# 5313        Donnie Smith   NE    M   1   1    53   0   0    0   0   0   0   0
# 5314   Wandrille Lefevre  MTL    D   3   1   103   0   0    2   1   0   0   0
# 5315      Connor Maloney  CLB    D   2   1   127   0   1    1   0   0   1   0
#
#       YC RC  Year Season
# 0      4  0  2007    REG
# 1     11  1  2007    REG
# 2      6  1  2007    REG
# 3      5  0  2007    REG
# 4      6  1  2007    REG
# 5      4  1  2007    REG
# 6      3  0  2007    REG
# 7      5  0  2007    REG
# 8      6  0  2007    REG
# 9      8  0  2007    REG
# 10     3  1  2007    REG
# 11     9  1  2007    REG
# 12     7  1  2007    REG
# 13     9  1  2007    REG
# 14     8  0  2007    REG
# 15     6  1  2007    REG
# 16     6  1  2007    REG
# 17     3  0  2007    REG
# 18     5  0  2007    REG
# 19     5  1  2007    REG
# 20     5  0  2007    REG
# 21     6  0  2007    REG
# 22     9  0  2007    REG
# 23     4  1  2007    REG
# 24     6  1  2007    REG
# 25     5  1  2007    REG
# 26     6  1  2007    REG
# 27     4  0  2007    REG
# 28     6  1  2007    REG
# 29     1  0  2007    REG
# ...   .. ..   ...    ...
# 5286   0  0  2017    REG
# 5287   0  0  2017    REG
# 5288   0  0  2017    REG
# 5289   0  0  2017    REG
# 5290   0  0  2017    REG
# 5291   0  0  2017    REG
# 5292   0  0  2017    REG
# 5293   0  0  2017    REG
# 5294   0  0  2017    REG
# 5295   0  0  2017    REG
# 5296   0  0  2017    REG
# 5297   0  0  2017    REG
# 5298   0  0  2017    REG
# 5299   0  0  2017    REG
# 5300   0  0  2017    REG
# 5301   0  0  2017    REG
# 5302   0  0  2017    REG
# 5303   0  0  2017    REG
# 5304   0  0  2017    REG
# 5305   0  0  2017    REG
# 5306   0  0  2017    REG
# 5307   0  0  2017    REG
# 5308   0  0  2017    REG
# 5309   0  0  2017    REG
# 5310   0  0  2017    REG
# 5311   0  0  2017    REG
# 5312   0  0  2017    REG
# 5313   0  0  2017    REG
# 5314   0  0  2017    REG
# 5315   0  0  2017    REG
#
# [5316 rows x 17 columns]

# %%
fouls_df.to_pickle('fouls_df.pkl')

# %% [markdown]
# ### Sandbox
