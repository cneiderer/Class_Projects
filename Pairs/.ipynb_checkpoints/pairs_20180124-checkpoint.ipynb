# %% [markdown]
# ### Pair Problem: 20180124

# %% [markdown]
# The data for this problem are the numbers 2, 7, 1, 5, and 10.
#
# We want to know which of the numbers from 0 to 10 (by tenths) gives the smallest result when we do the following:
#
# For each of the numbers in the data, subtract the candidate number and then square the result, then add up these numbers.
#
# For example, to test the candidate number 8.2, we do the following:
#
# ```
# 2 - 8.2 = -6.2
#          (-6.2)**2 = 38.44
# 7 - 8.2 = -1.2
#          (-1.2)**2 = 1.44
# 1 - 8.2 = -7.2
#          (-7.2)**2 = 51.84
# 5 - 8.2 = -3.2
#          (-3.2)**2 = 10.24
# 10 - 8.2 = 1.8
#            1.8**2  = 3.24
#
# 38.44 + 1.44 + 51.84 + 10.24 + 3.24 = 105.2
# ```
#
# For candidate number 8.2, the result is 105.2. Can we get a smaller result for any of the other candidate numbers? Try them all and find the candidate number that gives the smallest result.
#
# You might identify a shortcut to solving this problem. Write the code to try all the candidate numbers anyway.
#
# Once you have an answer, also make a plot to show the results for all the candidate numbers.
#
# As an extension, consider what class of problem this exercise represents. Can you write a general solution? Can you write a faster general solution?

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Pairs Solution

# %%
data = [2, 7, 1, 5, 10]

# %%
result = {}
for c in np.round(np.arange(0, 10.1, 0.1), 1):
    c_result = []
    for n in data:
        c_result.append((n - c) ** 2)
        result[np.round(c, 1)] = np.sum(c_result)
result
# Out:
# {0.0: 179.0,
#  0.10000000000000001: 174.05000000000001,
#  0.20000000000000001: 169.20000000000002,
#  0.29999999999999999: 164.44999999999999,
#  0.40000000000000002: 159.79999999999998,
#  0.5: 155.25,
#  0.59999999999999998: 150.80000000000001,
#  0.69999999999999996: 146.44999999999999,
#  0.80000000000000004: 142.19999999999999,
#  0.90000000000000002: 138.04999999999998,
#  1.0: 134.0,
#  1.1000000000000001: 130.05000000000001,
#  1.2: 126.20000000000002,
#  1.3: 122.44999999999999,
#  1.3999999999999999: 118.79999999999998,
#  1.5: 115.25,
#  1.6000000000000001: 111.80000000000001,
#  1.7: 108.45000000000002,
#  1.8: 105.2,
#  1.8999999999999999: 102.05,
#  2.0: 99.0,
#  2.1000000000000001: 96.050000000000011,
#  2.2000000000000002: 93.199999999999989,
#  2.2999999999999998: 90.450000000000017,
#  2.3999999999999999: 87.799999999999997,
#  2.5: 85.25,
#  2.6000000000000001: 82.800000000000011,
#  2.7000000000000002: 80.450000000000003,
#  2.7999999999999998: 78.200000000000003,
#  2.8999999999999999: 76.049999999999997,
#  3.0: 74.0,
#  3.1000000000000001: 72.050000000000011,
#  3.2000000000000002: 70.199999999999989,
#  3.2999999999999998: 68.450000000000003,
#  3.3999999999999999: 66.799999999999997,
#  3.5: 65.25,
#  3.6000000000000001: 63.800000000000011,
#  3.7000000000000002: 62.449999999999996,
#  3.7999999999999998: 61.200000000000003,
#  3.8999999999999999: 60.049999999999997,
#  4.0: 59.0,
#  4.0999999999999996: 58.050000000000004,
#  4.2000000000000002: 57.200000000000003,
#  4.2999999999999998: 56.450000000000003,
#  4.4000000000000004: 55.799999999999997,
#  4.5: 55.25,
#  4.5999999999999996: 54.799999999999997,
#  4.7000000000000002: 54.450000000000003,
#  4.7999999999999998: 54.200000000000003,
#  4.9000000000000004: 54.049999999999997,
#  5.0: 54.0,
#  5.0999999999999996: 54.050000000000004,
#  5.2000000000000002: 54.200000000000003,
#  5.2999999999999998: 54.450000000000003,
#  5.4000000000000004: 54.800000000000004,
#  5.5: 55.25,
#  5.5999999999999996: 55.799999999999997,
#  5.7000000000000002: 56.450000000000003,
#  5.7999999999999998: 57.200000000000003,
#  5.9000000000000004: 58.050000000000011,
#  6.0: 59.0,
#  6.0999999999999996: 60.049999999999997,
#  6.2000000000000002: 61.200000000000003,
#  6.2999999999999998: 62.450000000000003,
#  6.4000000000000004: 63.800000000000011,
#  6.5: 65.25,
#  6.5999999999999996: 66.799999999999997,
#  6.7000000000000002: 68.450000000000003,
#  6.7999999999999998: 70.200000000000003,
#  6.9000000000000004: 72.050000000000011,
#  7.0: 74.0,
#  7.0999999999999996: 76.049999999999983,
#  7.2000000000000002: 78.200000000000017,
#  7.2999999999999998: 80.450000000000003,
#  7.4000000000000004: 82.800000000000011,
#  7.5: 85.25,
#  7.5999999999999996: 87.799999999999997,
#  7.7000000000000002: 90.450000000000017,
#  7.7999999999999998: 93.200000000000003,
#  7.9000000000000004: 96.050000000000011,
#  8.0: 99.0,
#  8.0999999999999996: 102.04999999999998,
#  8.1999999999999993: 105.19999999999997,
#  8.3000000000000007: 108.45000000000003,
#  8.4000000000000004: 111.80000000000001,
#  8.5: 115.25,
#  8.5999999999999996: 118.8,
#  8.6999999999999993: 122.44999999999999,
#  8.8000000000000007: 126.20000000000002,
#  8.9000000000000004: 130.05000000000001,
#  9.0: 134.0,
#  9.0999999999999996: 138.04999999999998,
#  9.1999999999999993: 142.19999999999999,
#  9.3000000000000007: 146.45000000000005,
#  9.4000000000000004: 150.80000000000004,
#  9.5: 155.25,
#  9.5999999999999996: 159.79999999999998,
#  9.6999999999999993: 164.44999999999999,
#  9.8000000000000007: 169.20000000000002,
#  9.9000000000000004: 174.05000000000001,
#  10.0: 179.0}

# %%
plt.plot(result.keys(), result.values())

# %%
min(result, key=result.get), min(result.values())
# Out:
# (5.0, 54.0)

# %% [markdown]
# ### My Solution

# %%
data = [2, 7, 1, 5, 10]
candidates = np.round(np.arange(0, 10.1, 0.1), 1)

# %%
rep_data = np.tile(np.array(data), (len(candidates), 1))
rep_candidates = np.tile(candidates, (len(data), 1)).T

# %%
diff_result = rep_data - rep_candidates
square_result = diff_result ** 2
sum_result = np.sum(square_result, axis=1)

# %%
min_candidate, min_result = (candidates[np.argmin(sum_result)], min(sum_result))
print('Min Candidate:', min_candidate, ', Result:', min_result)
# Out:
# Min Candidate: 5.0 , Result: 54.0

# %%
df = pd.DataFrame([candidates, diff_result, square_result, sum_result], 
             index=['Candidate', 'Diff', 'Square', 'Sum']).T

# %%
df
# Out:
#     Candidate                           Diff  \
# 0           0     [2.0, 7.0, 1.0, 5.0, 10.0]
# 1         0.1      [1.9, 6.9, 0.9, 4.9, 9.9]
# 2         0.2      [1.8, 6.8, 0.8, 4.8, 9.8]
# 3         0.3      [1.7, 6.7, 0.7, 4.7, 9.7]
# 4         0.4      [1.6, 6.6, 0.6, 4.6, 9.6]
# 5         0.5      [1.5, 6.5, 0.5, 4.5, 9.5]
# 6         0.6      [1.4, 6.4, 0.4, 4.4, 9.4]
# 7         0.7      [1.3, 6.3, 0.3, 4.3, 9.3]
# 8         0.8      [1.2, 6.2, 0.2, 4.2, 9.2]
# 9         0.9      [1.1, 6.1, 0.1, 4.1, 9.1]
# 10          1      [1.0, 6.0, 0.0, 4.0, 9.0]
# 11        1.1     [0.9, 5.9, -0.1, 3.9, 8.9]
# 12        1.2     [0.8, 5.8, -0.2, 3.8, 8.8]
# 13        1.3     [0.7, 5.7, -0.3, 3.7, 8.7]
# 14        1.4     [0.6, 5.6, -0.4, 3.6, 8.6]
# 15        1.5     [0.5, 5.5, -0.5, 3.5, 8.5]
# 16        1.6     [0.4, 5.4, -0.6, 3.4, 8.4]
# 17        1.7     [0.3, 5.3, -0.7, 3.3, 8.3]
# 18        1.8     [0.2, 5.2, -0.8, 3.2, 8.2]
# 19        1.9     [0.1, 5.1, -0.9, 3.1, 8.1]
# 20          2     [0.0, 5.0, -1.0, 3.0, 8.0]
# 21        2.1    [-0.1, 4.9, -1.1, 2.9, 7.9]
# 22        2.2    [-0.2, 4.8, -1.2, 2.8, 7.8]
# 23        2.3    [-0.3, 4.7, -1.3, 2.7, 7.7]
# 24        2.4    [-0.4, 4.6, -1.4, 2.6, 7.6]
# 25        2.5    [-0.5, 4.5, -1.5, 2.5, 7.5]
# 26        2.6    [-0.6, 4.4, -1.6, 2.4, 7.4]
# 27        2.7    [-0.7, 4.3, -1.7, 2.3, 7.3]
# 28        2.8    [-0.8, 4.2, -1.8, 2.2, 7.2]
# 29        2.9    [-0.9, 4.1, -1.9, 2.1, 7.1]
# ..        ...                            ...
# 71        7.1  [-5.1, -0.1, -6.1, -2.1, 2.9]
# 72        7.2  [-5.2, -0.2, -6.2, -2.2, 2.8]
# 73        7.3  [-5.3, -0.3, -6.3, -2.3, 2.7]
# 74        7.4  [-5.4, -0.4, -6.4, -2.4, 2.6]
# 75        7.5  [-5.5, -0.5, -6.5, -2.5, 2.5]
# 76        7.6  [-5.6, -0.6, -6.6, -2.6, 2.4]
# 77        7.7  [-5.7, -0.7, -6.7, -2.7, 2.3]
# 78        7.8  [-5.8, -0.8, -6.8, -2.8, 2.2]
# 79        7.9  [-5.9, -0.9, -6.9, -2.9, 2.1]
# 80          8  [-6.0, -1.0, -7.0, -3.0, 2.0]
# 81        8.1  [-6.1, -1.1, -7.1, -3.1, 1.9]
# 82        8.2  [-6.2, -1.2, -7.2, -3.2, 1.8]
# 83        8.3  [-6.3, -1.3, -7.3, -3.3, 1.7]
# 84        8.4  [-6.4, -1.4, -7.4, -3.4, 1.6]
# 85        8.5  [-6.5, -1.5, -7.5, -3.5, 1.5]
# 86        8.6  [-6.6, -1.6, -7.6, -3.6, 1.4]
# 87        8.7  [-6.7, -1.7, -7.7, -3.7, 1.3]
# 88        8.8  [-6.8, -1.8, -7.8, -3.8, 1.2]
# 89        8.9  [-6.9, -1.9, -7.9, -3.9, 1.1]
# 90          9  [-7.0, -2.0, -8.0, -4.0, 1.0]
# 91        9.1  [-7.1, -2.1, -8.1, -4.1, 0.9]
# 92        9.2  [-7.2, -2.2, -8.2, -4.2, 0.8]
# 93        9.3  [-7.3, -2.3, -8.3, -4.3, 0.7]
# 94        9.4  [-7.4, -2.4, -8.4, -4.4, 0.6]
# 95        9.5  [-7.5, -2.5, -8.5, -4.5, 0.5]
# 96        9.6  [-7.6, -2.6, -8.6, -4.6, 0.4]
# 97        9.7  [-7.7, -2.7, -8.7, -4.7, 0.3]
# 98        9.8  [-7.8, -2.8, -8.8, -4.8, 0.2]
# 99        9.9  [-7.9, -2.9, -8.9, -4.9, 0.1]
# 100        10  [-8.0, -3.0, -9.0, -5.0, 0.0]
#
#                                 Square     Sum
# 0        [4.0, 49.0, 1.0, 25.0, 100.0]     179
# 1    [3.61, 47.61, 0.81, 24.01, 98.01]  174.05
# 2    [3.24, 46.24, 0.64, 23.04, 96.04]   169.2
# 3    [2.89, 44.89, 0.49, 22.09, 94.09]  164.45
# 4    [2.56, 43.56, 0.36, 21.16, 92.16]   159.8
# 5    [2.25, 42.25, 0.25, 20.25, 90.25]  155.25
# 6    [1.96, 40.96, 0.16, 19.36, 88.36]   150.8
# 7    [1.69, 39.69, 0.09, 18.49, 86.49]  146.45
# 8    [1.44, 38.44, 0.04, 17.64, 84.64]   142.2
# 9    [1.21, 37.21, 0.01, 16.81, 82.81]  138.05
# 10        [1.0, 36.0, 0.0, 16.0, 81.0]     134
# 11   [0.81, 34.81, 0.01, 15.21, 79.21]  130.05
# 12   [0.64, 33.64, 0.04, 14.44, 77.44]   126.2
# 13   [0.49, 32.49, 0.09, 13.69, 75.69]  122.45
# 14   [0.36, 31.36, 0.16, 12.96, 73.96]   118.8
# 15   [0.25, 30.25, 0.25, 12.25, 72.25]  115.25
# 16   [0.16, 29.16, 0.36, 11.56, 70.56]   111.8
# 17   [0.09, 28.09, 0.49, 10.89, 68.89]  108.45
# 18   [0.04, 27.04, 0.64, 10.24, 67.24]   105.2
# 19    [0.01, 26.01, 0.81, 9.61, 65.61]  102.05
# 20         [0.0, 25.0, 1.0, 9.0, 64.0]      99
# 21    [0.01, 24.01, 1.21, 8.41, 62.41]   96.05
# 22    [0.04, 23.04, 1.44, 7.84, 60.84]    93.2
# 23    [0.09, 22.09, 1.69, 7.29, 59.29]   90.45
# 24    [0.16, 21.16, 1.96, 6.76, 57.76]    87.8
# 25    [0.25, 20.25, 2.25, 6.25, 56.25]   85.25
# 26    [0.36, 19.36, 2.56, 5.76, 54.76]    82.8
# 27    [0.49, 18.49, 2.89, 5.29, 53.29]   80.45
# 28    [0.64, 17.64, 3.24, 4.84, 51.84]    78.2
# 29    [0.81, 16.81, 3.61, 4.41, 50.41]   76.05
# ..                                 ...     ...
# 71    [26.01, 0.01, 37.21, 4.41, 8.41]   76.05
# 72    [27.04, 0.04, 38.44, 4.84, 7.84]    78.2
# 73    [28.09, 0.09, 39.69, 5.29, 7.29]   80.45
# 74    [29.16, 0.16, 40.96, 5.76, 6.76]    82.8
# 75    [30.25, 0.25, 42.25, 6.25, 6.25]   85.25
# 76    [31.36, 0.36, 43.56, 6.76, 5.76]    87.8
# 77    [32.49, 0.49, 44.89, 7.29, 5.29]   90.45
# 78    [33.64, 0.64, 46.24, 7.84, 4.84]    93.2
# 79    [34.81, 0.81, 47.61, 8.41, 4.41]   96.05
# 80         [36.0, 1.0, 49.0, 9.0, 4.0]      99
# 81    [37.21, 1.21, 50.41, 9.61, 3.61]  102.05
# 82   [38.44, 1.44, 51.84, 10.24, 3.24]   105.2
# 83   [39.69, 1.69, 53.29, 10.89, 2.89]  108.45
# 84   [40.96, 1.96, 54.76, 11.56, 2.56]   111.8
# 85   [42.25, 2.25, 56.25, 12.25, 2.25]  115.25
# 86   [43.56, 2.56, 57.76, 12.96, 1.96]   118.8
# 87   [44.89, 2.89, 59.29, 13.69, 1.69]  122.45
# 88   [46.24, 3.24, 60.84, 14.44, 1.44]   126.2
# 89   [47.61, 3.61, 62.41, 15.21, 1.21]  130.05
# 90        [49.0, 4.0, 64.0, 16.0, 1.0]     134
# 91   [50.41, 4.41, 65.61, 16.81, 0.81]  138.05
# 92   [51.84, 4.84, 67.24, 17.64, 0.64]   142.2
# 93   [53.29, 5.29, 68.89, 18.49, 0.49]  146.45
# 94   [54.76, 5.76, 70.56, 19.36, 0.36]   150.8
# 95   [56.25, 6.25, 72.25, 20.25, 0.25]  155.25
# 96   [57.76, 6.76, 73.96, 21.16, 0.16]   159.8
# 97   [59.29, 7.29, 75.69, 22.09, 0.09]  164.45
# 98   [60.84, 7.84, 77.44, 23.04, 0.04]   169.2
# 99   [62.41, 8.41, 79.21, 24.01, 0.01]  174.05
# 100       [64.0, 9.0, 81.0, 25.0, 0.0]     179
#
# [101 rows x 4 columns]

# %%
df.plot('Candidate', 'Sum')
