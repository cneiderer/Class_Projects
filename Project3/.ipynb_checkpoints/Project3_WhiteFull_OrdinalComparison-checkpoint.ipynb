# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.utils import resample
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import add_dummy_feature
from sklearn.decomposition import PCA

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
import mord

# %% [markdown]
# ### Load and Explore Data

# %%
# df = pd.read_csv('winequality-white.csv', delimiter=';')
df = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.quality.value_counts(sort=False).sort_index()
# Out:
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
corr = df.corr()

# %%
plt.figure(num=None, figsize=(12, 8))
sns.heatmap(corr, center=0, vmin=-1, vmax=1, cmap=sns.diverging_palette(10, 133, sep=80, n=20), annot=True)

# %%
from scipy import stats

# %%
for f in df.columns[:-1]:
    
    print('Feature: %s' % f)
    q_levels1 = df.quality.unique()
    q_levels2 = np.copy(q_levels1)
    
    for q1 in sorted(q_levels1):  
        for q2 in sorted(q_levels2):
            if q1 == q2:
                continue
            else:    
                _, pval = stats.ttest_ind(df[f][df.quality == q1], df[f][df.quality == q2], 0, True)
                print('    Q1: %d vs. Q2: %d, pval: %.3f' % (q1, q2, pval))
        
        print('\n')
        
    print(4*'----------' + '\n')
# Out:
# Feature: fixed acidity
#     Q1: 3 vs. Q2: 4, pval: 0.311
#     Q1: 3 vs. Q2: 5, pval: 0.699
#     Q1: 3 vs. Q2: 6, pval: 0.982
#     Q1: 3 vs. Q2: 7, pval: 0.426
#     Q1: 3 vs. Q2: 8, pval: 0.796
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.311
#     Q1: 4 vs. Q2: 5, pval: 0.083
#     Q1: 4 vs. Q2: 6, pval: 0.026
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.106
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.699
#     Q1: 5 vs. Q2: 4, pval: 0.083
#     Q1: 5 vs. Q2: 6, pval: 0.052
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.290
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.982
#     Q1: 6 vs. Q2: 4, pval: 0.026
#     Q1: 6 vs. Q2: 5, pval: 0.052
#     Q1: 6 vs. Q2: 7, pval: 0.000
#     Q1: 6 vs. Q2: 8, pval: 0.611
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.426
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.000
#     Q1: 7 vs. Q2: 8, pval: 0.536
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.796
#     Q1: 8 vs. Q2: 4, pval: 0.106
#     Q1: 8 vs. Q2: 5, pval: 0.290
#     Q1: 8 vs. Q2: 6, pval: 0.611
#     Q1: 8 vs. Q2: 7, pval: 0.536
#
#
# ----------------------------------------
#
# Feature: volatile acidity
#     Q1: 3 vs. Q2: 4, pval: 0.025
#     Q1: 3 vs. Q2: 5, pval: 0.000
#     Q1: 3 vs. Q2: 6, pval: 0.000
#     Q1: 3 vs. Q2: 7, pval: 0.000
#     Q1: 3 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.025
#     Q1: 4 vs. Q2: 5, pval: 0.000
#     Q1: 4 vs. Q2: 6, pval: 0.000
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.000
#     Q1: 5 vs. Q2: 4, pval: 0.000
#     Q1: 5 vs. Q2: 6, pval: 0.000
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.000
#     Q1: 6 vs. Q2: 4, pval: 0.000
#     Q1: 6 vs. Q2: 5, pval: 0.000
#     Q1: 6 vs. Q2: 7, pval: 0.000
#     Q1: 6 vs. Q2: 8, pval: 0.054
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.000
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.000
#     Q1: 7 vs. Q2: 8, pval: 0.588
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.000
#     Q1: 8 vs. Q2: 4, pval: 0.000
#     Q1: 8 vs. Q2: 5, pval: 0.000
#     Q1: 8 vs. Q2: 6, pval: 0.054
#     Q1: 8 vs. Q2: 7, pval: 0.588
#
#
# ----------------------------------------
#
# Feature: citric acid
#     Q1: 3 vs. Q2: 4, pval: 0.965
#     Q1: 3 vs. Q2: 5, pval: 0.208
#     Q1: 3 vs. Q2: 6, pval: 0.100
#     Q1: 3 vs. Q2: 7, pval: 0.002
#     Q1: 3 vs. Q2: 8, pval: 0.017
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.965
#     Q1: 4 vs. Q2: 5, pval: 0.007
#     Q1: 4 vs. Q2: 6, pval: 0.000
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.208
#     Q1: 5 vs. Q2: 4, pval: 0.007
#     Q1: 5 vs. Q2: 6, pval: 0.004
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.001
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.100
#     Q1: 6 vs. Q2: 4, pval: 0.000
#     Q1: 6 vs. Q2: 5, pval: 0.004
#     Q1: 6 vs. Q2: 7, pval: 0.000
#     Q1: 6 vs. Q2: 8, pval: 0.012
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.002
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.000
#     Q1: 7 vs. Q2: 8, pval: 0.740
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.017
#     Q1: 8 vs. Q2: 4, pval: 0.000
#     Q1: 8 vs. Q2: 5, pval: 0.001
#     Q1: 8 vs. Q2: 6, pval: 0.012
#     Q1: 8 vs. Q2: 7, pval: 0.740
#
#
# ----------------------------------------
#
# Feature: residual sugar
#     Q1: 3 vs. Q2: 4, pval: 0.921
#     Q1: 3 vs. Q2: 5, pval: 0.807
#     Q1: 3 vs. Q2: 6, pval: 0.731
#     Q1: 3 vs. Q2: 7, pval: 0.848
#     Q1: 3 vs. Q2: 8, pval: 0.914
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.921
#     Q1: 4 vs. Q2: 5, pval: 0.406
#     Q1: 4 vs. Q2: 6, pval: 0.302
#     Q1: 4 vs. Q2: 7, pval: 0.908
#     Q1: 4 vs. Q2: 8, pval: 0.800
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.807
#     Q1: 5 vs. Q2: 4, pval: 0.406
#     Q1: 5 vs. Q2: 6, pval: 0.503
#     Q1: 5 vs. Q2: 7, pval: 0.081
#     Q1: 5 vs. Q2: 8, pval: 0.880
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.731
#     Q1: 6 vs. Q2: 4, pval: 0.302
#     Q1: 6 vs. Q2: 5, pval: 0.503
#     Q1: 6 vs. Q2: 7, pval: 0.036
#     Q1: 6 vs. Q2: 8, pval: 0.770
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.848
#     Q1: 7 vs. Q2: 4, pval: 0.908
#     Q1: 7 vs. Q2: 5, pval: 0.081
#     Q1: 7 vs. Q2: 6, pval: 0.036
#     Q1: 7 vs. Q2: 8, pval: 0.671
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.914
#     Q1: 8 vs. Q2: 4, pval: 0.800
#     Q1: 8 vs. Q2: 5, pval: 0.880
#     Q1: 8 vs. Q2: 6, pval: 0.770
#     Q1: 8 vs. Q2: 7, pval: 0.671
#
#
# ----------------------------------------
#
# Feature: chlorides
#     Q1: 3 vs. Q2: 4, pval: 0.222
#     Q1: 3 vs. Q2: 5, pval: 0.083
#     Q1: 3 vs. Q2: 6, pval: 0.003
#     Q1: 3 vs. Q2: 7, pval: 0.000
#     Q1: 3 vs. Q2: 8, pval: 0.002
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.222
#     Q1: 4 vs. Q2: 5, pval: 0.795
#     Q1: 4 vs. Q2: 6, pval: 0.357
#     Q1: 4 vs. Q2: 7, pval: 0.037
#     Q1: 4 vs. Q2: 8, pval: 0.224
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.083
#     Q1: 5 vs. Q2: 4, pval: 0.795
#     Q1: 5 vs. Q2: 6, pval: 0.003
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.056
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.003
#     Q1: 6 vs. Q2: 4, pval: 0.357
#     Q1: 6 vs. Q2: 5, pval: 0.003
#     Q1: 6 vs. Q2: 7, pval: 0.006
#     Q1: 6 vs. Q2: 8, pval: 0.078
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.000
#     Q1: 7 vs. Q2: 4, pval: 0.037
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.006
#     Q1: 7 vs. Q2: 8, pval: 0.246
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.002
#     Q1: 8 vs. Q2: 4, pval: 0.224
#     Q1: 8 vs. Q2: 5, pval: 0.056
#     Q1: 8 vs. Q2: 6, pval: 0.078
#     Q1: 8 vs. Q2: 7, pval: 0.246
#
#
# ----------------------------------------
#
# Feature: free sulfur dioxide
#     Q1: 3 vs. Q2: 4, pval: 0.690
#     Q1: 3 vs. Q2: 5, pval: 0.086
#     Q1: 3 vs. Q2: 6, pval: 0.137
#     Q1: 3 vs. Q2: 7, pval: 0.356
#     Q1: 3 vs. Q2: 8, pval: 0.594
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.690
#     Q1: 4 vs. Q2: 5, pval: 0.002
#     Q1: 4 vs. Q2: 6, pval: 0.015
#     Q1: 4 vs. Q2: 7, pval: 0.248
#     Q1: 4 vs. Q2: 8, pval: 0.700
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.086
#     Q1: 5 vs. Q2: 4, pval: 0.002
#     Q1: 5 vs. Q2: 6, pval: 0.028
#     Q1: 5 vs. Q2: 7, pval: 0.001
#     Q1: 5 vs. Q2: 8, pval: 0.157
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.137
#     Q1: 6 vs. Q2: 4, pval: 0.015
#     Q1: 6 vs. Q2: 5, pval: 0.028
#     Q1: 6 vs. Q2: 7, pval: 0.040
#     Q1: 6 vs. Q2: 8, pval: 0.308
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.356
#     Q1: 7 vs. Q2: 4, pval: 0.248
#     Q1: 7 vs. Q2: 5, pval: 0.001
#     Q1: 7 vs. Q2: 6, pval: 0.040
#     Q1: 7 vs. Q2: 8, pval: 0.761
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.594
#     Q1: 8 vs. Q2: 4, pval: 0.700
#     Q1: 8 vs. Q2: 5, pval: 0.157
#     Q1: 8 vs. Q2: 6, pval: 0.308
#     Q1: 8 vs. Q2: 7, pval: 0.761
#
#
# ----------------------------------------
#
# Feature: total sulfur dioxide
#     Q1: 3 vs. Q2: 4, pval: 0.215
#     Q1: 3 vs. Q2: 5, pval: 0.007
#     Q1: 3 vs. Q2: 6, pval: 0.045
#     Q1: 3 vs. Q2: 7, pval: 0.340
#     Q1: 3 vs. Q2: 8, pval: 0.351
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.215
#     Q1: 4 vs. Q2: 5, pval: 0.000
#     Q1: 4 vs. Q2: 6, pval: 0.200
#     Q1: 4 vs. Q2: 7, pval: 0.805
#     Q1: 4 vs. Q2: 8, pval: 0.706
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.007
#     Q1: 5 vs. Q2: 4, pval: 0.000
#     Q1: 5 vs. Q2: 6, pval: 0.000
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.009
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.045
#     Q1: 6 vs. Q2: 4, pval: 0.200
#     Q1: 6 vs. Q2: 5, pval: 0.000
#     Q1: 6 vs. Q2: 7, pval: 0.008
#     Q1: 6 vs. Q2: 8, pval: 0.215
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.340
#     Q1: 7 vs. Q2: 4, pval: 0.805
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.008
#     Q1: 7 vs. Q2: 8, pval: 0.845
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.351
#     Q1: 8 vs. Q2: 4, pval: 0.706
#     Q1: 8 vs. Q2: 5, pval: 0.009
#     Q1: 8 vs. Q2: 6, pval: 0.215
#     Q1: 8 vs. Q2: 7, pval: 0.845
#
#
# ----------------------------------------
#
# Feature: density
#     Q1: 3 vs. Q2: 4, pval: 0.109
#     Q1: 3 vs. Q2: 5, pval: 0.478
#     Q1: 3 vs. Q2: 6, pval: 0.183
#     Q1: 3 vs. Q2: 7, pval: 0.054
#     Q1: 3 vs. Q2: 8, pval: 0.018
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.109
#     Q1: 4 vs. Q2: 5, pval: 0.013
#     Q1: 4 vs. Q2: 6, pval: 0.797
#     Q1: 4 vs. Q2: 7, pval: 0.171
#     Q1: 4 vs. Q2: 8, pval: 0.009
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.478
#     Q1: 5 vs. Q2: 4, pval: 0.013
#     Q1: 5 vs. Q2: 6, pval: 0.000
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.183
#     Q1: 6 vs. Q2: 4, pval: 0.797
#     Q1: 6 vs. Q2: 5, pval: 0.000
#     Q1: 6 vs. Q2: 7, pval: 0.002
#     Q1: 6 vs. Q2: 8, pval: 0.004
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.054
#     Q1: 7 vs. Q2: 4, pval: 0.171
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.002
#     Q1: 7 vs. Q2: 8, pval: 0.100
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.018
#     Q1: 8 vs. Q2: 4, pval: 0.009
#     Q1: 8 vs. Q2: 5, pval: 0.000
#     Q1: 8 vs. Q2: 6, pval: 0.004
#     Q1: 8 vs. Q2: 7, pval: 0.100
#
#
# ----------------------------------------
#
# Feature: pH
#     Q1: 3 vs. Q2: 4, pval: 0.787
#     Q1: 3 vs. Q2: 5, pval: 0.053
#     Q1: 3 vs. Q2: 6, pval: 0.104
#     Q1: 3 vs. Q2: 7, pval: 0.028
#     Q1: 3 vs. Q2: 8, pval: 0.082
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.787
#     Q1: 4 vs. Q2: 5, pval: 0.000
#     Q1: 4 vs. Q2: 6, pval: 0.005
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.028
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.053
#     Q1: 5 vs. Q2: 4, pval: 0.000
#     Q1: 5 vs. Q2: 6, pval: 0.118
#     Q1: 5 vs. Q2: 7, pval: 0.242
#     Q1: 5 vs. Q2: 8, pval: 0.299
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.104
#     Q1: 6 vs. Q2: 4, pval: 0.005
#     Q1: 6 vs. Q2: 5, pval: 0.118
#     Q1: 6 vs. Q2: 7, pval: 0.028
#     Q1: 6 vs. Q2: 8, pval: 0.171
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.028
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.242
#     Q1: 7 vs. Q2: 6, pval: 0.028
#     Q1: 7 vs. Q2: 8, pval: 0.537
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.082
#     Q1: 8 vs. Q2: 4, pval: 0.028
#     Q1: 8 vs. Q2: 5, pval: 0.299
#     Q1: 8 vs. Q2: 6, pval: 0.171
#     Q1: 8 vs. Q2: 7, pval: 0.537
#
#
# ----------------------------------------
#
# Feature: sulphates
#     Q1: 3 vs. Q2: 4, pval: 0.736
#     Q1: 3 vs. Q2: 5, pval: 0.348
#     Q1: 3 vs. Q2: 6, pval: 0.037
#     Q1: 3 vs. Q2: 7, pval: 0.000
#     Q1: 3 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.736
#     Q1: 4 vs. Q2: 5, pval: 0.330
#     Q1: 4 vs. Q2: 6, pval: 0.001
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.005
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.348
#     Q1: 5 vs. Q2: 4, pval: 0.330
#     Q1: 5 vs. Q2: 6, pval: 0.000
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.037
#     Q1: 6 vs. Q2: 4, pval: 0.001
#     Q1: 6 vs. Q2: 5, pval: 0.000
#     Q1: 6 vs. Q2: 7, pval: 0.000
#     Q1: 6 vs. Q2: 8, pval: 0.014
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.000
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.000
#     Q1: 7 vs. Q2: 8, pval: 0.423
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.000
#     Q1: 8 vs. Q2: 4, pval: 0.005
#     Q1: 8 vs. Q2: 5, pval: 0.000
#     Q1: 8 vs. Q2: 6, pval: 0.014
#     Q1: 8 vs. Q2: 7, pval: 0.423
#
#
# ----------------------------------------
#
# Feature: alcohol
#     Q1: 3 vs. Q2: 4, pval: 0.331
#     Q1: 3 vs. Q2: 5, pval: 0.814
#     Q1: 3 vs. Q2: 6, pval: 0.044
#     Q1: 3 vs. Q2: 7, pval: 0.000
#     Q1: 3 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 4 vs. Q2: 3, pval: 0.331
#     Q1: 4 vs. Q2: 5, pval: 0.001
#     Q1: 4 vs. Q2: 6, pval: 0.015
#     Q1: 4 vs. Q2: 7, pval: 0.000
#     Q1: 4 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 5 vs. Q2: 3, pval: 0.814
#     Q1: 5 vs. Q2: 4, pval: 0.001
#     Q1: 5 vs. Q2: 6, pval: 0.000
#     Q1: 5 vs. Q2: 7, pval: 0.000
#     Q1: 5 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 6 vs. Q2: 3, pval: 0.044
#     Q1: 6 vs. Q2: 4, pval: 0.015
#     Q1: 6 vs. Q2: 5, pval: 0.000
#     Q1: 6 vs. Q2: 7, pval: 0.000
#     Q1: 6 vs. Q2: 8, pval: 0.000
#
#
#     Q1: 7 vs. Q2: 3, pval: 0.000
#     Q1: 7 vs. Q2: 4, pval: 0.000
#     Q1: 7 vs. Q2: 5, pval: 0.000
#     Q1: 7 vs. Q2: 6, pval: 0.000
#     Q1: 7 vs. Q2: 8, pval: 0.010
#
#
#     Q1: 8 vs. Q2: 3, pval: 0.000
#     Q1: 8 vs. Q2: 4, pval: 0.000
#     Q1: 8 vs. Q2: 5, pval: 0.000
#     Q1: 8 vs. Q2: 6, pval: 0.000
#     Q1: 8 vs. Q2: 7, pval: 0.010
#
#
# ----------------------------------------

# %%
for f in df.columns[:-1]:
    plt.figure(num=None, figsize=(10, 8))
    for q in sorted(df.quality.unique()):
        sns.distplot(df[f][df.quality == q], hist=False, label=('quality %d: %d' % (q, df[f][df.quality == q].count())))
    plt.legend()

# %%
sns.pairplot(df, hue='quality', diag_kind='kde')
# Out:
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ### Feature Engineering

# %%
def reciprocal(x):
    return 1/x

def negative_reciprocal(x):
    return -1/x

def logarithm(x):
    return np.log(x)

def square_root(x):
    return x ** 0.5

def cube_root(x):
    return x ** (1/3)

def square(x):
    return x ** 2

# %%
tmp = pd.concat([df['volatile acidity'], df['volatile acidity'].apply(lambda x: x ** (2/5)), df['quality']], 
                axis=1, keys=['x', 'x_transform', 'q'])
for q in sorted(tmp.q.unique()):
    sns.distplot(tmp.x_transform[tmp.q==q], hist=False, label=q)

# %% [markdown]
#  ### Bootstrapping Data

# %%
def sample_to_level(orig_df, target_col, level=None):
    
    if level is None:
        level = int(orig_df[target_col].value_counts().median())
        
    resampled = {}
    for idx in df.quality.unique():
        orig = orig_df[df[target_col] == idx]
        resampled[idx] = pd.DataFrame() 
        resampled[idx] = resample(orig, replace=True,
                                  n_samples=level, random_state=129)
    
    resampled_df = pd.concat(resampled, ignore_index=True)
    
    return resampled_df

# %%
resampled_df = sample_to_level(df, 'quality', 1000)

# %%
resampled_df.quality.value_counts()
# Out:
# 7    1000
# 3    1000
# 6    1000
# 5    1000
# 8    1000
# 4    1000
# Name: quality, dtype: int64

# %% [markdown]
# ### Subset Data

# %%
df_subset = df.copy()
df_subset['quality2'] = pd.cut(df.quality, bins=3, labels=[1, 2, 3]).astype('int') #['good', 'medium', 'bad'])

# %%
df_subset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  quality2
# 0      9.4        5         2
# 1      9.8        5         2
# 2      9.8        5         2
# 3      9.8        6         2
# 4      9.4        5         2

# %% [markdown]
# ### Split Data

# %%
# Split 
# y = resampled_df.quality
# X = resampled_df.drop(columns='quality')

y = df_subset.quality2
X = df_subset.drop(columns=['quality', 'quality2'])

# y = df.quality
# X = df.drop(columns='quality')

# X = df[['volatile acidity', 'citric acid', 'total sulfur dioxide', 'density', 'alcohol']]
# X = df[['volatile acidity', 'alcohol']]

# Make sure intercept exists
if ~any(X.columns == 'Intercept'):
    X.insert(0, 'Intercept', 1)
else: 
    X.Intercept = 1
    
# Stratified Split
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, stratify=y, test_size=.7, random_state=1294)

# %% [markdown]
# ### Build Models

# %% [markdown]
# #### Vanilla Logistic w/out Balanced Class Weight

# %%
lr1 = make_pipeline(PolynomialFeatures(degree=2, interaction_only=False), LogisticRegression(C=1e3))
# lr1 = LogisticRegression(C=1e3, random_state=129)
lr1.fit(X_train, y_train)

print(lr1)
# make predictions
lr1_pred = lr1.predict(X_test)
# summarize the fit of the model
print(classification_report(y_test, lr1_pred))
print(confusion_matrix(y_test, lr1_pred))
# Out:
# Pipeline(memory=None,
#      steps=[('polynomialfeatures', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('logisticregression', LogisticRegression(C=1000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False))])
#              precision    recall  f1-score   support
#
#           1       0.71      0.11      0.20        44
#           2       0.87      0.94      0.90       924
#           3       0.52      0.41      0.46       152
#
# avg / total       0.82      0.83      0.82      1120
#
# [[  5  38   1]
#  [  0 866  58]
#  [  2  87  63]]

# %% [markdown]
# #### Balanced Logistic

# %%
lr2 = make_pipeline(PolynomialFeatures(degree=2, interaction_only=False), LogisticRegression(C=1e3, class_weight='balanced', random_state=129))
# lr2 = LogisticRegression(C=1e3, class_weight='balanced', random_state=129)
lr2.fit(X_train, y_train)

print(lr2)

# make predictions
lr2_pred = lr2.predict(X_test)

# summarize the fit of the model
print(classification_report(y_test, lr2_pred))
print(confusion_matrix(y_test, lr2_pred))
# Out:
# Pipeline(memory=None,
#      steps=[('polynomialfeatures', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('logisticregression', LogisticRegression(C=1000.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=129,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False))])
#              precision    recall  f1-score   support
#
#           1       0.19      0.20      0.20        44
#           2       0.91      0.85      0.88       924
#           3       0.47      0.63      0.54       152
#
# avg / total       0.82      0.79      0.80      1120
#
# [[  9  31   4]
#  [ 34 784 106]
#  [  5  51  96]]

# %% [markdown]
# #### Ordinal Logistic Flavors

# %%
# LogisticAT
ordlr1 = mord.LogisticAT(alpha=1e3)
ordlr1.fit(X_train, y_train)

print(ordlr1)
# make predictions
ordlr1_pred = ordlr1.predict(X_test)
# summarize the fit of the model
print(classification_report(y_test, ordlr1_pred))
print(confusion_matrix(y_test, ordlr1_pred))
# Out:
# LogisticAT(alpha=1000.0, max_iter=1000, verbose=0)
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        44
#           2       0.82      1.00      0.90       924
#           3       0.00      0.00      0.00       152
#
# avg / total       0.68      0.82      0.75      1120
#
# [[  0  44   0]
#  [  0 924   0]
#  [  0 152   0]]
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# LogisticIT
ordlr2 = mord.LogisticIT(alpha=100)
ordlr2.fit(X_train, y_train)

print(ordlr2)
# make predictions
ordlr2_pred = ordlr2.predict(X_test)
# summarize the fit of the model
print(classification_report(y_test, ordlr2_pred))
print(confusion_matrix(y_test, ordlr2_pred))
# Out:
# LogisticIT(alpha=100, max_iter=1000, verbose=0)
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        44
#           2       0.82      1.00      0.90       924
#           3       0.00      0.00      0.00       152
#
# avg / total       0.68      0.82      0.75      1120
#
# [[  0  44   0]
#  [  0 923   1]
#  [  0 152   0]]
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# LogisticSE
ordlr3 = mord.LogisticSE(alpha=100)
ordlr3.fit(X_train, y_train)

print(ordlr3)
# make predictions
ordlr3_pred = ordlr3.predict(X_test)
# summarize the fit of the model
print(classification_report(y_test, ordlr3_pred))
print(confusion_matrix(y_test, ordlr3_pred))
# Out:
# LogisticSE(alpha=100, max_iter=100000, verbose=0)
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        44
#           2       0.82      1.00      0.90       924
#           3       0.00      0.00      0.00       152
#
# avg / total       0.68      0.82      0.75      1120
#
# [[  0  44   0]
#  [  0 923   1]
#  [  0 152   0]]
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
