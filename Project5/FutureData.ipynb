# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import pickle

# %%
bike_data_path = '/home/cneiderer/Metis/boston_bike_data/trip_data'

trips_2018 = ['201801_hubway_tripdata.csv', 
              '201802_hubway_tripdata.csv',
              '201803_hubway_tripdata.csv']

# trips_2018 = ['201802_hubway_tripdata.csv']

# %%
df_jan2018 = pd.read_csv(os.path.join(bike_data_path, trips_2018[0]))
df_feb2018 = pd.read_csv(os.path.join(bike_data_path, trips_2018[1]))
df_mar2018 = pd.read_csv(os.path.join(bike_data_path, trips_2018[2]))
df = pd.concat([df_jan2018, df_feb2018, df_mar2018], axis=0)
df.starttime = pd.to_datetime(df.starttime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166734 entries, 0 to 62984
# Data columns (total 15 columns):
# tripduration               166734 non-null int64
# starttime                  166734 non-null datetime64[ns]
# stoptime                   166734 non-null object
# start station id           166734 non-null int64
# start station name         166734 non-null object
# start station latitude     166734 non-null float64
# start station longitude    166734 non-null float64
# end station id             166734 non-null int64
# end station name           166734 non-null object
# end station latitude       166734 non-null float64
# end station longitude      166734 non-null float64
# bikeid                     166734 non-null int64
# usertype                   166734 non-null object
# birth year                 157142 non-null float64
# gender                     166734 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(5), object(4)
# memory usage: 20.4+ MB

# %%
df = pd.concat([df_jan2018, df_feb2018, df_mar2018], axis=0)

# %%
min(df.starttime), max(df.starttime)
# Out:
# ('2018-01-01 00:16:33', '2018-03-31 23:58:30')

# %%
df = df.set_index('starttime')
df = df.sort_index()

# %%
df
# Out:
#                      tripduration             stoptime  start station id  \
# starttime
# 2018-01-01 00:16:33           388  2018-01-01 00:23:01               178
# 2018-01-01 00:42:00           265  2018-01-01 00:46:25                78
# 2018-01-01 00:42:44          1167  2018-01-01 01:02:11                16
# 2018-01-01 00:56:50           855  2018-01-01 01:11:06                69
# 2018-01-01 01:07:54           487  2018-01-01 01:16:02                 4
# 2018-01-01 01:15:59            81  2018-01-01 01:17:21                31
# 2018-01-01 01:35:37           417  2018-01-01 01:42:35                51
# 2018-01-01 01:35:46           564  2018-01-01 01:45:11               189
# 2018-01-01 01:45:04           515  2018-01-01 01:53:40               108
# 2018-01-01 01:56:58           555  2018-01-01 02:06:13               185
# 2018-01-01 02:01:28           400  2018-01-01 02:08:09                95
# 2018-01-01 02:06:06           293  2018-01-01 02:10:59               218
# ...

# %%
df_week = df.bikeid.resample('w').count()

# %%
# Out:
# starttime
# 2018-01-07     2639
# 2018-01-14     9171
# 2018-01-21    10394
# 2018-01-28    12948
# 2018-02-04    11474
# 2018-02-11    12388
# 2018-02-18    16378
# 2018-02-25    17626
# 2018-03-04    17839
# 2018-03-11    12855
# 2018-03-18    10059
# 2018-03-25    14406
# 2018-04-01    18557
# Freq: W-SUN, Name: bikeid, dtype: int64

# %%
with open('future.pkl', 'wb') as f:
    pickle.dump(df, f)

# %% [markdown]
# ### Data Extension

# %%
with open('new_clean.pkl', 'rb') as f:
    new_df = pickle.load(f)
    
with open('old_clean.pkl', 'rb') as f:
    old_df = pickle.load(f)

# %%
new_df.head()
# Out:
#    Duration           StartTime            StopTime  StartID  \
# 0       196 2016-11-01 00:00:35 2016-11-01 00:03:52       95
# 1       222 2016-11-01 00:01:23 2016-11-01 00:05:06       23
# 2       483 2016-11-01 00:04:19 2016-11-01 00:12:22      178
# 3       141 2016-11-01 00:05:31 2016-11-01 00:07:53       25
# 4       154 2016-11-01 00:05:59 2016-11-01 00:08:34       76
#
#                                            StartName   StartLat   StartLon  \
# 0        Cambridge St - at Columbia St / Webster Ave  42.372969 -71.094445
# 1                 Mayor Martin J Walsh - 28 State St  42.358920 -71.057629
# 2                    MIT Pacific St at Purrington St  42.359573 -71.101295
# 3                           Tremont St / W Newton St  42.341332 -71.076847
# 4  Central Sq Post Office / Cambridge City Hall a...  42.366426 -71.105495
#
#    StopID                                        StopName    StopLat  \
# 0      78                       Union Square - Somerville  42.379637
# ...

# %%
old_df.head()
# Out:
#    Duration           StartTime            StopTime StartID  \
# 0       397 2014-12-31 23:58:00 2015-01-01 00:05:00  B32004
# 1       543 2014-12-31 23:51:00 2015-01-01 00:00:00  M32006
# 2       928 2014-12-31 23:30:00 2014-12-31 23:46:00  D32005
# 3       270 2014-12-31 23:26:00 2014-12-31 23:31:00  B32004
# 4       960 2014-12-31 23:07:00 2014-12-31 23:23:00  D32010
#
#                                   StartName  StopID  \
# 0      Aquarium Station - 200 Atlantic Ave.  D32022
# 1              MIT at Mass Ave / Amherst St  M32007
# 2  Boston Public Library - 700 Boylston St.  A32008
# 3      Aquarium Station - 200 Atlantic Ave.  A32010
# 4                  Cross St. at Hanover St.  B32004
#
#                                       StopName  BikeID    UserType  ZipCode  \
# 0       TD Garden - Causeway at Portal Park #1  T01335  Subscriber   2148.0
# 1  Cambridge St - at Columbia St / Webster Ave  T01426  Subscriber   2143.0
# ...

# %%
new_df[['StartTime', ['']]
