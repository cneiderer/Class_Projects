# %% [markdown]
# # Linear Regression and Learning Curve Challenges

# %%
import pandas as pd
import numpy as np
import pickle
import random

import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# Generate (fake) data that is linearly related to `log(x)`.
#
# You are making this model up. It is of the form `B0 + B1*log(x) + epsilon`. (You are making up the parameters.)
#
# Simulate some data from this model.
#
# Then fit two models to it:
#
#  * quadratic (second degree polynomial)
#  * logarithmic (`log(x)`)
#
# (The second one should fit really well, since it has the same form as the underlying model!)

# %% [markdown]
# ### Generate Data

# %%
from IPython.core.pylabtools import figsize
figsize(10, 10)
plt.style.use('fivethirtyeight')

np.random.seed(129)

def f(x):
    return np.log(x)

n_samples = 1000
# Generate the x values from the random uniform distribution between 0 and 1
X1 = np.random.uniform(0, 15, size=n_samples)
# Generate the y values by taking the sin and adding a random Gaussian (normal) noise term
y1 = f(X1) + np.random.normal(scale=0.25, size=n_samples)

x_plot = np.linspace(0, 15, n_samples)
# Plot the training data against what we know to be the ground truth sin function
fig, ax = plt.subplots(1,1);
ax.plot(x_plot, f(x_plot), label='ground truth', color='green', lw=2)
ax.scatter(X1, y1, label='data', lw=1)
ax.set_ylim((-5, 5))
ax.set_xlim((-1, 15))
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.legend()
# Out:
# /home/cneiderer/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ### Create Features

# %%
intercept1 = np.ones((len(X1), 1))
X1 = np.reshape(X1, (len(X1), 1))
y1 = np.reshape(y1, (len(y1), 1))

# %%
df1 = pd.DataFrame(np.concatenate([y1, intercept1, X1], axis=1), columns=['Y', 'Intercept', 'X'])

# %%
df1['X_2'] = df1['X'] ** 2
df1['Log_X'] = df1['X'].map(np.log)

# %% [markdown]
# ### Fit Polynomial Model

# %%
# Generate Design Matrices
y, X = patsy.dmatrices('Y ~ X_2', data=df1, return_type="dataframe")
# Create your model
model = sm.OLS(y, X)
# Fit your model to your training set
fit = model.fit()
# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.538
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     1161.
# Date:                Wed, 31 Jan 2018   Prob (F-statistic):          2.06e-169
# Time:                        17:55:36   Log-Likelihood:                -1031.5
# No. Observations:                1000   AIC:                             2067.
# Df Residuals:                     998   BIC:                             2077.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8996      0.031     28.625      0.000       0.838       0.961
# ...

# %% [markdown]
# ### Fit Log Model

# %%
# Generate Design Matrices
y, X = patsy.dmatrices('Y ~ Log_X', data=df1, return_type="dataframe")
# Create your model
model = sm.OLS(y, X)
# Fit your model to your training set
fit = model.fit()
# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.522e+04
# Date:                Wed, 31 Jan 2018   Prob (F-statistic):               0.00
# Time:                        17:55:37   Log-Likelihood:                -23.206
# No. Observations:                1000   AIC:                             50.41
# Df Residuals:                     998   BIC:                             60.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0064      0.016      0.407      0.684      -0.024       0.037
# ...

# %% [markdown]
# ## Challenge 2
#
# Generate (fake) data from a model of the form `B0 + B1*x + B2*x^2 + epsilon`. (You are making up the parameters.)
#
# Split the data into a training and test set.
#
# Fit a model to your training set. Calculate mean squared error on your training set. Then calculate it on your test set.
#
# (You could use `sklearn.metrics.mean_squared_error`.)

# %% [markdown]
# ### Generate Data

# %%
from IPython.core.pylabtools import figsize
figsize(10, 10)
plt.style.use('fivethirtyeight')

np.random.seed(129)

def f(x):
    return x + x ** 2

n_samples = 1000
# Generate the x values from the random uniform distribution between 0 and 1
X2 = np.random.uniform(-12, 12, size=n_samples)
# Generate the y values by taking the sin and adding a random Gaussian (normal) noise term
y2 = f(X2) + np.random.normal(scale=5, size=n_samples)

x_plot = np.linspace(-10, 10, n_samples)
# Plot the training data against what we know to be the ground truth sin function
fig, ax = plt.subplots(1,1);
ax.plot(x_plot, f(x_plot), label='ground truth', color='green', lw=2)
ax.scatter(X2, y2, label='data', lw=1)
ax.set_ylim((-10, 100))
ax.set_xlim((-12, 12))
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.legend()

# %% [markdown]
# ### Create Features

# %%
intercept2 = np.ones((len(X2), 1))
y2 = np.reshape(y2, (len(y2), 1))
X2 = np.reshape(X2, (len(X2), 1))

# %%
df2 = pd.DataFrame(np.concatenate([y2, intercept2, X2], axis=1), columns=['Y', 'Intercept', 'X'])

# %%
df2['X_2'] = df2['X'] ** 2

# %% [markdown]
# ### Split Data

# %%
# Split data
X_train2, X_test2, y_train2, y_test2 = train_test_split(df2[['Intercept', 'X', 'X_2']], df2['Y'], 
                                                        test_size=0.3, random_state=129)

# %%
lr = LinearRegression(fit_intercept=True, normalize=False)
lr.fit(X_train2, y_train2)
lr.score(X_test2, y_test2)
# Out:
# 0.98814824903529419

# %%
print('MSE Training:', mean_squared_error(y_train2, lr.predict(X_train2)))
print('MSE Test:', mean_squared_error(y_test2, lr.predict(X_test2)))
# Out:
# MSE Training: 24.7578529563
# MSE Test: 24.0283501688

# %% [markdown]
# ## Challenge 3
#
# For the data from two (above), try polynomial fits from 0th (just constant) to 7th order (highest term x^7). Over the x axis of model degree (8 points), plot:
#
#  * training error
#  * test error
#  * R squared
#  * AIC

# %%
def score_degree_models(deg, X, y):
    
    results = {'train_error': np.ones((len(degree), 1)),
               'test_error': np.ones((len(degree), 1)),
               'r_squared': np.zeros((len(degree), 1)),
               'aic': np.zeros((len(degree), 1))}
    for deg in degree:
        X_train, X_test, y_train, y_test = train_test_split(np.concatenate([intercept, X**deg], axis=1), y,
                                                            test_size=0.3, random_state=129)
        est = make_pipeline(PolynomialFeatures(deg), LinearRegression())    
        est.fit(X_train, y_train)
        results['r_squared'][deg] = est.score(X_test, y_test)
        results['train_error'][deg] = mean_squared_error(y_train, est.predict(X_train))
        results['test_error'][deg] = mean_squared_error(y_test, est.predict(X_test))
        
        return results

# %%
len(scores['r_squared']), len(degree)
# Out:
# (8, 8)

# %%
degree = np.arange(0, 8)
scores = score_degree_models(degree, X1, y1)
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
ax[0,0].scatter(degree, scores[key], label=key, color='b')
ax[1,0].set_ylabel(key)
    ax.set_xlabel('degree')
    ax.legend()

# %% [markdown]
# ## Challenge 4
#
# For the data from two (above), fit a model to only the first 5 of your data points (m=5). Then to first 10 (m=10). Then to first 15 (m=15). In this manner, keep fitting until you fit your entire training set. For each step, calculate the training error and the test error. Plot both (in the same plot) over m. This is called a learning curve.

# %%
np.reshape(X1, (len(X1), 1)).shape
