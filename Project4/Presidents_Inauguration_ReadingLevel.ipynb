# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import spacy
import textstat

# %%
df = pd.read_csv('/home/cneiderer/Downloads/inaug_speeches_mod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date                                               text
# 0  Thursday, April 30, 1789             Fellow-Citizens of the Senate and o...
# 1     Monday, March 4, 1793              Fellow Citizens:  I AM again calle...
# 2   Saturday, March 4, 1797              WHEN it was first perceived, in ea...
# 3  Wednesday, March 4, 1801              Friends and Fellow-Citizens:  CALL...
# 4     Monday, March 4, 1805              PROCEEDING, fellow-citizens, to th...

# %%
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# %%
docs = list(df.text)
len(docs)
# Out:
# 58

# %%
from textstat.textstat import textstat

# %%
for idx, doc in enumerate(docs):
#     print(textstat.automated_readability_index(doc))
#     print('%s: %.2f' % (df['Name'][idx], textstat.text_standard(doc)))
    print(df['Name'][idx], '\n==========')
    print(textstat.flesch_reading_ease(doc))
    print(textstat.smog_index(doc))
    print(textstat.flesch_kincaid_grade(doc))
    print(textstat.coleman_liau_index(doc))
    print(textstat.automated_readability_index(doc))
    print(textstat.dale_chall_readability_score(doc))
    print(textstat.difficult_words(doc))
    print(textstat.linsear_write_formula(doc))
    print(textstat.gunning_fog(doc))
    print(textstat.text_standard(doc))
    print('\n')
# Out:
# George Washington
# ...
# 8.55
# 22.1
# 27.5
# 12.84
# 33.3
# 10.75
# 365
# 26.25
# 37.0312543798178
# 12th and 13th grade
#
#
# George Washington
# ...
# 20.25
# 17.7
# 18.8
# 11.33
# 18.2
# 9.87
# 39
# 11.875
# 27.075555555555553
# 11th and 12th grade
#
#
# John Adams
# ...
# 7.94
# 21.7
# 27.7
# 12.55
# 33.4
# 10.37
# 532
# 25.5
# 36.22429003021148
# 12th and 13th grade
#
#
# Thomas Jefferson
# ...
# 37.41
# 16.6
# 18.5
# 12.09
# 22.6
# 9.17
# 376
# 26.75
# 27.51946418171229
# 27th and 28th grade
#
#
# Thomas Jefferson
# ...
# 31.32
# 17.9
# 20.8
# 12.49
# 26.0
# 9.52
# 479
# 17.833333333333332
# 30.04270746407047
# 17th and 18th grade
#
#
# James Madison
# ...
# 14.74
# 20.3
# 25.1
# 12.43
# 29.9
# 10.57
# 309
# 15.166666666666666
# 34.897084398976986
# 34th and 35th grade
#
#
# James Madison
# ...
# 34.22
# 16.4
# 17.6
# 11.79
# 20.0
# 9.38
# 301
# 15.833333333333334
# 26.6304132231405
# 15th and 16th grade
#
#
# James Monroe
# ...
# 43.66
# 14.8
# 14.0
# 11.49
# 15.4
# 8.13
# 668
# 17.0
# 20.895847935847936
# ...
