# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import spacy
import textstat
import textblob

# %%
df = pd.read_csv('/home/cneiderer/Downloads/inaug_speeches_mod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date                                               text
# 0  Thursday, April 30, 1789             Fellow-Citizens of the Senate and o...
# 1     Monday, March 4, 1793              Fellow Citizens:  I AM again calle...
# 2   Saturday, March 4, 1797              WHEN it was first perceived, in ea...
# 3  Wednesday, March 4, 1801              Friends and Fellow-Citizens:  CALL...
# 4     Monday, March 4, 1805              PROCEEDING, fellow-citizens, to th...

# %%
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# %%
docs = list(df.text)
len(docs)
# Out:
# 58

# %%
from textstat.textstat import textstat

# %%
for idx, doc in enumerate(docs):
#     print(textstat.automated_readability_index(doc))
#     print('%s: %.2f' % (df['Name'][idx], textstat.text_standard(doc)))
    print(df['Name'][idx], '\n==========')
    print(textblob.TextBlob(doc).sentiment)
    print('\n')
# Out:
# George Washington
# ...
# Sentiment(polarity=0.20409989875715678, subjectivity=0.42919372294372315)
#
#
# George Washington
# ...
# Sentiment(polarity=0.012777777777777782, subjectivity=0.315)
#
#
# John Adams
# ...
# Sentiment(polarity=0.17336012435277134, subjectivity=0.4608487019516431)
#
#
# Thomas Jefferson
# ...
# Sentiment(polarity=0.2354787414965986, subjectivity=0.5395680272108843)
#
#
# Thomas Jefferson
# ...
# Sentiment(polarity=0.12462612618862617, subjectivity=0.4034314065564069)
#
#
# James Madison
# ...
# Sentiment(polarity=0.21747610513739546, subjectivity=0.4733137054104795)
#
#
# James Madison
# ...
# Sentiment(polarity=0.10456119604390882, subjectivity=0.46984889814677044)
#
#
# James Monroe
# ...
# Sentiment(polarity=0.25356938135240015, subjectivity=0.4864496038552645)
#
#
# James Monroe
# ...
# Sentiment(polarity=0.17629732606251947, subjectivity=0.497537221832802)
#
#
# John Quincy Adams
# ...
# Sentiment(polarity=0.156065848965849, subjectivity=0.40134409294409296)
#
#
# Andrew Jackson
# ...

# %%
from nltk.tokenize import sent_tokenize

# %%
for idx, doc in enumerate(docs):
    print(df['Name'][idx], '\n==========')    
    for sent in textblob.blob.sent_tokenize(doc):
        print(textblob.TextBlob(sent).sentiment)
    print('\n')
# Out:
# George Washington
# ...
# Sentiment(polarity=0.3, subjectivity=0.4666666666666666)
# Sentiment(polarity=0.23333333333333336, subjectivity=0.48333333333333334)
# Sentiment(polarity=0.375, subjectivity=0.655)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.00416666666666667, subjectivity=0.2333333333333333)
# Sentiment(polarity=0.15625, subjectivity=0.1875)
# Sentiment(polarity=0.2788690476190476, subjectivity=0.4191964285714286)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.16818181818181815, subjectivity=0.41818181818181815)
# Sentiment(polarity=0.04444444444444442, subjectivity=0.3111111111111111)
# Sentiment(polarity=0.34545454545454546, subjectivity=0.5848484848484848)
# Sentiment(polarity=0.0, subjectivity=0.75)
# Sentiment(polarity=0.21111111111111114, subjectivity=0.5277777777777778)
# Sentiment(polarity=0.23194444444444448, subjectivity=0.4930555555555556)
# Sentiment(polarity=0.3163265306122449, subjectivity=0.4392857142857142)
# ...
