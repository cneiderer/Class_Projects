# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
import spacy
import textstat

# %%
df = pd.read_csv('/home/cneiderer/Downloads/inaug_speeches_mod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date                                               text
# 0  Thursday, April 30, 1789             Fellow-Citizens of the Senate and o...
# 1     Monday, March 4, 1793              Fellow Citizens:  I AM again calle...
# 2   Saturday, March 4, 1797              WHEN it was first perceived, in ea...
# 3  Wednesday, March 4, 1801              Friends and Fellow-Citizens:  CALL...
# 4     Monday, March 4, 1805              PROCEEDING, fellow-citizens, to th...

# %%
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# %%
docs = list(df.text)
len(docs)
# Out:
# 58

# %%
from textstat.textstat import textstat

# %%
docs[1]
# Out:
# '            Fellow Citizens:  I AM again called upon by the voice of my country to execute the functions of its Chief Magistrate. When the occasion proper for it shall arrive, I shall endeavor to express the high sense I entertain of this distinguished honor, and of the confidence which has been reposed in me by the people of united America. Previous to the execution of any official act of the President the Constitution requires an oath of office. This oath I am now about to take, and in your presence: That if it shall be found during my administration of the Government I have in any instance violated willingly or knowingly the injunctions thereof, I may (besides incurring constitutional punishment) be subject to the upbraidings of all who are now witnesses of the present solemn ceremony.           '

# %%
for idx, doc in enumerate(docs):

    print(df['Name'][idx], '\n==========')
    
    print(textstat.lexicon_count(doc))
    print(textstat.sentence_count(doc))
    
    print(textstat.difficult_words(doc))
    print(textstat.avg_syllables_per_word(doc))
    print(textstat.avg_letter_per_word(doc))  
    print(textstat.avg_sentence_length(doc))
    print(textstat.avg_sentence_per_word(doc))    

    print('\n')
# Out:
# George Washington
# ...
# 1427
# 23
# 365
# 1.6
# 5.04
# 62.0
# 0.02
#
#
# George Washington
# ...
# 135
# 4
# 39
# 1.8
# 4.83
# 33.8
# 0.03
#
#
# John Adams
# ...
# 2317
# 37
# 532
# 1.6
# 4.99
# 62.6
# 0.02
#
#
# Thomas Jefferson
# ...
# 1717
# 41
# 376
# 1.5
# 4.91
# 41.9
# 0.02
#
#
# Thomas Jefferson
# ...
# 2157
# 45
# 479
# 1.5
# 4.98
# 47.9
# 0.02
#
#
# James Madison
# ...
# 1173
# 21
# 309
# 1.6
# 4.97
# 55.9
# 0.02
#
#
# James Madison
# ...
# 1210
# 33
# 301
# 1.6
# 4.91
# 36.7
# 0.03
#
#
# James Monroe
# ...
# 3367
# 123
# 668
# 1.6
# 4.91
# 27.4
# 0.04
#
#
# James Monroe
# ...
# 4450
# 133
# 847
# 1.5
# 4.9
# 33.5
# 0.03
#
#
# John Quincy Adams
# ...
# 2907
# 76
# 676
# 1.6
# 5.11
# 38.3
# 0.03
#
#
# Andrew Jackson
# ...
# 1124
# 25
# 309
# 1.6
# 5.06
# 45.0
# 0.02
#
#
# Andrew Jackson
# ...
# 1171
# 30
# 280
# 1.6
# 5.03
# 39.0
# 0.03
#
#
# Martin Van Buren
# ...
# 3884
# 98
# 914
# 1.6
# 5.05
# 39.6
# 0.03
#
#
# William Henry Harrison
# ...
# 8425
# 219
# 1424
# 1.6
# 4.91
# 38.5
# 0.03
#
#
# James Knox Polk
# ...
# 4792
# 153
# 944
# 1.6
# 4.99
# 31.3
# ...
