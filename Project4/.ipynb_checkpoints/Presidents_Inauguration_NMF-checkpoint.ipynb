# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
import spacy
import nltk
from gensim import corpora, models, similarities, matutils
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

from sklearn.feature_extraction import stop_words as sklearn_stopwords
from nltk.corpus import stopwords as nltk_stopwords

# %%
df = pd.read_csv('/home/cneiderer/Downloads/inaug_speeches_mod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date                                               text
# 0  Thursday, April 30, 1789             Fellow-Citizens of the Senate and o...
# 1     Monday, March 4, 1793              Fellow Citizens:  I AM again calle...
# 2   Saturday, March 4, 1797              WHEN it was first perceived, in ea...
# 3  Wednesday, March 4, 1801              Friends and Fellow-Citizens:  CALL...
# 4     Monday, March 4, 1805              PROCEEDING, fellow-citizens, to th...

# %%
docs = list(df.text)
len(docs)
# Out:
# 58

# %%
import re

# custom stop words and stop phrases
custom_stopwords = ['mr', 'miss', 'vice president', 'chief justice', 'united states', 'god bless', 
                    'fellow citizens', 'fellow-citizens', 'government']
docs_orig = docs.copy()
for wd in custom_stopwords:
    for idx in range(len(docs)):
        docs[idx] = re.sub(wd, ' ', docs[idx], flags=re.I)
        docs[idx] = re.sub('<[Uu]\+\d{4,4}>', ' ', docs[idx])

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
lmtzr = nltk.stem.wordnet.WordNetLemmatizer()
stemmer = nltk.stem.porter.PorterStemmer()

# for idx, doc in enumerate(docs):
    
#     processed_words = []    
#     sentences = sent_tokenize(doc)
#     for sentence in sentences:
#         words = word_tokenize(sentence)
#         for word in words:
#             processed_words.append(lmtzr.lemmatize(word))
# #             processed_words.append(stemmer.stem(word))
# #             processed_words.append(lmtzr.lemmatize(stemmer.stem(word)))
                               
#     docs[idx] = ' '.join(processed_words)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
n_features = 2500
n_topics = 20
n_top_words = 30

# %%
# Helper Function
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words-1:-1]]), '\n')
    print()

# %%
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 4), max_df=0.8, min_df=0.02,    
                                   max_features=n_features,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(docs)

# %%
tfidf.shape
# Out:
# (58, 2500)

# %%
doc_topics = nmf.fit_transform(tfidf)
doc_topics
# Out:
# array([[ 0.42513318,  0.        ,  0.        , ...,  0.00443021,
#          0.        ,  0.        ],
#        [ 0.00510299,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.51411612,  0.04324393,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.06495496,  0.54204363,  0.        , ...,  0.04648778,
#          0.01223186,  0.        ],
#        [ 0.06764986,  0.54690101,  0.        , ...,  0.        ,
#          0.        ,  0.02573574],
#        [ 0.00713087,  0.59141058,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
doc_topics[0]
# Out:
# array([ 0.42513318,  0.        ,  0.        ,  0.00367951,  0.        ,
#         0.        ,  0.        ,  0.02459219,  0.03452581,  0.        ,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.00443021,  0.        ,  0.        ])

# %%
nmf = NMF(n_components=n_topics, random_state=129, alpha=.1, l1_ratio=0.2)
nmf.fit(tfidf)

tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topic #0:
# public states union constitution foreign interests state duties executive powers peace principles present revenue best national duty measures institutions general congress spirit limits war policy circumstances commerce necessary condition experience
#
# Topic #1:
# america today americans let freedom work american make century promise children history journey thank generation know day dreams women forward better millions old story challenges jobs citizens lives god come
#
# Topic #2:
# business congress law tariff legislation enforcement negro policy south laws conditions session trade race amendment international ought taxation proper progress american election methods consideration order feeling treaty employees secure increase
#
# Topic #3:
# public partisan interests service american citizen patriotic extravagance laws federal citizenship concession strife countrymen reform national constitution vicious thrift executive branch al relieve usefulness activity labor benefits business demands exact enforced
#
# Topic #4:
# constitution union states case law slavery surrendered authority minority laws clause congress expressly lawfully slave administration plainly cases constitutional possible territories majority constitution laws offices right perpetual fly provision supreme national constitution
#
# Topic #5:
# war british enemy element honorable render reflect carried received issue reliance spirit sense class practice consideration distinguished placed obligations justice political citizens arms warfare period facility long invites society wanting
#
# Topic #6:
# freedom peace peoples help economic united nations seek security communism know program strength earth faith mankind hope live free nations justice man strive international divided free world purpose human history force areas hopes
#
# Topic #7:
# counsel things set thought purpose justice industrial action men women cost women party vision private processes politics process democratic task look stood duty use opportunity comprehend mere waste means thing wrong
#
# Topic #8:
# thereof reposed oath shall endeavor chief magistrate entertain magistrate ceremony oath office punishment execution instance official requires execute functions distinguished chief endeavor express presence voice constitutional united proper occasion subject solemn act sense
#
# Topic #9:
# democracy speaks know spirit freedom america body mind human years came person continent acted midst sacred freely task day destiny seen early written built faith live maintained like forms create
#
# Topic #10:
# helped leadership emergency discipline respects money recovery national neighbor days action values profit measures hand face dark normal unprecedented lies balance task faced lie efforts failure frankly putting banking old
#
# Topic #11:
# union rights states preservation general exercise powers states rest objects intentions impressed importance necessarily promote considerations connected loss directly expressed event happy policy continue finally concerns liberal liberty stand pursued federal
#
# Topic #12:
# covenant change union man old trying generation justice land fellow possibilities bounty article demanded seek enemy american weapons liberty moment greatness believe learned citizen way meaning child faith achieve day
#
# Topic #13:
# dollar paying specie deal debt best ability laws national honor pay best desirable determination ability method office ultimately question careful greatest public debt public paid prejudice years necessary requires religious follow secure pride
#
# Topic #14:
# principle let man safety honest opinion trusted republican happiness industry wide errors peace error law abuses equal destinies issue steps services confidence freedom majority right reason religious religion unite difficulties
#
# Topic #15:
# new spirit dream strength human rights built new beginning spirit human bible weapons remembered afford mercy basic used continuing armaments physical weakness commitment worthy urge ceremony say respect inauguration moral let weak times
#
# Topic #16:
# war god slaves union altogether let pray address cease drawn gives years conflict seeking came needs said years ago right claimed ago occasion distributed speedily strange course pursued righteous suppose cause colored
#
# Topic #17:
# let sides pledge begin ask final dare globe arms help foe join oppose bear generation americans alliance poverty instruments loyalty man word weakness supporting anew generation absolute truly americans assure disease
#
# Topic #18:
# regards problems tasks republic conditions children children faced cause wish heritage children perils greatness national life self foundations relations affairs mighty industrial days founded experiment responsibility weak success preserved continent able welfare
#
# Topic #19:
# learned test shall strive peace upward today gain strive achieve simple days perfect democracy way truth remember presence said fellow courage dependent peace shall know america races fearful rising live reverse perfection immediately

# %%
component_dicts = []

components = nmf.components_
for index,values in enumerate(components):
    print("topic {}".format(index))
    temp = list(zip(tfidf_feature_names, components[index]))
    print(sorted(temp, key=lambda x: x[1], reverse=True)[:20], "\n")
    
    component_dicts.append(dict(sorted(temp, key=lambda x: x[1], reverse=True)[:20]))
# Out:
# topic 0
#
# topic 16
# [('war', 0.2700051876598889), ('god', 0.14787338907395842), ('slaves', 0.11576796324992562), ('union', 0.10436507036704927), ('altogether', 0.10380253983779525), ('let', 0.10067163829286199), ('pray', 0.10017107060413918), ('address', 0.097773411306053562), ('cease', 0.09418361338786839), ('drawn', 0.088272892441133455), ('gives', 0.08763769829055687), ('years', 0.083237329010409811), ('conflict', 0.070703629119842237), ('seeking', 0.068938892124776316), ('came', 0.064529849772568051), ('needs', 0.064117803497383219), ('said', 0.063626381280283598), ('years ago', 0.061769826582368216), ('right', 0.061666081041997237), ('claimed', 0.056327030279330705)]
#
# topic 17
# [('let', 0.24468727526700634), ('sides', 0.22932953185081076), ('pledge', 0.1339969891641713), ('begin', 0.085839175530956893), ('ask', 0.085175567281813303), ('final', 0.0849694961542838), ('dare', 0.084941360924184639), ('globe', 0.071497645090261144), ('arms', 0.070606811944859474), ('help', 0.069790180760034889), ('foe', 0.062435641979789493), ('join', 0.062241985428133917), ('oppose', 0.058735895052389929), ('bear', 0.058562669347002314), ('generation americans', 0.058055120003680696), ('alliance', 0.058014553352669473), ('poverty', 0.057978314912849611), ('instruments', 0.056465568672226601), ('loyalty', 0.055200798959115463), ('man', 0.052914772052950268)]
#
# topic 18
# [('regards', 0.16468012699665954), ('problems', 0.15884000040678065), ('tasks', 0.12821262639523712), ('republic', 0.11336615573324493), ('conditions', 0.09481125592992741), ('children children', 0.093339086138955057), ('faced', 0.090570735529511434), ('cause', 0.09019392345816897), ('wish', 0.083535313593549085), ('heritage', 0.076559309779415136), ('children', 0.074694397922681496), ('perils', 0.072361436206813401), ('greatness', 0.070729153129635985), ('national life', 0.069114516624661809), ('self', 0.068360761069544571), ('foundations', 0.068266547596048416), ('relations', 0.068221950502799056), ('affairs', 0.066838659357358915), ('mighty', 0.065476379383656719), ('industrial', 0.062105987819488201)]
#
# topic 19
# [('learned', 0.26624467402749724), ('test', 0.16857272184643068), ('shall strive', 0.14951116893026553), ('peace', 0.13097160133415664), ('upward', 0.12571509953536286), ('today', 0.12166805213272498), ('gain', 0.11865096445887853), ('strive', 0.092064171311023846), ('achieve', 0.087754756582026569), ('simple', 0.084113195224400056), ('days', 0.08389596725569648), ('perfect', 0.079195611596715204), ('democracy', 0.078557616778978254), ('way', 0.075263754146156908), ('truth', 0.075057451737894992), ('remember', 0.071730875136646319), ('presence', 0.070129586903993055), ('said', 0.069157916404510592), ('fellow', 0.059330800251298652), ('courage', 0.058802229911889312)]

# %%
ncol = 2
nrow = int(np.ceil(len(component_dicts) / ncol))

figwidth = ncol * 9
figheight = nrow * 5
fig, axes = plt.subplots(nrow, ncol, figsize=(figwidth, figheight))
ax = axes.flatten()

num_words = 20 # Number of words to include in word cloud
for t in range(len(component_dicts)): 
    plt.sca(ax[t])    
    plt.title("Topic #" + str(t))
    plt.axis("off")    
    plt.imshow(WordCloud().fit_words(component_dicts[t]))
