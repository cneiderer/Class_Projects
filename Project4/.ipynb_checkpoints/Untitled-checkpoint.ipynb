# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_json('/home/cneiderer/Downloads/JEOPARDY_QUESTIONS1.json')

# %%
df.head()
# Out:
#      air_date       answer                         category  \
# 0  2004-12-31   Copernicus                          HISTORY
# 1  2004-12-31   Jim Thorpe  ESPN's TOP 10 ALL-TIME ATHLETES
# 2  2004-12-31      Arizona      EVERYBODY TALKS ABOUT IT...
# 3  2004-12-31  McDonald\'s                 THE COMPANY LINE
# 4  2004-12-31   John Adams              EPITAPHS & TRIBUTES
#
#                                             question      round  show_number  \
# 0  'For the last 8 years of his life, Galileo was...  Jeopardy!         4680
# 1  'No. 2: 1912 Olympian; football star at Carlis...  Jeopardy!         4680
# 2  'The city of Yuma in this state has a record a...  Jeopardy!         4680
# 3  'In 1963, live on "The Art Linkletter Show", t...  Jeopardy!         4680
# 4  'Signer of the Dec. of Indep., framer of the C...  Jeopardy!         4680
#
#   value
# 0  $200
# 1  $200
# 2  $200
# 3  $200
# 4  $200

# %%
df.iloc[0, :].question
# Out:
# "'For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory'"

# %%
len(df.category.unique())
# Out:
# 27995

# %%
df_b = pd.read_csv('/home/cneiderer/Downloads/yelp-dataset/yelp_business.csv')

# %%
df_b.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# ...

# %%
cat = df_b.categories

# %%
bidx = []
cat_list = []
comp = []
for idx, kw in enumerate(cat):
    kw = [x.lower() for x in kw.split(';')]
    cat_list += kw
#     result = set(['wineries', 'cideries', 'breweries', 'distilleries']).intersection(kw)
    result = set(['doctors']).intersection(kw)
#     result = set(['distilleries']).intersection(kw)
    if len(result) > 0:
        bidx.append(idx)
        comp.append(result)
        
print(len(bidx))
# Out:
# 4838

# %%
df_bb = df_b.iloc[bidx, :]
df_bb.review_count.sum()
# Out:
# 61232

# %%
pd.pivot_table(df_bb, ='city', aggfunc='count')
# Out:
# city          Ahwatukee  Ajax  Anthem  Aurora  Avon  Avon Lake  Avondale  \
# address               1     4       4       3     3          1        12
# business_id           1     4       4       3     3          1        12
# categories            1     4       4       3     3          1        12
# is_open               1     4       4       3     3          1        12
# latitude              1     4       4       3     3          1        12
# longitude             1     4       4       3     3          1        12
# name                  1     4       4       3     3          1        12
# neighborhood          0     0       0       0     0          0         0
# postal_code           1     4       4       3     3          1        12
# review_count          1     4       4       3     3          1        12
# stars                 1     4       4       3     3          1        12
# state                 1     4       4       3     3          1        12
#
# ...

# %%
cnts = df_bb['city'].value_counts()
cnts
# Out:
# Las Vegas                 235
# Phoenix                   214
# Toronto                   155
# Charlotte                  97
# Scottsdale                 91
# Pittsburgh                 75
# Mesa                       65
# Glendale                   55
# Tempe                      52
# Chandler                   49
# Henderson                  38
# Madison                    33
# Montréal                   30
# Cleveland                  26
# Gilbert                    26
# Champaign                  22
# Peoria                     22
# North Las Vegas            21
# Mississauga                21
# Edinburgh                  15
# Surprise                   15
# North York                 13
# Avondale                   12
# Goodyear                   11
# Markham                    10
# Stuttgart                   9
# Scarborough                 8
# Matthews                    8
# Huntersville                8
# Lakewood                    7
#                          ...
# ...

# %%
cnts[cnts == cnts.max()]
# Out:
# Las Vegas    235
# Name: city, dtype: int64

# %%
df_bb[df_bb.city == 'Las Vegas'].head()
# Out:
#                  business_id                           name neighborhood  \
# 869   _1CdOPPGWdwT3YsVuEUNNA           "The Art of Shaving"    The Strip
# 1767  lzF-nrG9kblOm5eweaBJGg           "The Art of Shaving"    The Strip
# 2596  lrMuq4geWVWDkYIxOdTE2A                     "FairKutz"     Westside
# 2631  y8FfZr8vU0Xapfm-LFuMzg  "Murray's Salon & Barbershop"     Westside
# 2755  qxTtvf73qDcPaFckkGJwVw               "The Tower Club"     Westside
#
#                                      address       city state postal_code  \
# 869   "3663 Las Vegas Blvd. South, Suite 51"  Las Vegas    NV       89109
# 1767         "3200 Las Vegas Blvd, Ste 1790"  Las Vegas    NV       89109
# 2596                    "270 S Decatur Blvd"  Las Vegas    NV       89107
# 2631             "4300 Meadows Ln, Ste 2050"  Las Vegas    NV       89107
# 2755                "430 S Rampart, Ste 150"  Las Vegas    NV       89145
#
#        latitude   longitude  stars  review_count  is_open  \
# ...

# %%
joined = df_bb.merge(df_rev, how='left', on='business_id')

# %%
joined.shape
# Out:
# (27959, 21)

# %%
df_b.city.value_counts()
# Out:
# Las Vegas                    26775
# Phoenix                      17213
# Toronto                      17206
# Charlotte                     8553
# Scottsdale                    8228
# Pittsburgh                    6355
# Mesa                          5760
# Montréal                      5709
# Henderson                     4465
# Tempe                         4263
# Chandler                      3994
# Edinburgh                     3868
# Cleveland                     3322
# Madison                       3213
# Glendale                      3206
# Gilbert                       3128
# Mississauga                   2726
# Stuttgart                     2000
# Peoria                        1706
# Markham                       1564
# North Las Vegas               1393
# Champaign                     1195
# Scarborough                   1095
# North York                    1092
# Surprise                      1018
# Richmond Hill                  888
# Concord                        864
# ...

# %%
df_ba = pd.read_csv('/home/cneiderer/Downloads/yelp-dataset/yelp_business_attributes.csv')

# %%
df_ba.head()
# Out:
#               business_id AcceptsInsurance ByAppointmentOnly  \
# 0  FYWN1wneV18bWNgQjJ2GNg               Na                Na
# 1  He-G7vWjzVUysIKrfNbPUQ               Na                Na
# 2  8DShNS-LuFqpEWIp0HxijA               Na                Na
# 3  PfOCPjBrlQAnz__NXj9h_w               Na                Na
# 4  o9eMRCWt5PkpLDE0gOPtcQ               Na                Na
#
#   BusinessAcceptsCreditCards BusinessParking_garage BusinessParking_street  \
# 0                         Na                   True                     Na
# 1                         Na                     Na                     Na
# 2                         Na                     Na                     Na
# 3                         Na                     Na                     Na
# 4                         Na                     Na                  False
#
#   BusinessParking_validated BusinessParking_lot BusinessParking_valet  \
# 0                        Na                  Na                    Na
# ...

# %%
df_bh = pd.read_csv('/home/cneiderer/Downloads/yelp-dataset/yelp_business_hours.csv')

# %%
df_bh.head()
# Out:
#               business_id     monday    tuesday  wednesday   thursday  \
# 0  FYWN1wneV18bWNgQjJ2GNg  7:30-17:0  7:30-17:0  7:30-17:0  7:30-17:0
# 1  He-G7vWjzVUysIKrfNbPUQ   9:0-20:0   9:0-20:0   9:0-20:0   9:0-20:0
# 2  KQPW8lFf1y5BT2MxiSZ3QA       None       None       None       None
# 3  8DShNS-LuFqpEWIp0HxijA  10:0-21:0  10:0-21:0  10:0-21:0  10:0-21:0
# 4  PfOCPjBrlQAnz__NXj9h_w   11:0-1:0   11:0-1:0   11:0-1:0   11:0-1:0
#
#       friday   saturday     sunday
# 0  7:30-17:0       None       None
# 1   9:0-16:0   8:0-16:0       None
# 2       None       None       None
# 3  10:0-21:0  10:0-21:0  11:0-19:0
# 4   11:0-1:0   11:0-2:0   11:0-0:0

# %%
df_ci = pd.read_csv('/home/cneiderer/Downloads/yelp-dataset/yelp_checkin.csv')
df_ci.head()
# Out:
#               business_id weekday   hour  checkins
# 0  3Mc-LxcqeguOXOVT_2ZtCg     Tue   0:00        12
# 1  SVFx6_epO22bZTZnKwlX7g     Wed   0:00         4
# 2  vW9aLivd4-IorAfStzsHww     Tue  14:00         1
# 3  tEzxhauTQddACyqdJ0OPEQ     Fri  19:00         1
# 4  CEyZU32P-vtMhgqRCaXzMA     Tue  17:00         1

# %%
df_rev = pd.read_csv('/home/cneiderer/Downloads/yelp-dataset/yelp_review.csv')
df_rev.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 2  MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g
# 3  IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA
# 4  L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
# 1      5  2016-05-28  Small unassuming place that changes their menu...
# 2      5  2016-05-28  Lester's is located in a beautiful neighborhoo...
# 3      4  2016-05-28  Love coming here. Yes the place always needs t...
# 4      4  2016-05-28  Had their chocolate almond croissant and it wa...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# ...

# %%
df_rev.shape
# Out:
# (5261668, 9)

# %%
pres_df = pd.read_json('/home/cneiderer/Downloads/presidency.json')

# %%
pres_df
# Out:
#                                                    Abraham Lincoln  \
# Debates                                                         []
# E.O.P.                                                          []
# OMB                                                             []
# Oral             [{'category': 'Address', 'subcategory': 'Inaug...
# Party Platforms                                                 []
# Written          [{'category': 'Messages', 'subcategory': '(non...
#
#                                                     Andrew Jackson  \
# Debates                                                         []
# E.O.P.                                                          []
# OMB                                                             []
# Oral             [{'category': 'Address', 'subcategory': 'Inaug...
# Party Platforms                                                 []
# Written          [{'category': 'Messages', 'subcategory': '(non...
#
# ...

# %%
import pymongo

# %%
client = pymongo.MongoClient()

# %%
client.database_names()
# Out:
# ['admin', 'config', 'legislation', 'local']

# %%
db = client.get_database('president')

# %%
client.database_names()
# Out:
# ['admin', 'config', 'legislation', 'local']

# %%
db.create_collection('data')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'president'), 'data')

# %%
client.database_names()
# Out:
# ['admin', 'config', 'legislation', 'local', 'president']

# %%
collection = db.get_collection('data')

# %%
import json

# %%
json_filename = '/home/cneiderer/Downloads/presidency.json'
with open(json_filename, 'r') as f:
    json_president = json.load(f)

# %%
collection.insert_one(pres_df['Abraham Lincoln']['Oral'][0])

# %%
collection.find_one()['_id']
# Out:
# ObjectId('5a9726dd4ff91e65a4248ed3')

# %%
for item in pres_df['George Washington']['Oral']:
    print(item['title'])
# Out:
# Inaugural Address
# Inaugural Address
# First Annual Message to Congress on the State of the Union
# Second Annual Message
# Third Annual Message
# Fourth Annual Message
# Fifth Annual Message
# Sixth Annual Message
# Seventh Annual Message
# Eighth Annual Message

# %%
len(pres_df['George W. Bush']['Oral'])
# Out:
# 2922

# %%
len(pres_df[''])
# Out:
# 6

# %%
len(pres_df['George Bush'])
# Out:
# 6
