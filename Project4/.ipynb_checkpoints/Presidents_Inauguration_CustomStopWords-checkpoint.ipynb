# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
import spacy
import nltk
from gensim import corpora, models, similarities, matutils
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

from sklearn.feature_extraction import stop_words as sklearn_stopwords
from nltk.corpus import stopwords as nltk_stopwords

# %%
df = pd.read_csv('/home/cneiderer/Downloads/inaug_speeches_mod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Name         Inaugural Address  \
# 0           4  George Washington   First Inaugural Address
# 1           5  George Washington  Second Inaugural Address
# 2           6         John Adams         Inaugural Address
# 3           7   Thomas Jefferson   First Inaugural Address
# 4           8   Thomas Jefferson  Second Inaugural Address
#
#                        Date                                               text
# 0  Thursday, April 30, 1789             Fellow-Citizens of the Senate and o...
# 1     Monday, March 4, 1793              Fellow Citizens:  I AM again calle...
# 2   Saturday, March 4, 1797              WHEN it was first perceived, in ea...
# 3  Wednesday, March 4, 1801              Friends and Fellow-Citizens:  CALL...
# 4     Monday, March 4, 1805              PROCEEDING, fellow-citizens, to th...

# %%
docs = list(df.text)
len(docs)
# Out:
# 58

# %%
import re

# custom stop words and stop phrases
custom_stopwords = ['mr', 'miss', 'vice president', 'chief justice', 'united states', 'god bless', 
                    'fellow citizens', 'fellow-citizens', 'government']
docs_orig = docs.copy()
for wd in custom_stopwords:
    remove = re.compile(wd, re.I)   
    for idx in range(len(docs)):
        docs[idx] = remove.sub(' ', docs[idx])
#         docs[idx] = re.sub(wd, '', docs[idx], flags=re.I)

        docs[idx] = re.sub('<[Uu]\+\d{4,4}>', ' ', docs[idx])

# %%
sw = set(nltk_stopwords.words('english')).union(sklearn_stopwords.ENGLISH_STOP_WORDS)

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
lmtzr = nltk.stem.wordnet.WordNetLemmatizer()
stemmer = nltk.stem.porter.PorterStemmer()

for idx, doc in enumerate(docs):
    
    processed_words = []    
    sentences = sent_tokenize(doc)
    for sentence in sentences:
        words = word_tokenize(sentence)
        for word in words:
            processed_words.append(lmtzr.lemmatize(word))
#             processed_words.append(stemmer.stem(word))
#             processed_words.append(lmtzr.lemmatize(stemmer.stem(word)))
                               
    docs[idx] = ' '.join(processed_words)

# %%
# Create a CountVectorizer for parsing/counting words
count_vectorizer = CountVectorizer(ngram_range=(2, 4), min_df=0.02, max_df=0.8,
                                   max_features=1000,
                                   stop_words=sw)
count_vectorizer.fit(docs)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.8, max_features=1000, min_df=0.02,
#         ngram_range=(2, 4), preprocessor=None,
#         stop_words={"didn't", 'less', 'off', 'with', 'too', 'nine', 'rather', 'whatever', 'out', 'why', 'own', 'therein', 'detail', 'front', 'everywhere', 'where', 'full', 'seems', 'onto', 'two', 'third', 'anyhow', 'con', 'always', 'behind', 'interest', 'keep', 'no', 'above', 'serious', 'few', 'between', 'm...', 'weren', 'towards', 'yourself', "wouldn't", 'whole', 'inc', 'ever', 'that', 'amount', 'formerly'},
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# Create the term-document matrix
# Transpose it so the terms are the rows
counts = count_vectorizer.transform(docs).transpose()

# %%
counts.shape
# Out:
# (1000, 58)

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(counts)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

# %%
len(id2word)
# Out:
# 1000

# %%
# Create lda model (equivalent to "fit" in sklearn)
lda = models.LdaModel(corpus=corpus, 
                      num_topics=3, 
                      alpha=0.2, #'asymmetric',
                      minimum_probability=0.03, 
                      id2word=id2word, passes=10, random_state=129)

# %%
# lda.print_topics()

# %%
# Transform the docs from the word space to the topic space (like "transform" in sklearn)
lda_corpus = lda[corpus]
lda_corpus

# %%
# Store the documents' topic vectors in a list so we can take a peak
lda_docs = [doc for doc in lda_corpus]

# %%
# Check out the document vectors in the topic space for the first 5 documents
for pres in zip(df['Name'], lda_docs):
# for pres in zip(df['Name'], df['Date'], lda_docs):
    print(pres)
# Out:
# ('George Washington', [(2, 0.9835161)])
# ('George Washington', [(0, 0.036167271), (1, 0.036066454), (2, 0.92776632)])
# ('John Adams', [(0, 0.995309)])
# ('Thomas Jefferson', [(0, 0.99012005)])
# ('Thomas Jefferson', [(2, 0.9910298)])
# ('James Madison', [(1, 0.98992217)])
# ('James Madison', [(0, 0.97686243)])
# ('James Monroe', [(1, 0.99639046)])
# ('James Monroe', [(1, 0.99627072)])
# ('John Quincy Adams', [(0, 0.99742639)])
# ('Andrew Jackson', [(0, 0.93356425), (1, 0.061816059)])
# ('Andrew Jackson', [(0, 0.097108088), (1, 0.16432355), (2, 0.73856831)])
# ('Martin Van Buren', [(0, 0.19195867), (1, 0.063642599), (2, 0.74439877)])
# ('William Henry Harrison', [(2, 0.9983989)])
# ('James Knox Polk', [(1, 0.99808139)])
# ('Zachary Taylor', [(2, 0.99381638)])
# ('Franklin Pierce', [(2, 0.99512559)])
# ('James Buchanan', [(2, 0.99731272)])
# ('Abraham Lincoln', [(2, 0.99649292)])
# ('Abraham Lincoln', [(2, 0.97796428)])
# ('Ulysses S. Grant', [(0, 0.99099135)])
# ('Ulysses S. Grant', [(2, 0.98947322)])
# ('Rutherford B. Hayes', [(2, 0.99651384)])
# ('James A. Garfield', [(2, 0.99588269)])
# ('Grover Cleveland', [(1, 0.18175766), (2, 0.81583196)])
# ('Benjamin Harrison', [(2, 0.9968698)])
# ('Grover Cleveland', [(2, 0.99164331)])
# ('William McKinley', [(1, 0.99712014)])
# ('William McKinley', [(2, 0.99473709)])
# ('Theodore Roosevelt', [(2, 0.98789799)])
# ('William Howard Taft', [(1, 0.9971475)])
# ('Woodrow Wilson', [(0, 0.98826939)])
# ('Woodrow Wilson', [(0, 0.98938537)])
# ('Warren G. Harding', [(0, 0.99542475)])
# ('Calvin Coolidge', [(2, 0.99631625)])
# ('Herbert Hoover', [(2, 0.99642485)])
# ('Franklin D. Roosevelt', [(2, 0.99205261)])
# ('Franklin D. Roosevelt', [(0, 0.99450344)])
# ('Franklin D. Roosevelt', [(0, 0.99218136)])
# ('Franklin D. Roosevelt', [(0, 0.23605806), (2, 0.75736862)])
# ('Harry S. Truman', [(0, 0.99557859)])
# ('Dwight D. Eisenhower', [(1, 0.99490124)])
# ('Dwight D. Eisenhower', [(0, 0.99129987)])
# ('John F. Kennedy', [(1, 0.99144167)])
# ('Lyndon Baines Johnson', [(2, 0.98910731)])
# ('Richard Milhous Nixon', [(0, 0.70401561), (1, 0.29292306)])
# ('Richard Milhous Nixon', [(0, 0.99664259)])
# ('Jimmy Carter', [(0, 0.9904533)])
# ('Ronald Reagan', [(0, 0.99378902)])
# ('Ronald Reagan', [(0, 0.78256625), (1, 0.2153101)])
# ('George Bush', [(0, 0.9095192), (1, 0.087414294)])
# ('Bill Clinton', [(0, 0.99382824)])
# ('Bill Clinton', [(0, 0.9958685)])
# ('George W. Bush', [(1, 0.9896853)])
# ('George W. Bush', [(1, 0.99337143)])
# ('Barack Obama', [(0, 0.30792618), (1, 0.68968475)])
# ('Barack Obama', [(0, 0.99486333)])
# ('Donald J. Trump', [(1, 0.99018943)])

# %%
ncol = 2
nrow = int(np.ceil(lda.num_topics / ncol))

figwidth = ncol * 9
figheight = nrow * 5
fig, axes = plt.subplots(nrow, ncol, figsize=(figwidth, figheight))
ax = axes.flatten()

num_words = 30 # Number of words to include in word cloud
for t in range(lda.num_topics): 
    plt.sca(ax[t])    
    plt.title("Topic #" + str(t))
    plt.axis("off")    
    plt.imshow(WordCloud().fit_words(dict(lda.show_topic(t, num_words))))

# %%
# num_words = 30 # Number of words to include in word cloud
# for t in range(lda.num_topics):
#     plt.figure(figsize=(16,12))
#     plt.imshow(WordCloud().fit_words(dict(lda.show_topic(t, num_words))))
#     plt.axis("off")
#     plt.title("Topic #" + str(t))
#     plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %%
n_samples = 2000
n_features = 1000
n_topics = 20
n_top_words = 20

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, min_df=0.02,
                                   max_features=n_features,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(docs)

# %%
nmf = NMF(n_components=n_topics, random_state=129, alpha=.1, l1_ratio=.5).fit(tfidf)

tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topic #0:
# public constitution union states law duty principle peace foreign congress national citizen state party revenue policy opinion war best institution
# Topic #1:
# america freedom today americans let know work child century american generation day man peace earth history old democracy god dream
# Topic #2:
# counsel thought thing purpose set action industrial politics process stand current drawn principle immediate private equally influence task opportunity matter
# Topic #3:
# negro business south tariff race amendment canal congress proper likely law legislation passed issue coast trade prevent feeling court jurisdiction
# Topic #4:
# war god union let drawn slave seeking said came conflict ago occasion cause party southern come agent devoted divide fundamental
# Topic #5:
# war honorable received carried battle reliance sympathy suffering spirit issue sense necessary enemy distinguished element placed practice class consideration arm
# Topic #6:
# program communism democracy peace freedom nations area security economic development help international attack aim benefit believe based strengthen effort desire
# Topic #7:
# let responsibility america role peace abroad home era help respect policy proud better bold structure history greatly challenge resolve ask
# Topic #8:
# oath magistrate execution instance witness requires official distinguished execute chief function express presence endeavor constitutional united voice occasion proper solemn
# Topic #9:
# democracy know spirit body mind human sacred person continent came early written built maintained america create peril destiny measure freedom
# Topic #10:
# helped leadership emergency profit lie money national action neighbor dark effort measure balance face respect task failure restoration attack failed
# Topic #11:
# zeal europe existing existence exist exercised exercise executive execution execute example exalted evil event european establishment enlightened established establish essential
# Topic #12:
# zeal europe existing existence exist exercised exercise executive execution execute example exalted evil event european establishment enlightened established establish essential
# Topic #13:
# dream strength built spirit human afford used worthy weakness commitment respect say weapon moral goal society weak special join strong
# Topic #14:
# story commitment ideal citizen courage promise america birth community defend deep character school child common live responsibility generous small pas
# Topic #15:
# territory best influence office effort section commerce executive restoration exercised subject effect looking civilized scarcely question support receive abuse past
# Topic #16:
# zeal europe existing existence exist exercised exercise executive execution execute example exalted evil event european establishment enlightened established establish essential
# Topic #17:
# island executive congress ion com obligation treaty fundamental order guaranty ago rest american faithful session war purpose liberty relation assured
# Topic #18:
# learned peace today strive way achieve perfect simple said remember presence democracy truth courage fellow friend live given profit structure
# Topic #19:
# ought present house article nature circumstance assure hand heaven recommendation particular instance public humble happiness official station measure department duty

# %%
tfidf_feature_names
# Out:
# ['abiding',
#  'ability',
#  'able',
#  'abroad',
#  'abuse',
#  'accept',
#  'accomplished',
#  'according',
#  'achieve',
#  'achievement',
#  'act',
#  'action',
#  'activity',
#  'actual',
#  'adapted',
#  'add',
#  'added',
#  'additional',
#  'adequate',
#  'administration',
#  'adopt',
#  'adopted',
#  'adoption',
#  'advance',
#  'advanced',
#  'advancement',
#  'advantage',
#  'affair',
#  'affection',
#  'afford',
#  'afforded',
#  'age',
#  'agency',
#  'agent',
#  'aggression',
#  'ago',
#  'agriculture',
#  'aid',
#  'aim',
#  'alike',
#  'alliance',
#  'ally',
#  'almighty',
#  'ambition',
#  'amendment',
#  'america',
#  'american',
#  'americans',
#  'ample',
#  'ancient',
#  'answer',
#  'anxiety',
#  'appeal',
#  'appear',
#  'application',
#  'appointment',
#  'apprehension',
#  'area',
#  'arise',
#  'arm',
#  'armed',
#  'army',
#  'arrangement',
#  'art',
#  'article',
#  'ask',
#  'aspiration',
#  'assume',
#  'assurance',
#  'assure',
#  'assured',
#  'attack',
#  'attempt',
#  'attention',
#  'authority',
#  'avoid',
#  'away',
#  'bad',
#  'balance',
#  'based',
#  'basis',
#  'battle',
#  'bear',
#  'bearing',
#  'began',
#  'begin',
#  'beginning',
#  'belief',
#  'believe',
#  'believed',
#  'belongs',
#  'beneficent',
#  'benefit',
#  'best',
#  'better',
#  'bind',
#  'birth',
#  'blessed',
#  'blessing',
#  'blood',
#  'body',
#  'bold',
#  'bond',
#  'born',
#  'bound',
#  'branch',
#  'break',
#  'bring',
#  'brought',
#  'build',
#  'building',
#  'built',
#  'burden',
#  'business',
#  'called',
#  'came',
#  'canal',
#  'capacity',
#  'capital',
#  'care',
#  'careful',
#  'carried',
#  'carry',
#  'case',
#  'cause',
#  'celebrate',
#  'century',
#  'certain',
#  'certainly',
#  'challenge',
#  'chance',
#  'change',
#  'changed',
#  'character',
#  'cheerfully',
#  'cherish',
#  'cherished',
#  'chief',
#  'child',
#  'choice',
#  'chosen',
#  'circumstance',
#  'citizen',
#  'citizenship',
#  'city',
#  'civil',
#  'civilization',
#  'civilized',
#  'claim',
#  'class',
#  'clear',
#  'clearly',
#  'close',
#  'coast',
#  'com',
#  'combination',
#  'come',
#  'comfort',
#  'coming',
#  'command',
#  'commerce',
#  'commercial',
#  'commitment',
#  'committed',
#  'common',
#  'communism',
#  'community',
#  'competent',
#  'complete',
#  'compromise',
#  'concern',
#  'concession',
#  'condition',
#  'conduct',
#  'confederacy',
#  'confidence',
#  'conflict',
#  'congress',
#  'connected',
#  'conscience',
#  'consciousness',
#  'consent',
#  'consequence',
#  'consider',
#  'consideration',
#  'considered',
#  'consistent',
#  'constant',
#  'constantly',
#  'constitution',
#  'constitutional',
#  'construction',
#  'contest',
#  'continent',
#  'continuance',
#  'continue',
#  'continued',
#  'contrary',
#  'contributed',
#  'control',
#  'controversy',
#  'conviction',
#  'cooperation',
#  'cost',
#  'counsel',
#  'countryman',
#  'courage',
#  'course',
#  'court',
#  'covenant',
#  'create',
#  'created',
#  'credit',
#  'creed',
#  'crime',
#  'crisis',
#  'cultivate',
#  'currency',
#  'current',
#  'danger',
#  'dangerous',
#  'dark',
#  'day',
#  'dealing',
#  'debt',
#  'decision',
#  'declaration',
#  'declare',
#  'declared',
#  'dedication',
#  'deep',
#  'deeply',
#  'defend',
#  'defense',
#  'degree',
#  'demand',
#  'democracy',
#  'democratic',
#  'department',
#  'depend',
#  'depends',
#  'depression',
#  'desire',
#  'destiny',
#  'destroy',
#  'destruction',
#  'determination',
#  'determined',
#  'development',
#  'devoted',
#  'devotion',
#  'did',
#  'difference',
#  'different',
#  'difficult',
#  'difficulty',
#  'dignity',
#  'direct',
#  'directed',
#  'direction',
#  'directly',
#  'discharge',
#  'discussion',
#  'disposition',
#  'dispute',
#  'distant',
#  'distinction',
#  'distinguished',
#  'divide',
#  'divided',
#  'divine',
#  'division',
#  'doe',
#  'doing',
#  'domestic',
#  'dominion',
#  'doubt',
#  'drawn',
#  'dream',
#  'duty',
#  'early',
#  'earnest',
#  'earth',
#  'economic',
#  'economy',
#  'education',
#  'effect',
#  'effective',
#  'efficient',
#  'effort',
#  'elected',
#  'election',
#  'element',
#  'emergency',
#  'employed',
#  'employment',
#  'enable',
#  'encourage',
#  'encouragement',
#  'end',
#  'endeavor',
#  'endure',
#  'enduring',
#  'enemy',
#  'energy',
#  'enforce',
#  'enforced',
#  'enforcement',
#  'engaged',
#  'enjoy',
#  'enjoyed',
#  'enjoyment',
#  'enlightened',
#  'enter',
#  'enterprise',
#  'entire',
#  'entirely',
#  'entitled',
#  'equal',
#  'equality',
#  'equally',
#  'era',
#  'error',
#  'especially',
#  'essential',
#  'establish',
#  'established',
#  'establishment',
#  'europe',
#  'european',
#  'event',
#  'evil',
#  'exalted',
#  'example',
#  'execute',
#  'execution',
#  'executive',
#  'exercise',
#  'exercised',
#  'exist',
#  'existence',
#  'existing',
#  'exists',
#  'expect',
#  'expected',
#  'expenditure',
#  'expense',
#  'experience',
#  'experiment',
#  'express',
#  'expressed',
#  'expression',
#  'extend',
#  'extended',
#  'extent',
#  'eye',
#  'face',
#  'facility',
#  'fact',
#  'factory',
#  'fail',
#  'failed',
#  'failure',
#  'fair',
#  'faith',
#  'faithful',
#  'faithfully',
#  'fall',
#  'false',
#  'family',
#  'far',
#  'farm',
#  'fate',
#  'father',
#  'favor',
#  'favored',
#  'fear',
#  'federal',
#  'feel',
#  'feeling',
#  'fellow',
#  'felt',
#  'field',
#  'finally',
#  'financial',
#  'firm',
#  'fixed',
#  'flag',
#  'follow',
#  'followed',
#  'forbearance',
#  'force',
#  'foreign',
#  'forever',
#  'form',
#  'formation',
#  'formed',
#  'forth',
#  'forward',
#  'foundation',
#  'founded',
#  'freedom',
#  'friend',
#  'friendly',
#  'friendship',
#  'fulfillment',
#  'fully',
#  'function',
#  'fundamental',
#  'general',
#  'generally',
#  'generation',
#  'generous',
#  'genius',
#  'gift',
#  'given',
#  'globe',
#  'glory',
#  'goal',
#  'god',
#  'gone',
#  'govern',
#  'grant',
#  'granted',
#  'grateful',
#  'gratitude',
#  'greater',
#  'greatest',
#  'greatly',
#  'greatness',
#  'ground',
#  'group',
#  'growing',
#  'growth',
#  'guaranty',
#  'guidance',
#  'guide',
#  'habit',
#  'half',
#  'hand',
#  'happily',
#  'happiness',
#  'happy',
#  'hard',
#  'harmony',
#  'hatred',
#  'having',
#  'head',
#  'health',
#  'heard',
#  'heart',
#  'heaven',
#  'held',
#  'help',
#  'helped',
#  'heretofore',
#  'high',
#  'higher',
#  'highest',
#  'history',
#  'hold',
#  'home',
#  'honest',
#  'honor',
#  'honorable',
#  'hour',
#  'house',
#  'human',
#  'humanity',
#  'humble',
#  'idea',
#  'ideal',
#  'ill',
#  'immediate',
#  'importance',
#  'important',
#  'imposed',
#  'impossible',
#  'improvement',
#  'increase',
#  'increased',
#  'increasing',
#  'independence',
#  'independent',
#  'individual',
#  'industrial',
#  'industry',
#  'influence',
#  'information',
#  'injury',
#  'injustice',
#  'instance',
#  'instead',
#  'institution',
#  'instrument',
#  'instrumentality',
#  'integrity',
#  'intelligence',
#  'intelligent',
#  'intended',
#  'intention',
#  'intercourse',
#  'interference',
#  'internal',
#  'international',
#  'invasion',
#  'invite',
#  'ion',
#  'island',
#  'issue',
#  'job',
#  'join',
#  'journey',
#  'judge',
#  'judgment',
#  'jurisdiction',
#  'justice',
#  'justly',
#  'kind',
#  'know',
#  'knowing',
#  'knowledge',
#  'known',
#  'labor',
#  'land',
#  'language',
#  'large',
#  'larger',
#  'lasting',
#  'late',
#  'law',
#  'le',
#  'lead',
#  'leader',
#  'leadership',
#  'leading',
#  'learn',
#  'learned',
#  'leave',
#  'led',
#  'left',
#  'legal',
#  'legislation',
#  'legislative',
#  'legislature',
#  'legitimate',
#  'lesson',
#  'let',
#  'liberal',
#  'liberty',
#  'lie',
#  'light',
#  'like',
#  'likely',
#  'limit',
#  'limitation',
#  'limited',
#  'line',
#  'little',
#  'live',
#  'living',
#  'local',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'loss',
#  'lost',
#  'love',
#  'magistrate',
#  'maintain',
#  'maintained',
#  'maintaining',
#  'maintenance',
#  'majority',
#  'making',
#  'man',
#  'mankind',
#  'manner',
#  'manufacture',
#  'mark',
#  'market',
#  'mass',
#  'master',
#  'material',
#  'matter',
#  'mean',
#  'meaning',
#  'measure',
#  'meet',
#  'member',
#  'mere',
#  'merely',
#  'met',
#  'method',
#  'mighty',
#  'military',
#  'militia',
#  'million',
#  'mind',
#  'minority',
#  'mode',
#  'modern',
#  'moment',
#  'money',
#  'moral',
#  'movement',
#  'mutual',
#  'narrow',
#  'national',
#  'nations',
#  'native',
#  'natural',
#  'nature',
#  'naval',
#  'navy',
#  'nearly',
#  'necessary',
#  'necessity',
#  'need',
#  'needed',
#  'negro',
#  'neighbor',
#  'north',
#  'number',
#  'oath',
#  'object',
#  'obligation',
#  'observe',
#  'observed',
#  'obvious',
#  'occasion',
#  'ocean',
#  'offer',
#  'office',
#  'officer',
#  'official',
#  'old',
#  'open',
#  'operation',
#  'opinion',
#  'opportunity',
#  'opposed',
#  'order',
#  'organization',
#  'ought',
#  'pacific',
#  'paid',
#  'particular',
#  'partisan',
#  'party',
#  'pas',
#  'passed',
#  'passion',
#  'past',
#  'path',
#  'patriot',
#  'patriotic',
#  'patriotism',
#  'pay',
#  'peace',
#  'peaceful',
#  'peculiar',
#  'perfect',
#  'perform',
#  'performance',
#  'peril',
#  'period',
#  'permanent',
#  'permit',
#  'person',
#  'personal',
#  'place',
#  'placed',
#  'plain',
#  'plan',
#  'play',
#  'pledge',
#  'pledged',
#  'point',
#  'policy',
#  'political',
#  'politics',
#  'popular',
#  'population',
#  'portion',
#  'position',
#  'posse',
#  'possession',
#  'possibility',
#  'possible',
#  'poverty',
#  'powerful',
#  'practicable',
#  'practical',
#  'practice',
#  'prayer',
#  'precious',
#  'predecessor',
#  'prejudice',
#  'prepared',
#  'prescribed',
#  'presence',
#  'present',
#  'preservation',
#  'preserve',
#  'preserved',
#  'preserving',
#  'president',
#  'press',
#  'prevent',
#  'price',
#  'pride',
#  'principle',
#  'private',
#  'privilege',
#  'problem',
#  'process',
#  'produce',
#  'product',
#  'production',
#  'productive',
#  'profit',
#  'profound',
#  'program',
#  'progress',
#  'promise',
#  'promote',
#  'promoted',
#  'proof',
#  'proper',
#  'property',
#  'prosperity',
#  'prosperous',
#  'protect',
#  'protected',
#  'protection',
#  'proud',
#  'proved',
#  'provide',
#  'provided',
#  'providence',
#  'provision',
#  'public',
#  'purpose',
#  'pursue',
#  'pursued',
#  'pursuit',
#  'quality',
#  'question',
#  'race',
#  'raised',
#  'reach',
#  'reached',
#  'ready',
#  'real',
#  'realize',
#  'realized',
#  'reason',
#  'reasonable',
#  'receive',
#  'received',
#  'recent',
#  'recognize',
#  'recognized',
#  'recommend',
#  'recommendation',
#  'reduce',
#  'reform',
#  'regard',
#  'relation',
#  'reliance',
#  'relief',
#  'religion',
#  'religious',
#  'remain',
#  'remains',
#  'remedy',
#  'remember',
#  'renew',
#  'renewed',
#  'representative',
#  'republic',
#  'republican',
#  'require',
#  'required',
#  'requires',
#  'reserved',
#  'resolve',
#  'resource',
#  'respect',
#  'respecting',
#  'respective',
#  'responsibility',
#  'responsible',
#  'rest',
#  'restoration',
#  'restore',
#  'result',
#  'return',
#  'revenue',
#  'revolution',
#  'reward',
#  'rich',
#  'river',
#  'road',
#  'role',
#  'rule',
#  'run',
#  'sacred',
#  'sacrifice',
#  'safe',
#  'safety',
#  'said',
#  'sanction',
#  'satisfaction',
#  'save',
#  'say',
#  'scarcely',
#  'scheme',
#  'school',
#  'science',
#  'sea',
#  'second',
#  'section',
#  'sectional',
#  'secure',
#  'secured',
#  'security',
#  'seek',
#  'seeking',
#  'seen',
#  'self',
#  'senate',
#  'sense',
#  'sentiment',
#  'separate',
#  'servant',
#  'serve',
#  'service',
#  'session',
#  'set',
#  'settled',
#  'settlement',
#  'share',
#  'shore',
#  'short',
#  'shown',
#  'simple',
#  'single',
#  'situation',
#  'slave',
#  'slavery',
#  'small',
#  'social',
#  'society',
#  'soil',
#  'soldier',
#  'solemn',
#  'solution',
#  'soon',
#  'sought',
#  'soul',
#  'sound',
#  'source',
#  'south',
#  'southern',
#  'sovereign',
#  'sovereignty',
#  'speak',
#  'special',
#  'sphere',
#  'spirit',
#  'spring',
#  'stability',
#  'stand',
#  'standard',
#  'standing',
#  'state',
#  'states',
#  'statesman',
#  'station',
#  'step',
#  'story',
#  'strength',
#  'strengthen',
#  'strengthened',
#  'strict',
#  'strictly',
#  'strive',
#  'strong',
#  'stronger',
#  'structure',
#  'struggle',
#  'subject',
#  'succeed',
#  'success',
#  'successful',
#  'suffer',
#  'suffering',
#  'sufficient',
#  'suffrage',
#  'support',
#  'supported',
#  'supposed',
#  'supreme',
#  'sure',
#  'surely',
#  'surplus',
#  'sustain',
#  'sustained',
#  'sympathy',
#  'taken',
#  'taking',
#  'talent',
#  'tariff',
#  'task',
#  'tax',
#  'taxation',
#  'tendency',
#  'term',
#  'territories',
#  'territory',
#  'th',
#  'thank',
#  'thing',
#  'think',
#  'thought',
#  'thousand',
#  'threat',
#  'tie',
#  'today',
#  'trade',
#  'tranquillity',
#  'treasury',
#  'treaty',
#  'trial',
#  'tribunal',
#  'triumph',
#  'true',
#  'truly',
#  'trust',
#  'truth',
#  'try',
#  'turn',
#  'tyranny',
#  'understand',
#  'understanding',
#  'understood',
#  'union',
#  'unite',
#  'united',
#  'unity',
#  'universal',
#  'unless',
#  'use',
#  'used',
#  'useful',
#  'value',
#  'various',
#  'vast',
#  'victory',
#  'view',
#  'violence',
#  'virtue',
#  'vision',
#  'vital',
#  'voice',
#  'vote',
#  'want',
#  'war',
#  'washington',
#  'waste',
#  'way',
#  'weak',
#  'weakness',
#  'wealth',
#  'weapon',
#  'weight',
#  'welcome',
#  'welfare',
#  'west',
#  'western',
#  'whilst',
#  'white',
#  'willing',
#  'wisdom',
#  'wise',
#  'wisely',
#  'wish',
#  'witness',
#  'woman',
#  'word',
#  'work',
#  'worthy',
#  'written',
#  'wrong',
#  'yes',
#  'young',
#  'zeal']
